# %%
import pandas as pd
import numpy as np

df = pd.read_csv('produkty_mediaexpert_szczegoly.csv')

# %%
df['Cena'] = (
    df['Cena']
    .str.replace('\n', '', regex=True)
    .str.replace('zł', '', regex=False)
    .str.replace('\u202f', '', regex=False)
    .str.replace('n', '', regex=False)
    .astype(int)                        
)

df['Cena'] = df.apply(
    lambda row: row['Cena'] /100,
    axis=1
)

df = df.dropna() 
df.head()
# Out:
#                                                Tytuł     Cena  \
# 0  Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3699.00
# 1  Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8499.99
# 2  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00
# 3  Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00
# 4  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4879.00
#
#                Procesor:                 RAM:                Dysk SSD:  \
# 0  Intel Core i5-12450HX  24GB, DDR5, 4800MHz   512GB PCIe NVMe 4.0 x4
# 1               Apple M4                 16GB                    512GB
# 2      AMD Ryzen 7 7730U           16GB, DDR4   512GB PCIe NVMe 4.0 x4
# 3   Intel Core i5-13420H           16GB, DDR5          512GB PCIe NVMe
# 4     AMD Ryzen 7 7435HS  16GB, DDR5, 4800MHz  1000GB PCIe NVMe 4.0 x4
#
#                                Karta graficzna:  \
# 0  NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                          Apple M4 (10 rdzeni)
# 2                           AMD Radeon Graphics
# 3  NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4                       NVIDIA GeForce RTX 4050
#
#                                               Ekran: System operacyjny:
# 0           15.6", 1920 x 1080px, Matryca IPS, 144Hz    Windows 11 Home
# 1  14.2", 3024 x 1964px, Matryca Liquid Retina XD...      macOS Sequoia
# 2         16", 1920 x 1200px, Matryca IPS, LED, 60Hz    Windows 11 Home
# 3           15.6", 1920 x 1080px, Matryca IPS, 144Hz               Brak
# 4           15.6", 1920 x 1080px, Matryca IPS, 144Hz    Windows 11 Home

# %%
df = df.dropna()
df.head()
# Out:
#                                                Tytuł     Cena  \
# 0  Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3699.00
# 1  Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8499.99
# 2  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00
# 3  Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00
# 4  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4879.00
#
#                Procesor:                 RAM:                Dysk SSD:  \
# 0  Intel Core i5-12450HX  24GB, DDR5, 4800MHz   512GB PCIe NVMe 4.0 x4
# 1               Apple M4                 16GB                    512GB
# 2      AMD Ryzen 7 7730U           16GB, DDR4   512GB PCIe NVMe 4.0 x4
# 3   Intel Core i5-13420H           16GB, DDR5          512GB PCIe NVMe
# 4     AMD Ryzen 7 7435HS  16GB, DDR5, 4800MHz  1000GB PCIe NVMe 4.0 x4
#
#                                Karta graficzna:  \
# 0  NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                          Apple M4 (10 rdzeni)
# 2                           AMD Radeon Graphics
# 3  NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4                       NVIDIA GeForce RTX 4050
#
#                                               Ekran: System operacyjny:
# 0           15.6", 1920 x 1080px, Matryca IPS, 144Hz    Windows 11 Home
# 1  14.2", 3024 x 1964px, Matryca Liquid Retina XD...      macOS Sequoia
# 2         16", 1920 x 1200px, Matryca IPS, LED, 60Hz    Windows 11 Home
# 3           15.6", 1920 x 1080px, Matryca IPS, 144Hz               Brak
# 4           15.6", 1920 x 1080px, Matryca IPS, 144Hz    Windows 11 Home

# %%
df = df.rename(columns={'RAM:': 'RAM'})
df['RAM'] = df['RAM'].str.extract(r'(\d+)\s*GB', expand=False).astype(int)

df.head()
# Out:
#                                                Tytuł    Cena  \
# 0  Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  369900
# 1  Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  849999
# 2  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  298900
# 3  Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  369900
# 4  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  487900
#
#                Procesor:  RAM                Dysk SSD:  \
# 0  Intel Core i5-12450HX   24   512GB PCIe NVMe 4.0 x4
# 1               Apple M4   16                    512GB
# 2      AMD Ryzen 7 7730U   16   512GB PCIe NVMe 4.0 x4
# 3   Intel Core i5-13420H   16          512GB PCIe NVMe
# 4     AMD Ryzen 7 7435HS   16  1000GB PCIe NVMe 4.0 x4
#
#                                Karta graficzna:  \
# 0  NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                          Apple M4 (10 rdzeni)
# 2                           AMD Radeon Graphics
# 3  NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4                       NVIDIA GeForce RTX 4050
#
#                                               Ekran: System operacyjny:
# 0           15.6", 1920 x 1080px, Matryca IPS, 144Hz    Windows 11 Home
# 1  14.2", 3024 x 1964px, Matryca Liquid Retina XD...      macOS Sequoia
# 2         16", 1920 x 1200px, Matryca IPS, LED, 60Hz    Windows 11 Home
# 3           15.6", 1920 x 1080px, Matryca IPS, 144Hz               Brak
# 4           15.6", 1920 x 1080px, Matryca IPS, 144Hz    Windows 11 Home

# %%
df = df.rename(columns={'Dysk SSD:': 'Dysk SSD'})
df[['Dysk_Wartosc', 'Dysk_Jednostka']] = df['Dysk SSD'].str.extract(r'(\d+)\s*(GB|TB)', expand=True)
df['Dysk_Wartosc'] = df.apply(
    lambda row: row['Dysk_Wartosc'] * 1024 if row['Dysk_Jednostka'] == 'TB' else row['Dysk_Wartosc'],
    axis=1
)
df['Dysk SSD'] = df['Dysk_Wartosc']

df = df.drop(columns=['Dysk_Wartosc', 'Dysk_Jednostka'])

df
# Out:
#                                                 Tytuł     Cena  \
# 0   Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3699.00
# 1   Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8499.99
# 2   Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00
# 3   Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00
# 4   Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4879.00
# 5   Laptop ASUS ExpertBook B1502CVA-BQ0095X 15.6" ...  2799.00
# 6   Laptop PREDATOR Helios Neo PHN16-71 16" IPS 16...  6999.99
# 7   Laptop APPLE MacBook Air 13.6" Retina M2 8GB R...  4199.00
# 8   Laptop ACER Swift Go 14 SFG14-63-R19Q 14" OLED...  3499.00
# 9   Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4999.98
# 10  Laptop ACER Nitro AN16-41-R7U0 16" IPS 165Hz R...  6699.00
# 11  Laptop LENOVO Yoga Slim 6 14IRH8 14" OLED i5-1...  3499.00
# 12  Laptop ASUS TUF Gaming A15 FA507NV-TT903W 15.6...  4999.00
# 13  Laptop LENOVO Legion Slim 5 16IRH8 16" IPS 240...  5999.99
# 14  Laptop DELL G15 5530-6916 i7-13650HX 16GB RAM ...  5999.98
# 15  Laptop LENOVO Legion 5 15ARH7H 15.6" IPS 165Hz...  5479.00
# 16  Laptop ACER Nitro V 15 ANV15-51-53W4 15.6" IPS...  4299.99
# 17  Laptop HP Pavilion 15-EH3333NW 15.6" IPS R5-75...  2799.99
# 18  Laptop LENOVO Yoga Slim 7 15ILL9 Aura Edition ...  6399.99
# 19  Laptop ACER Nitro V 16 ANV16-41 16" IPS 165Hz ...  4299.00
# 20  Laptop ASUS VivoBook M1502YA-BQ059W 15.6" IPS ...  1899.99
# 21  Laptop LENOVO Legion Slim 5 16AHP9 16" IPS 240...  7979.00
# 22  Laptop ACER Swift 14 AI SF14-11 Copilot+ PC 14...  4499.00
# 23  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2998.99
# 24  Laptop ACER Nitro 5 AN515-58 15.6" IPS 144Hz i...  3389.99
# 25  Laptop LENOVO Yoga Book 9 13IRU8 13.3" OLED i7...  8979.00
# 26  Laptop ACER Nitro V 15 ANV15-41 15.6" IPS 144H...  2999.99
# 27  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  3999.00
# 28  Laptop HP Envy x360 15-FH0333NW 15.6" IPS R5-7...  3999.98
# 29  Laptop LENOVO IdeaPad Slim 3 Chrome 14M868 14"...   999.00
#
#                                 Procesor:                    RAM: Dysk SSD  \
# 0                   Intel Core i5-12450HX     24GB, DDR5, 4800MHz      512
# 1                                Apple M4                    16GB      512
# 2                       AMD Ryzen 7 7730U              16GB, DDR4      512
# 3                    Intel Core i5-13420H              16GB, DDR5      512
# 4                      AMD Ryzen 7 7435HS     16GB, DDR5, 4800MHz     1000
# 5                     Intel Core i5-1335U              16GB, DDR4      512
# 6                   Intel Core i9-13900HX     16GB, DDR5, 5600MHz     1000
# 7                                Apple M2                     8GB      256
# 8                      AMD Ryzen 5 8645HS           16GB, LPDDR5X      512
# 9                 Intel Core Ultra 7-155H  16GB, LPDDR5X, 7467MHz      512
# 10                     AMD Ryzen 7 7735HS              16GB, DDR5     1000
# 11                   Intel Core i5-13500H  16GB, LPDDR5X, 5200MHz      512
# 12                     AMD Ryzen 7 7735HS     16GB, DDR5, 4800MHz     1000
# 13                   Intel Core i5-13500H     16GB, DDR5, 5200MHz      512
# 14                  Intel Core i7-13650HX     16GB, DDR5, 4800MHz      512
# 15                      AMD Ryzen 7 6800H     16GB, DDR5, 4800MHz      512
# 16                   Intel Core i5-13420H              16GB, DDR5      512
# 17                      AMD Ryzen 5 7530U     16GB, DDR4, 3200MHz     1000
# 18                Intel Core Ultra 7-258V  32GB, LPDDR5X, 8533MHz      512
# 19                     AMD Ryzen 5 8645HS     16GB, DDR5, 5600MHz      512
# 20                      AMD Ryzen 5 7530U               8GB, DDR4      512
# 21                     AMD Ryzen 7 8845HS     32GB, DDR5, 5600MHz      512
# 22  Qualcomm Snapdragon X Plus X1P-64-100           16GB, LPDDR5X     1000
# 23                      AMD Ryzen 7 7730U     16GB, DDR4, 3200MHz      512
# 24                   Intel Core i5-12450H              16GB, DDR4      512
# 25                    Intel Core i7-1355U  16GB, LPDDR5X, 6400MHz     1000
# 26                     AMD Ryzen 5 7535HS              16GB, DDR5      512
# 27                     AMD Ryzen 7 7435HS     24GB, DDR5, 4800MHz      512
# 28                      AMD Ryzen 5 7530U  16GB, LPDDR4X, 4266MHz      512
# 29                  MediaTek Kompanio 520   8GB, LPDDR4X, 3600MHz      128
#
#                                     Karta graficzna:  \
# 0       NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                               Apple M4 (10 rdzeni)
# 2                                AMD Radeon Graphics
# 3       NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4                            NVIDIA GeForce RTX 4050
# 5                                 Intel UHD Graphics
# 6       NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 7                                Apple M2 (8 rdzeni)
# 8                                    AMD Radeon 760M
# 9                                 Intel Arc Graphics
# 10         NVIDIA GeForce RTX 4070 + AMD Radeon 680M
# 11                                Intel UHD Graphics
# 12         NVIDIA GeForce RTX 4060 + AMD Radeon 680M
# 13  NVIDIA GeForce RTX 4060 + Intel Iris Xe Graphics
# 14      NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 15         NVIDIA GeForce RTX 3070 + AMD Radeon 680M
# 16      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 17                               AMD Radeon Graphics
# 18                           Intel Arc Graphics 140V
# 19         NVIDIA GeForce RTX 4050 + AMD Radeon 760M
# 20                               AMD Radeon Graphics
# 21         NVIDIA GeForce RTX 4070 + AMD Radeon 780M
# 22                                   Qualcomm Adreno
# 23                               AMD Radeon Graphics
# 24      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 25                            Intel Iris Xe Graphics
# 26         NVIDIA GeForce RTX 2050 + AMD Radeon 660M
# 27                           NVIDIA GeForce RTX 4050
# 28                               AMD Radeon Graphics
# 29                              ARM Mali-G52 2EE MC2
#
#                                                Ekran:       System operacyjny:
# 0            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 1   14.2", 3024 x 1964px, Matryca Liquid Retina XD...            macOS Sequoia
# 2          16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 3            15.6", 1920 x 1080px, Matryca IPS, 144Hz                     Brak
# 4            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 5                     15.6", 1920 x 1080px, LED, 60Hz  Windows 11 Professional
# 6         16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 7   13.6", 2560 x 1664px, Matryca Liquid Retina,Ma...           macOS Monterey
# 8                                  14", 2880 x 1800px          Windows 11 Home
# 9                            14", 1920 x 1200px, 60Hz          Windows 11 Home
# 10        16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 11                           14", 1920 x 1200px, 60Hz          Windows 11 Home
# 12           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 13        16", 2560 x 1600px, Matryca IPS, LED, 240Hz          Windows 11 Home
# 14      15.6", 1920 x 1080px, Matryca WVA, LED, 165Hz          Windows 11 Home
# 15           15.6", 2560 x 1440px, Matryca IPS, 165Hz                     Brak
# 16      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 17                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 18           15.3", 2880 x 1800px, Matryca IPS, 120Hz          Windows 11 Home
# 19             16", 1920 x 1200px, Matryca IPS, 165Hz          Windows 11 Home
# 20       15.6", 1920 x 1080px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 21             16", 2560 x 1600px, Matryca IPS, 240Hz          Windows 11 Home
# 22           14.5", 2560 x 1600px, Matryca IPS, 120Hz          Windows 11 Home
# 23         16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 24      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 25                         13.3", 2880 x 1800px, 60Hz          Windows 11 Home
# 26           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 27           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 28                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 29                     14", 1920 x 1080px, Matryca TN                Chrome OS

# %%
df = df.rename(columns={'RAM:': 'RAM'})

df['RAM'] = df['RAM'].str.extract(r'(\d+)\s*GB', expand=False).astype(int)

df
# Out:
#                                                 Tytuł     Cena  \
# 0   Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3699.00
# 1   Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8499.99
# 2   Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00
# 3   Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00
# 4   Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4879.00
# 5   Laptop ASUS ExpertBook B1502CVA-BQ0095X 15.6" ...  2799.00
# 6   Laptop PREDATOR Helios Neo PHN16-71 16" IPS 16...  6999.99
# 7   Laptop APPLE MacBook Air 13.6" Retina M2 8GB R...  4199.00
# 8   Laptop ACER Swift Go 14 SFG14-63-R19Q 14" OLED...  3499.00
# 9   Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4999.98
# 10  Laptop ACER Nitro AN16-41-R7U0 16" IPS 165Hz R...  6699.00
# 11  Laptop LENOVO Yoga Slim 6 14IRH8 14" OLED i5-1...  3499.00
# 12  Laptop ASUS TUF Gaming A15 FA507NV-TT903W 15.6...  4999.00
# 13  Laptop LENOVO Legion Slim 5 16IRH8 16" IPS 240...  5999.99
# 14  Laptop DELL G15 5530-6916 i7-13650HX 16GB RAM ...  5999.98
# 15  Laptop LENOVO Legion 5 15ARH7H 15.6" IPS 165Hz...  5479.00
# 16  Laptop ACER Nitro V 15 ANV15-51-53W4 15.6" IPS...  4299.99
# 17  Laptop HP Pavilion 15-EH3333NW 15.6" IPS R5-75...  2799.99
# 18  Laptop LENOVO Yoga Slim 7 15ILL9 Aura Edition ...  6399.99
# 19  Laptop ACER Nitro V 16 ANV16-41 16" IPS 165Hz ...  4299.00
# 20  Laptop ASUS VivoBook M1502YA-BQ059W 15.6" IPS ...  1899.99
# 21  Laptop LENOVO Legion Slim 5 16AHP9 16" IPS 240...  7979.00
# 22  Laptop ACER Swift 14 AI SF14-11 Copilot+ PC 14...  4499.00
# 23  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2998.99
# 24  Laptop ACER Nitro 5 AN515-58 15.6" IPS 144Hz i...  3389.99
# 25  Laptop LENOVO Yoga Book 9 13IRU8 13.3" OLED i7...  8979.00
# 26  Laptop ACER Nitro V 15 ANV15-41 15.6" IPS 144H...  2999.99
# 27  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  3999.00
# 28  Laptop HP Envy x360 15-FH0333NW 15.6" IPS R5-7...  3999.98
# 29  Laptop LENOVO IdeaPad Slim 3 Chrome 14M868 14"...   999.00
#
#                                 Procesor:  RAM Dysk SSD  \
# 0                   Intel Core i5-12450HX   24      512
# 1                                Apple M4   16      512
# 2                       AMD Ryzen 7 7730U   16      512
# 3                    Intel Core i5-13420H   16      512
# 4                      AMD Ryzen 7 7435HS   16     1000
# 5                     Intel Core i5-1335U   16      512
# 6                   Intel Core i9-13900HX   16     1000
# 7                                Apple M2    8      256
# 8                      AMD Ryzen 5 8645HS   16      512
# 9                 Intel Core Ultra 7-155H   16      512
# 10                     AMD Ryzen 7 7735HS   16     1000
# 11                   Intel Core i5-13500H   16      512
# 12                     AMD Ryzen 7 7735HS   16     1000
# 13                   Intel Core i5-13500H   16      512
# 14                  Intel Core i7-13650HX   16      512
# 15                      AMD Ryzen 7 6800H   16      512
# 16                   Intel Core i5-13420H   16      512
# 17                      AMD Ryzen 5 7530U   16     1000
# 18                Intel Core Ultra 7-258V   32      512
# 19                     AMD Ryzen 5 8645HS   16      512
# 20                      AMD Ryzen 5 7530U    8      512
# 21                     AMD Ryzen 7 8845HS   32      512
# 22  Qualcomm Snapdragon X Plus X1P-64-100   16     1000
# 23                      AMD Ryzen 7 7730U   16      512
# 24                   Intel Core i5-12450H   16      512
# 25                    Intel Core i7-1355U   16     1000
# 26                     AMD Ryzen 5 7535HS   16      512
# 27                     AMD Ryzen 7 7435HS   24      512
# 28                      AMD Ryzen 5 7530U   16      512
# 29                  MediaTek Kompanio 520    8      128
#
#                                     Karta graficzna:  \
# 0       NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                               Apple M4 (10 rdzeni)
# 2                                AMD Radeon Graphics
# 3       NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4                            NVIDIA GeForce RTX 4050
# 5                                 Intel UHD Graphics
# 6       NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 7                                Apple M2 (8 rdzeni)
# 8                                    AMD Radeon 760M
# 9                                 Intel Arc Graphics
# 10         NVIDIA GeForce RTX 4070 + AMD Radeon 680M
# 11                                Intel UHD Graphics
# 12         NVIDIA GeForce RTX 4060 + AMD Radeon 680M
# 13  NVIDIA GeForce RTX 4060 + Intel Iris Xe Graphics
# 14      NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 15         NVIDIA GeForce RTX 3070 + AMD Radeon 680M
# 16      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 17                               AMD Radeon Graphics
# 18                           Intel Arc Graphics 140V
# 19         NVIDIA GeForce RTX 4050 + AMD Radeon 760M
# 20                               AMD Radeon Graphics
# 21         NVIDIA GeForce RTX 4070 + AMD Radeon 780M
# 22                                   Qualcomm Adreno
# 23                               AMD Radeon Graphics
# 24      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 25                            Intel Iris Xe Graphics
# 26         NVIDIA GeForce RTX 2050 + AMD Radeon 660M
# 27                           NVIDIA GeForce RTX 4050
# 28                               AMD Radeon Graphics
# 29                              ARM Mali-G52 2EE MC2
#
#                                                Ekran:       System operacyjny:
# 0            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 1   14.2", 3024 x 1964px, Matryca Liquid Retina XD...            macOS Sequoia
# 2          16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 3            15.6", 1920 x 1080px, Matryca IPS, 144Hz                     Brak
# 4            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 5                     15.6", 1920 x 1080px, LED, 60Hz  Windows 11 Professional
# 6         16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 7   13.6", 2560 x 1664px, Matryca Liquid Retina,Ma...           macOS Monterey
# 8                                  14", 2880 x 1800px          Windows 11 Home
# 9                            14", 1920 x 1200px, 60Hz          Windows 11 Home
# 10        16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 11                           14", 1920 x 1200px, 60Hz          Windows 11 Home
# 12           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 13        16", 2560 x 1600px, Matryca IPS, LED, 240Hz          Windows 11 Home
# 14      15.6", 1920 x 1080px, Matryca WVA, LED, 165Hz          Windows 11 Home
# 15           15.6", 2560 x 1440px, Matryca IPS, 165Hz                     Brak
# 16      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 17                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 18           15.3", 2880 x 1800px, Matryca IPS, 120Hz          Windows 11 Home
# 19             16", 1920 x 1200px, Matryca IPS, 165Hz          Windows 11 Home
# 20       15.6", 1920 x 1080px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 21             16", 2560 x 1600px, Matryca IPS, 240Hz          Windows 11 Home
# 22           14.5", 2560 x 1600px, Matryca IPS, 120Hz          Windows 11 Home
# 23         16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 24      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 25                         13.3", 2880 x 1800px, 60Hz          Windows 11 Home
# 26           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 27           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 28                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 29                     14", 1920 x 1080px, Matryca TN                Chrome OS

# %%
df = df.rename(columns={'System operacyjny:': 'System operacyjny'})
df['System operacyjny'].value_counts()
# Out:
# System operacyjny
# Windows 11 Home            24
# Brak                        2
# macOS Sequoia               1
# Windows 11 Professional     1
# macOS Monterey              1
# Chrome OS                   1
# Name: count, dtype: int64

# %%
df['System operacyjny'] = df['System operacyjny'].replace('Brak', np.nan)

df['System operacyjny'] = df['System operacyjny'].fillna(
    df['Tytuł'].apply(lambda x: 'macOS Sequoia' if 'MAC' in x.upper() else 'Windows 11 Home')
)

df
# Out:
#                                                 Tytuł     Cena  \
# 0   Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3699.00
# 1   Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8499.99
# 2   Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00
# 3   Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00
# 4   Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4879.00
# 5   Laptop ASUS ExpertBook B1502CVA-BQ0095X 15.6" ...  2799.00
# 6   Laptop PREDATOR Helios Neo PHN16-71 16" IPS 16...  6999.99
# 7   Laptop APPLE MacBook Air 13.6" Retina M2 8GB R...  4199.00
# 8   Laptop ACER Swift Go 14 SFG14-63-R19Q 14" OLED...  3499.00
# 9   Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4999.98
# 10  Laptop ACER Nitro AN16-41-R7U0 16" IPS 165Hz R...  6699.00
# 11  Laptop LENOVO Yoga Slim 6 14IRH8 14" OLED i5-1...  3499.00
# 12  Laptop ASUS TUF Gaming A15 FA507NV-TT903W 15.6...  4999.00
# 13  Laptop LENOVO Legion Slim 5 16IRH8 16" IPS 240...  5999.99
# 14  Laptop DELL G15 5530-6916 i7-13650HX 16GB RAM ...  5999.98
# 15  Laptop LENOVO Legion 5 15ARH7H 15.6" IPS 165Hz...  5479.00
# 16  Laptop ACER Nitro V 15 ANV15-51-53W4 15.6" IPS...  4299.99
# 17  Laptop HP Pavilion 15-EH3333NW 15.6" IPS R5-75...  2799.99
# 18  Laptop LENOVO Yoga Slim 7 15ILL9 Aura Edition ...  6399.99
# 19  Laptop ACER Nitro V 16 ANV16-41 16" IPS 165Hz ...  4299.00
# 20  Laptop ASUS VivoBook M1502YA-BQ059W 15.6" IPS ...  1899.99
# 21  Laptop LENOVO Legion Slim 5 16AHP9 16" IPS 240...  7979.00
# 22  Laptop ACER Swift 14 AI SF14-11 Copilot+ PC 14...  4499.00
# 23  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2998.99
# 24  Laptop ACER Nitro 5 AN515-58 15.6" IPS 144Hz i...  3389.99
# 25  Laptop LENOVO Yoga Book 9 13IRU8 13.3" OLED i7...  8979.00
# 26  Laptop ACER Nitro V 15 ANV15-41 15.6" IPS 144H...  2999.99
# 27  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  3999.00
# 28  Laptop HP Envy x360 15-FH0333NW 15.6" IPS R5-7...  3999.98
# 29  Laptop LENOVO IdeaPad Slim 3 Chrome 14M868 14"...   999.00
#
#                                 Procesor:  RAM Dysk SSD  \
# 0                   Intel Core i5-12450HX   24      512
# 1                                Apple M4   16      512
# 2                       AMD Ryzen 7 7730U   16      512
# 3                    Intel Core i5-13420H   16      512
# 4                      AMD Ryzen 7 7435HS   16     1000
# 5                     Intel Core i5-1335U   16      512
# 6                   Intel Core i9-13900HX   16     1000
# 7                                Apple M2    8      256
# 8                      AMD Ryzen 5 8645HS   16      512
# 9                 Intel Core Ultra 7-155H   16      512
# 10                     AMD Ryzen 7 7735HS   16     1000
# 11                   Intel Core i5-13500H   16      512
# 12                     AMD Ryzen 7 7735HS   16     1000
# 13                   Intel Core i5-13500H   16      512
# 14                  Intel Core i7-13650HX   16      512
# 15                      AMD Ryzen 7 6800H   16      512
# 16                   Intel Core i5-13420H   16      512
# 17                      AMD Ryzen 5 7530U   16     1000
# 18                Intel Core Ultra 7-258V   32      512
# 19                     AMD Ryzen 5 8645HS   16      512
# 20                      AMD Ryzen 5 7530U    8      512
# 21                     AMD Ryzen 7 8845HS   32      512
# 22  Qualcomm Snapdragon X Plus X1P-64-100   16     1000
# 23                      AMD Ryzen 7 7730U   16      512
# 24                   Intel Core i5-12450H   16      512
# 25                    Intel Core i7-1355U   16     1000
# 26                     AMD Ryzen 5 7535HS   16      512
# 27                     AMD Ryzen 7 7435HS   24      512
# 28                      AMD Ryzen 5 7530U   16      512
# 29                  MediaTek Kompanio 520    8      128
#
#                                     Karta graficzna:  \
# 0       NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                               Apple M4 (10 rdzeni)
# 2                                AMD Radeon Graphics
# 3       NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4                            NVIDIA GeForce RTX 4050
# 5                                 Intel UHD Graphics
# 6       NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 7                                Apple M2 (8 rdzeni)
# 8                                    AMD Radeon 760M
# 9                                 Intel Arc Graphics
# 10         NVIDIA GeForce RTX 4070 + AMD Radeon 680M
# 11                                Intel UHD Graphics
# 12         NVIDIA GeForce RTX 4060 + AMD Radeon 680M
# 13  NVIDIA GeForce RTX 4060 + Intel Iris Xe Graphics
# 14      NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 15         NVIDIA GeForce RTX 3070 + AMD Radeon 680M
# 16      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 17                               AMD Radeon Graphics
# 18                           Intel Arc Graphics 140V
# 19         NVIDIA GeForce RTX 4050 + AMD Radeon 760M
# 20                               AMD Radeon Graphics
# 21         NVIDIA GeForce RTX 4070 + AMD Radeon 780M
# 22                                   Qualcomm Adreno
# 23                               AMD Radeon Graphics
# 24      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 25                            Intel Iris Xe Graphics
# 26         NVIDIA GeForce RTX 2050 + AMD Radeon 660M
# 27                           NVIDIA GeForce RTX 4050
# 28                               AMD Radeon Graphics
# 29                              ARM Mali-G52 2EE MC2
#
#                                                Ekran:        System operacyjny
# 0            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 1   14.2", 3024 x 1964px, Matryca Liquid Retina XD...            macOS Sequoia
# 2          16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 3            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 4            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 5                     15.6", 1920 x 1080px, LED, 60Hz  Windows 11 Professional
# 6         16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 7   13.6", 2560 x 1664px, Matryca Liquid Retina,Ma...           macOS Monterey
# 8                                  14", 2880 x 1800px          Windows 11 Home
# 9                            14", 1920 x 1200px, 60Hz          Windows 11 Home
# 10        16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 11                           14", 1920 x 1200px, 60Hz          Windows 11 Home
# 12           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 13        16", 2560 x 1600px, Matryca IPS, LED, 240Hz          Windows 11 Home
# 14      15.6", 1920 x 1080px, Matryca WVA, LED, 165Hz          Windows 11 Home
# 15           15.6", 2560 x 1440px, Matryca IPS, 165Hz          Windows 11 Home
# 16      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 17                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 18           15.3", 2880 x 1800px, Matryca IPS, 120Hz          Windows 11 Home
# 19             16", 1920 x 1200px, Matryca IPS, 165Hz          Windows 11 Home
# 20       15.6", 1920 x 1080px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 21             16", 2560 x 1600px, Matryca IPS, 240Hz          Windows 11 Home
# 22           14.5", 2560 x 1600px, Matryca IPS, 120Hz          Windows 11 Home
# 23         16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 24      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 25                         13.3", 2880 x 1800px, 60Hz          Windows 11 Home
# 26           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 27           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 28                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 29                     14", 1920 x 1080px, Matryca TN                Chrome OS

# %%
df = df.rename(columns={'Procesor:': 'Procesor'})
df['Procesor'].value_counts()
# Out:
# Procesor
# AMD Ryzen 5 7530U                        3
# Intel Core i5-13500H                     2
# AMD Ryzen 7 7730U                        2
# Intel Core i5-13420H                     2
# AMD Ryzen 7 7435HS                       2
# AMD Ryzen 5 8645HS                       2
# AMD Ryzen 7 7735HS                       2
# AMD Ryzen 5 7535HS                       1
# Intel Core i7-1355U                      1
# Intel Core i5-12450H                     1
# Qualcomm Snapdragon X Plus X1P-64-100    1
# AMD Ryzen 7 8845HS                       1
# Intel Core Ultra 7-258V                  1
# Intel Core i5-12450HX                    1
# AMD Ryzen 7 6800H                        1
# Intel Core i7-13650HX                    1
# Apple M4                                 1
# Intel Core Ultra 7-155H                  1
# Apple M2                                 1
# Intel Core i9-13900HX                    1
# Intel Core i5-1335U                      1
# MediaTek Kompanio 520                    1
# Name: count, dtype: int64

# %%
def extract_processor_brand(processor_name):
    if 'Intel' in processor_name:
        return 'Intel'
    elif 'AMD' in processor_name:
        return 'AMD'
    elif 'Apple' in processor_name:
        return 'Apple'
    elif 'MediaTek' in processor_name:
        return 'MediaTek'
    elif 'Qualcomm' in processor_name:
        return 'Qualcomm'
    else:
        return 'Inne'

df['Firma procesora'] = df['Procesor'].apply(extract_processor_brand)
df
# Out:
#                                                 Tytuł     Cena  \
# 0   Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3699.00
# 1   Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8499.99
# 2   Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00
# 3   Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00
# 4   Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4879.00
# 5   Laptop ASUS ExpertBook B1502CVA-BQ0095X 15.6" ...  2799.00
# 6   Laptop PREDATOR Helios Neo PHN16-71 16" IPS 16...  6999.99
# 7   Laptop APPLE MacBook Air 13.6" Retina M2 8GB R...  4199.00
# 8   Laptop ACER Swift Go 14 SFG14-63-R19Q 14" OLED...  3499.00
# 9   Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4999.98
# 10  Laptop ACER Nitro AN16-41-R7U0 16" IPS 165Hz R...  6699.00
# 11  Laptop LENOVO Yoga Slim 6 14IRH8 14" OLED i5-1...  3499.00
# 12  Laptop ASUS TUF Gaming A15 FA507NV-TT903W 15.6...  4999.00
# 13  Laptop LENOVO Legion Slim 5 16IRH8 16" IPS 240...  5999.99
# 14  Laptop DELL G15 5530-6916 i7-13650HX 16GB RAM ...  5999.98
# 15  Laptop LENOVO Legion 5 15ARH7H 15.6" IPS 165Hz...  5479.00
# 16  Laptop ACER Nitro V 15 ANV15-51-53W4 15.6" IPS...  4299.99
# 17  Laptop HP Pavilion 15-EH3333NW 15.6" IPS R5-75...  2799.99
# 18  Laptop LENOVO Yoga Slim 7 15ILL9 Aura Edition ...  6399.99
# 19  Laptop ACER Nitro V 16 ANV16-41 16" IPS 165Hz ...  4299.00
# 20  Laptop ASUS VivoBook M1502YA-BQ059W 15.6" IPS ...  1899.99
# 21  Laptop LENOVO Legion Slim 5 16AHP9 16" IPS 240...  7979.00
# 22  Laptop ACER Swift 14 AI SF14-11 Copilot+ PC 14...  4499.00
# 23  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2998.99
# 24  Laptop ACER Nitro 5 AN515-58 15.6" IPS 144Hz i...  3389.99
# 25  Laptop LENOVO Yoga Book 9 13IRU8 13.3" OLED i7...  8979.00
# 26  Laptop ACER Nitro V 15 ANV15-41 15.6" IPS 144H...  2999.99
# 27  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  3999.00
# 28  Laptop HP Envy x360 15-FH0333NW 15.6" IPS R5-7...  3999.98
# 29  Laptop LENOVO IdeaPad Slim 3 Chrome 14M868 14"...   999.00
#
#                                  Procesor  RAM Dysk SSD  \
# 0                   Intel Core i5-12450HX   24      512
# 1                                Apple M4   16      512
# 2                       AMD Ryzen 7 7730U   16      512
# 3                    Intel Core i5-13420H   16      512
# 4                      AMD Ryzen 7 7435HS   16     1000
# 5                     Intel Core i5-1335U   16      512
# 6                   Intel Core i9-13900HX   16     1000
# 7                                Apple M2    8      256
# 8                      AMD Ryzen 5 8645HS   16      512
# 9                 Intel Core Ultra 7-155H   16      512
# 10                     AMD Ryzen 7 7735HS   16     1000
# 11                   Intel Core i5-13500H   16      512
# 12                     AMD Ryzen 7 7735HS   16     1000
# 13                   Intel Core i5-13500H   16      512
# 14                  Intel Core i7-13650HX   16      512
# 15                      AMD Ryzen 7 6800H   16      512
# 16                   Intel Core i5-13420H   16      512
# 17                      AMD Ryzen 5 7530U   16     1000
# 18                Intel Core Ultra 7-258V   32      512
# 19                     AMD Ryzen 5 8645HS   16      512
# 20                      AMD Ryzen 5 7530U    8      512
# 21                     AMD Ryzen 7 8845HS   32      512
# 22  Qualcomm Snapdragon X Plus X1P-64-100   16     1000
# 23                      AMD Ryzen 7 7730U   16      512
# 24                   Intel Core i5-12450H   16      512
# 25                    Intel Core i7-1355U   16     1000
# 26                     AMD Ryzen 5 7535HS   16      512
# 27                     AMD Ryzen 7 7435HS   24      512
# 28                      AMD Ryzen 5 7530U   16      512
# 29                  MediaTek Kompanio 520    8      128
#
#                                     Karta graficzna:  \
# 0       NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                               Apple M4 (10 rdzeni)
# 2                                AMD Radeon Graphics
# 3       NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4                            NVIDIA GeForce RTX 4050
# 5                                 Intel UHD Graphics
# 6       NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 7                                Apple M2 (8 rdzeni)
# 8                                    AMD Radeon 760M
# 9                                 Intel Arc Graphics
# 10         NVIDIA GeForce RTX 4070 + AMD Radeon 680M
# 11                                Intel UHD Graphics
# 12         NVIDIA GeForce RTX 4060 + AMD Radeon 680M
# 13  NVIDIA GeForce RTX 4060 + Intel Iris Xe Graphics
# 14      NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 15         NVIDIA GeForce RTX 3070 + AMD Radeon 680M
# 16      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 17                               AMD Radeon Graphics
# 18                           Intel Arc Graphics 140V
# 19         NVIDIA GeForce RTX 4050 + AMD Radeon 760M
# 20                               AMD Radeon Graphics
# 21         NVIDIA GeForce RTX 4070 + AMD Radeon 780M
# 22                                   Qualcomm Adreno
# 23                               AMD Radeon Graphics
# 24      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 25                            Intel Iris Xe Graphics
# 26         NVIDIA GeForce RTX 2050 + AMD Radeon 660M
# 27                           NVIDIA GeForce RTX 4050
# 28                               AMD Radeon Graphics
# 29                              ARM Mali-G52 2EE MC2
#
#                                                Ekran:  \
# 0            15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 1   14.2", 3024 x 1964px, Matryca Liquid Retina XD...
# 2          16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 3            15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 4            15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 5                     15.6", 1920 x 1080px, LED, 60Hz
# 6         16", 2560 x 1600px, Matryca IPS, LED, 165Hz
# 7   13.6", 2560 x 1664px, Matryca Liquid Retina,Ma...
# 8                                  14", 2880 x 1800px
# 9                            14", 1920 x 1200px, 60Hz
# 10        16", 2560 x 1600px, Matryca IPS, LED, 165Hz
# 11                           14", 1920 x 1200px, 60Hz
# 12           15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 13        16", 2560 x 1600px, Matryca IPS, LED, 240Hz
# 14      15.6", 1920 x 1080px, Matryca WVA, LED, 165Hz
# 15           15.6", 2560 x 1440px, Matryca IPS, 165Hz
# 16      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz
# 17                  15.6", 1920 x 1080px, Matryca IPS
# 18           15.3", 2880 x 1800px, Matryca IPS, 120Hz
# 19             16", 1920 x 1200px, Matryca IPS, 165Hz
# 20       15.6", 1920 x 1080px, Matryca IPS, LED, 60Hz
# 21             16", 2560 x 1600px, Matryca IPS, 240Hz
# 22           14.5", 2560 x 1600px, Matryca IPS, 120Hz
# 23         16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 24      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz
# 25                         13.3", 2880 x 1800px, 60Hz
# 26           15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 27           15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 28                  15.6", 1920 x 1080px, Matryca IPS
# 29                     14", 1920 x 1080px, Matryca TN
#
#           System operacyjny Firma procesora
# 0           Windows 11 Home           Intel
# 1             macOS Sequoia           Apple
# 2           Windows 11 Home             AMD
# 3           Windows 11 Home           Intel
# 4           Windows 11 Home             AMD
# 5   Windows 11 Professional           Intel
# 6           Windows 11 Home           Intel
# 7            macOS Monterey           Apple
# 8           Windows 11 Home             AMD
# 9           Windows 11 Home           Intel
# 10          Windows 11 Home             AMD
# 11          Windows 11 Home           Intel
# 12          Windows 11 Home             AMD
# 13          Windows 11 Home           Intel
# 14          Windows 11 Home           Intel
# 15          Windows 11 Home             AMD
# 16          Windows 11 Home           Intel
# 17          Windows 11 Home             AMD
# 18          Windows 11 Home           Intel
# 19          Windows 11 Home             AMD
# 20          Windows 11 Home             AMD
# 21          Windows 11 Home             AMD
# 22          Windows 11 Home        Qualcomm
# 23          Windows 11 Home             AMD
# 24          Windows 11 Home           Intel
# 25          Windows 11 Home           Intel
# 26          Windows 11 Home             AMD
# 27          Windows 11 Home             AMD
# 28          Windows 11 Home             AMD
# 29                Chrome OS        MediaTek

# %%
df['Procesor'].value_counts()
df['Firma procesora'].value_counts()
# Out:
# Firma procesora
# AMD         14
# Intel       12
# Apple        2
# Qualcomm     1
# MediaTek     1
# Name: count, dtype: int64
