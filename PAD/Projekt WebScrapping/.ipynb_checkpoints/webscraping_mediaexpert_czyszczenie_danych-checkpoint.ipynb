# %%
import pandas as pd
df = pd.read_csv('produkty_mediaexpert_szczegoly.csv')
df
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                                                 Tytuł           Cena  \
# 0   Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3 699\n00\nzł
# 1   Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8 499\n99\nzł
# 2   Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2 989\n00\nzł
# 3   Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3 699\n00\nzł
# 4   Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4 879\n00\nzł
# 5   Laptop ASUS ExpertBook B1502CVA-BQ0095X 15.6" ...  2 799\n00\nzł
# 6   Laptop PREDATOR Helios Neo PHN16-71 16" IPS 16...  6 999\n99\nzł
# 7   Laptop APPLE MacBook Air 13.6" Retina M2 8GB R...  4 199\n00\nzł
# 8   Laptop ACER Swift Go 14 SFG14-63-R19Q 14" OLED...  3 499\n00\nzł
# 9   Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4 999\n98\nzł
# 10  Laptop ACER Nitro AN16-41-R7U0 16" IPS 165Hz R...  6 699\n00\nzł
# 11  Laptop LENOVO Yoga Slim 6 14IRH8 14" OLED i5-1...  3 499\n00\nzł
# 12  Laptop ASUS TUF Gaming A15 FA507NV-TT903W 15.6...  4 999\n00\nzł
# 13  Laptop LENOVO Legion Slim 5 16IRH8 16" IPS 240...  5 999\n99\nzł
# 14  Laptop DELL G15 5530-6916 i7-13650HX 16GB RAM ...  5 999\n98\nzł
# 15  Laptop LENOVO Legion 5 15ARH7H 15.6" IPS 165Hz...  5 479\n00\nzł
# 16  Laptop ACER Nitro V 15 ANV15-51-53W4 15.6" IPS...  4 299\n99\nzł
# 17  Laptop HP Pavilion 15-EH3333NW 15.6" IPS R5-75...  2 799\n99\nzł
# 18  Laptop LENOVO Yoga Slim 7 15ILL9 Aura Edition ...  6 399\n99\nzł
# 19  Laptop ACER Nitro V 16 ANV16-41 16" IPS 165Hz ...  4 299\n00\nzł
# 20  Laptop ASUS VivoBook M1502YA-BQ059W 15.6" IPS ...  1 899\n99\nzł
# 21  Laptop LENOVO Legion Slim 5 16AHP9 16" IPS 240...  7 979\n00\nzł
# 22  Laptop ACER Swift 14 AI SF14-11 Copilot+ PC 14...  4 499\n00\nzł
# 23  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2 998\n99\nzł
# 24  Laptop ACER Nitro 5 AN515-58 15.6" IPS 144Hz i...  3 389\n99\nzł
# 25  Laptop LENOVO Yoga Book 9 13IRU8 13.3" OLED i7...  8 979\n00\nzł
# 26  Laptop ACER Nitro V 15 ANV15-41 15.6" IPS 144H...  2 999\n99\nzł
# 27  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  3 999\n00\nzł
# 28  Laptop HP Envy x360 15-FH0333NW 15.6" IPS R5-7...  3 999\n98\nzł
# 29  Laptop LENOVO IdeaPad Slim 3 Chrome 14M868 14"...    999\n00\nzł
#
#                                 Procesor:                    RAM:  \
# 0                   Intel Core i5-12450HX     24GB, DDR5, 4800MHz
# 1                                Apple M4                    16GB
# 2                       AMD Ryzen 7 7730U              16GB, DDR4
# 3                    Intel Core i5-13420H              16GB, DDR5
# 4                      AMD Ryzen 7 7435HS     16GB, DDR5, 4800MHz
# 5                     Intel Core i5-1335U              16GB, DDR4
# 6                   Intel Core i9-13900HX     16GB, DDR5, 5600MHz
# 7                                Apple M2                     8GB
# 8                      AMD Ryzen 5 8645HS           16GB, LPDDR5X
# 9                 Intel Core Ultra 7-155H  16GB, LPDDR5X, 7467MHz
# 10                     AMD Ryzen 7 7735HS              16GB, DDR5
# 11                   Intel Core i5-13500H  16GB, LPDDR5X, 5200MHz
# 12                     AMD Ryzen 7 7735HS     16GB, DDR5, 4800MHz
# 13                   Intel Core i5-13500H     16GB, DDR5, 5200MHz
# 14                  Intel Core i7-13650HX     16GB, DDR5, 4800MHz
# 15                      AMD Ryzen 7 6800H     16GB, DDR5, 4800MHz
# 16                   Intel Core i5-13420H              16GB, DDR5
# 17                      AMD Ryzen 5 7530U     16GB, DDR4, 3200MHz
# 18                Intel Core Ultra 7-258V  32GB, LPDDR5X, 8533MHz
# 19                     AMD Ryzen 5 8645HS     16GB, DDR5, 5600MHz
# 20                      AMD Ryzen 5 7530U               8GB, DDR4
# 21                     AMD Ryzen 7 8845HS     32GB, DDR5, 5600MHz
# 22  Qualcomm Snapdragon X Plus X1P-64-100           16GB, LPDDR5X
# 23                      AMD Ryzen 7 7730U     16GB, DDR4, 3200MHz
# 24                   Intel Core i5-12450H              16GB, DDR4
# 25                    Intel Core i7-1355U  16GB, LPDDR5X, 6400MHz
# 26                     AMD Ryzen 5 7535HS              16GB, DDR5
# 27                     AMD Ryzen 7 7435HS     24GB, DDR5, 4800MHz
# 28                      AMD Ryzen 5 7530U  16GB, LPDDR4X, 4266MHz
# 29                  MediaTek Kompanio 520   8GB, LPDDR4X, 3600MHz
#
#                   Dysk SSD:                                  Karta graficzna:  \
# 0    512GB PCIe NVMe 4.0 x4      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 1                     512GB                              Apple M4 (10 rdzeni)
# 2    512GB PCIe NVMe 4.0 x4                               AMD Radeon Graphics
# 3           512GB PCIe NVMe      NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 4   1000GB PCIe NVMe 4.0 x4                           NVIDIA GeForce RTX 4050
# 5    512GB PCIe NVMe 4.0 x4                                Intel UHD Graphics
# 6          1000GB PCIe NVMe      NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 7                     256GB                               Apple M2 (8 rdzeni)
# 8           512GB PCIe NVMe                                   AMD Radeon 760M
# 9    512GB PCIe NVMe 4.0 x4                                Intel Arc Graphics
# 10         1000GB PCIe NVMe         NVIDIA GeForce RTX 4070 + AMD Radeon 680M
# 11   512GB PCIe NVMe 4.0 x4                                Intel UHD Graphics
# 12     1000GB PCIe NVMe 4.0         NVIDIA GeForce RTX 4060 + AMD Radeon 680M
# 13   512GB PCIe NVMe 4.0 x4  NVIDIA GeForce RTX 4060 + Intel Iris Xe Graphics
# 14          512GB PCIe NVMe      NVIDIA GeForce RTX 4060 + Intel UHD Graphics
# 15   512GB PCIe NVMe 4.0 x4         NVIDIA GeForce RTX 3070 + AMD Radeon 680M
# 16          512GB PCIe NVMe      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 17         1000GB PCIe NVMe                               AMD Radeon Graphics
# 18   512GB PCIe NVMe 4.0 x4                           Intel Arc Graphics 140V
# 19      512GB PCIe NVMe 4.0         NVIDIA GeForce RTX 4050 + AMD Radeon 760M
# 20   512GB PCIe NVMe 3.0 x4                               AMD Radeon Graphics
# 21   512GB PCIe NVMe 4.0 x4         NVIDIA GeForce RTX 4070 + AMD Radeon 780M
# 22     1000GB PCIe NVMe 4.0                                   Qualcomm Adreno
# 23   512GB PCIe NVMe 4.0 x4                               AMD Radeon Graphics
# 24          512GB PCIe NVMe      NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 25  1000GB PCIe NVMe 4.0 x4                            Intel Iris Xe Graphics
# 26          512GB PCIe NVMe         NVIDIA GeForce RTX 2050 + AMD Radeon 660M
# 27   512GB PCIe NVMe 4.0 x4                           NVIDIA GeForce RTX 4050
# 28          512GB PCIe NVMe                               AMD Radeon Graphics
# 29               128GB eMMC                              ARM Mali-G52 2EE MC2
#
#                                                Ekran:       System operacyjny:
# 0            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 1   14.2", 3024 x 1964px, Matryca Liquid Retina XD...            macOS Sequoia
# 2          16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 3            15.6", 1920 x 1080px, Matryca IPS, 144Hz                     Brak
# 4            15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 5                     15.6", 1920 x 1080px, LED, 60Hz  Windows 11 Professional
# 6         16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 7   13.6", 2560 x 1664px, Matryca Liquid Retina,Ma...           macOS Monterey
# 8                                  14", 2880 x 1800px          Windows 11 Home
# 9                            14", 1920 x 1200px, 60Hz          Windows 11 Home
# 10        16", 2560 x 1600px, Matryca IPS, LED, 165Hz          Windows 11 Home
# 11                           14", 1920 x 1200px, 60Hz          Windows 11 Home
# 12           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 13        16", 2560 x 1600px, Matryca IPS, LED, 240Hz          Windows 11 Home
# 14      15.6", 1920 x 1080px, Matryca WVA, LED, 165Hz          Windows 11 Home
# 15           15.6", 2560 x 1440px, Matryca IPS, 165Hz                     Brak
# 16      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 17                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 18           15.3", 2880 x 1800px, Matryca IPS, 120Hz          Windows 11 Home
# 19             16", 1920 x 1200px, Matryca IPS, 165Hz          Windows 11 Home
# 20       15.6", 1920 x 1080px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 21             16", 2560 x 1600px, Matryca IPS, 240Hz          Windows 11 Home
# 22           14.5", 2560 x 1600px, Matryca IPS, 120Hz          Windows 11 Home
# 23         16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 24      15.6", 1920 x 1080px, Matryca IPS, LED, 144Hz          Windows 11 Home
# 25                         13.3", 2880 x 1800px, 60Hz          Windows 11 Home
# 26           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 27           15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 28                  15.6", 1920 x 1080px, Matryca IPS          Windows 11 Home
# 29                     14", 1920 x 1080px, Matryca TN                Chrome OS

# %%
df['Cena'] = df['Cena'].str.replace('\n', '').str.replace(' zł', '').str.replace('n', '').astype(float)


df = df.dropna() 
df['RAM'] = df['RAM'].str.extract('(\d+)').astype(int)  # Wyciągnięcie liczby GB z tekstu
df['Dysk SSD'] = df['Dysk SSD'].str.replace('GB', '').str.replace('TB', '000').astype(int)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df['Cena'] = df['Cena'].str.replace('\n', '').str.replace(' zł', '').str.replace('n', '').astype(float)
#       4 df = df.dropna()
#       5 df['RAM'] = df['RAM'].str.extract('(\d+)').astype(int)  # Wyciągnięcie liczby GB z tekstu
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '3\u202f69900zł'
