# %%
import pandas as pd
import numpy as np

df = pd.read_csv('produkty_rtv_agd_full.csv')
df
# Out:
#                                                   Tytuł    Cena  \
# 0     Laptop ASUS VivoBook 15 A1504ZA-BQ739W 15,6" i...   2 199
# 1     Laptop gamingowy Acer Nitro V 15 ANV15-51 15,6...   2 899
# 2     Laptop Lenovo IdeaPad Slim 5 16IAH8 16" i5-124...   2 699
# 3     Laptop HP Pavilion 16-ag0019nw 16" R7 8840U 16...   2 999
# 4     Laptop Acer Aspire 3 14 A314-23P-R20G 14" R3 7...   1 299
# ...                                                 ...     ...
# 1423  Laptop gamingowy ASUS ROG Strix Scar 18 2024 G...  14 175
# 1424  Laptop biznesowy Dell XPS 14 9440-7715 14,5" 1...  13 500
# 1425  Laptop gamingowy MSI Raider GE78 HX 14VHG-626P...  12 600
# 1426  Laptop gamingowy MSI Katana 15 B13VGK-1436XPL ...   6 930
# 1427  Laptop gamingowy MSI Katana GF66 12UE-1206PL 1...   6 120
#
#                                                    Link  \
# 0     https://www.euro.com.pl/laptopy-i-netbooki/asu...
# 1     https://www.euro.com.pl/laptopy-i-netbooki/ace...
# 2     https://www.euro.com.pl/laptopy-i-netbooki/len...
# 3     https://www.euro.com.pl/laptopy-i-netbooki/hp-...
# 4     https://www.euro.com.pl/laptopy-i-netbooki/ace...
# ...                                                 ...
# 1423  https://www.euro.com.pl/laptopy-i-netbooki/asu...
# 1424  https://www.euro.com.pl/laptopy-i-netbooki/del...
# 1425  https://www.euro.com.pl/laptopy-i-netbooki/msi...
# 1426  https://www.euro.com.pl/laptopy-i-netbooki/msi...
# 1427  https://www.euro.com.pl/laptopy-i-netbooki/msi...
#
#                                                  Ekran:  \
# 0                     15,6 ", 1920 x 1080 pikseli 60 Hz
# 1                    15,6 ", 1920 x 1080 pikseli 144 Hz
# 2                       16 ", 1920 x 1200 pikseli 60 Hz
# 3                       16 ", 1920 x 1200 pikseli 60 Hz
# 4                       14 ", 1920 x 1080 pikseli 60 Hz
# ...                                                 ...
# 1423                   18 ", 2560 x 1600 pikseli 240 Hz
# 1424  14,5 ", ekran dotykowy 3200 x 2000 pikseli 120 Hz
# 1425                   17 ", 2560 x 1600 pikseli 240 Hz
# 1426                 15,6 ", 1920 x 1080 pikseli 144 Hz
# 1427                 15,6 ", 1920 x 1080 pikseli 144 Hz
#
#                             Procesor:                     Pamięć:  \
# 0         Intel® Core™ i5 12gen 1235U              16 GB DDR4 RAM
# 1        Intel® Core™ i5 13gen 13420H              16 GB DDR5 RAM
# 2        Intel® Core™ i5 12gen 12450H   16 GB LPDDR5 4800 Mhz RAM
# 3                  AMD Ryzen™ 7 8840U     16 GB DDR5 6400 Mhz RAM
# 4                  AMD Ryzen™ 3 7320U             8 GB LPDDR5 RAM
# ...                               ...                         ...
# 1423    Intel® Core™ i9 14gen 14900HX     32 GB DDR5 5600 Mhz RAM
# 1424  Intel® Core™ Ultra 7 14gen 155H  32 GB LPDDR5x 7467 Mhz RAM
# 1425    Intel® Core™ i9 14gen 14900HX     32 GB DDR5 5600 Mhz RAM
# 1426     Intel® Core™ i9 13gen 13900H     16 GB DDR5 5200 Mhz RAM
# 1427     Intel® Core™ i7 12gen 12650H     16 GB DDR4 3200 MHz RAM
#
#                                                Grafika:       Dysk:  \
# 0                               Intel® Iris Xe Graphics  512 GB SSD
# 1        NVIDIA® GeForce RTX™ 2050 + Intel UHD Graphics  512 GB SSD
# 2                                   Intel® UHD Graphics  512 GB SSD
# 3                                      AMD Radeon™ 780M  512 GB SSD
# 4                              AMD Radeon™ 610 Graphics  512 GB SSD
# ...                                                 ...         ...
# 1423     NVIDIA® Geforce RTX™ 4090 + Intel UHD Graphics    2 TB SSD
# 1424      NVIDIA® GeForce RTX 4050 + Intel Arc Graphics    1 TB SSD
# 1425     NVIDIA® GeForce RTX™ 4080 + Intel UHD Graphics    2 TB SSD
# 1426  NVIDIA® GeForce RTX™ 4070 + Intel Iris Xe Grap...    1 TB SSD
# 1427     NVIDIA® GeForce RTX™ 3060 + Intel UHD Graphics  512 GB SSD
#
#            System operacyjny:
# 0     Windows 11 Home Edition
# 1     Windows 11 Home Edition
# 2     Windows 11 Home Edition
# 3     Windows 11 Home Edition
# 4     Windows 11 Home Edition
# ...                       ...
# 1423  Windows 11 Professional
# 1424  Windows 11 Professional
# 1425  Windows 11 Home Edition
# 1426              bez systemu
# 1427  Windows 11 Home Edition
#
# [1428 rows x 9 columns]

# %%
df['Cena'] = (
    df['Cena']
    .str.replace('\n', '', regex=True)
    .str.replace('zł', '', regex=False)
    .str.replace('\u202f', '', regex=False)
    .str.replace(' ', '', regex=False)
    .astype(int)
)

df
# Out:
#                                                   Tytuł   Cena  \
# 0     Laptop ASUS VivoBook 15 A1504ZA-BQ739W 15,6" i...   2199
# 1     Laptop gamingowy Acer Nitro V 15 ANV15-51 15,6...   2899
# 2     Laptop Lenovo IdeaPad Slim 5 16IAH8 16" i5-124...   2699
# 3     Laptop HP Pavilion 16-ag0019nw 16" R7 8840U 16...   2999
# 4     Laptop Acer Aspire 3 14 A314-23P-R20G 14" R3 7...   1299
# ...                                                 ...    ...
# 1423  Laptop gamingowy ASUS ROG Strix Scar 18 2024 G...  14175
# 1424  Laptop biznesowy Dell XPS 14 9440-7715 14,5" 1...  13500
# 1425  Laptop gamingowy MSI Raider GE78 HX 14VHG-626P...  12600
# 1426  Laptop gamingowy MSI Katana 15 B13VGK-1436XPL ...   6930
# 1427  Laptop gamingowy MSI Katana GF66 12UE-1206PL 1...   6120
#
#                                                    Link  \
# 0     https://www.euro.com.pl/laptopy-i-netbooki/asu...
# 1     https://www.euro.com.pl/laptopy-i-netbooki/ace...
# 2     https://www.euro.com.pl/laptopy-i-netbooki/len...
# 3     https://www.euro.com.pl/laptopy-i-netbooki/hp-...
# 4     https://www.euro.com.pl/laptopy-i-netbooki/ace...
# ...                                                 ...
# 1423  https://www.euro.com.pl/laptopy-i-netbooki/asu...
# 1424  https://www.euro.com.pl/laptopy-i-netbooki/del...
# 1425  https://www.euro.com.pl/laptopy-i-netbooki/msi...
# 1426  https://www.euro.com.pl/laptopy-i-netbooki/msi...
# 1427  https://www.euro.com.pl/laptopy-i-netbooki/msi...
#
#                                                  Ekran:  \
# 0                     15,6 ", 1920 x 1080 pikseli 60 Hz
# 1                    15,6 ", 1920 x 1080 pikseli 144 Hz
# 2                       16 ", 1920 x 1200 pikseli 60 Hz
# 3                       16 ", 1920 x 1200 pikseli 60 Hz
# 4                       14 ", 1920 x 1080 pikseli 60 Hz
# ...                                                 ...
# 1423                   18 ", 2560 x 1600 pikseli 240 Hz
# 1424  14,5 ", ekran dotykowy 3200 x 2000 pikseli 120 Hz
# 1425                   17 ", 2560 x 1600 pikseli 240 Hz
# 1426                 15,6 ", 1920 x 1080 pikseli 144 Hz
# 1427                 15,6 ", 1920 x 1080 pikseli 144 Hz
#
#                             Procesor:                     Pamięć:  \
# 0         Intel® Core™ i5 12gen 1235U              16 GB DDR4 RAM
# 1        Intel® Core™ i5 13gen 13420H              16 GB DDR5 RAM
# 2        Intel® Core™ i5 12gen 12450H   16 GB LPDDR5 4800 Mhz RAM
# 3                  AMD Ryzen™ 7 8840U     16 GB DDR5 6400 Mhz RAM
# 4                  AMD Ryzen™ 3 7320U             8 GB LPDDR5 RAM
# ...                               ...                         ...
# 1423    Intel® Core™ i9 14gen 14900HX     32 GB DDR5 5600 Mhz RAM
# 1424  Intel® Core™ Ultra 7 14gen 155H  32 GB LPDDR5x 7467 Mhz RAM
# 1425    Intel® Core™ i9 14gen 14900HX     32 GB DDR5 5600 Mhz RAM
# 1426     Intel® Core™ i9 13gen 13900H     16 GB DDR5 5200 Mhz RAM
# 1427     Intel® Core™ i7 12gen 12650H     16 GB DDR4 3200 MHz RAM
#
#                                                Grafika:       Dysk:  \
# 0                               Intel® Iris Xe Graphics  512 GB SSD
# 1        NVIDIA® GeForce RTX™ 2050 + Intel UHD Graphics  512 GB SSD
# 2                                   Intel® UHD Graphics  512 GB SSD
# 3                                      AMD Radeon™ 780M  512 GB SSD
# 4                              AMD Radeon™ 610 Graphics  512 GB SSD
# ...                                                 ...         ...
# 1423     NVIDIA® Geforce RTX™ 4090 + Intel UHD Graphics    2 TB SSD
# 1424      NVIDIA® GeForce RTX 4050 + Intel Arc Graphics    1 TB SSD
# 1425     NVIDIA® GeForce RTX™ 4080 + Intel UHD Graphics    2 TB SSD
# 1426  NVIDIA® GeForce RTX™ 4070 + Intel Iris Xe Grap...    1 TB SSD
# 1427     NVIDIA® GeForce RTX™ 3060 + Intel UHD Graphics  512 GB SSD
#
#            System operacyjny:
# 0     Windows 11 Home Edition
# 1     Windows 11 Home Edition
# 2     Windows 11 Home Edition
# 3     Windows 11 Home Edition
# 4     Windows 11 Home Edition
# ...                       ...
# 1423  Windows 11 Professional
# 1424  Windows 11 Professional
# 1425  Windows 11 Home Edition
# 1426              bez systemu
# 1427  Windows 11 Home Edition
#
# [1428 rows x 9 columns]

# %%
df.rename(columns={'Pamięć:': 'RAM'}, inplace=True)
df['RAM'] = df['RAM'].str.extract(r'(\d+)\s*GB')[0].astype(int)

# %%
df.rename(columns={'Dysk:': 'Dysk SSD'}, inplace=True)

df[['Dysk_Wartosc', 'Dysk_Jednostka']] = df['Dysk SSD'].str.extract(r'(\d+)\s+(GB|TB)', expand=True)

df['Dysk_Wartosc'] = df['Dysk_Wartosc'].astype(int)
df['Dysk SSD'] = df.apply(
    lambda row: row['Dysk_Wartosc'] * 1024 if row['Dysk_Jednostka'] == 'TB' else row['Dysk_Wartosc'],
    axis=1
)

df = df.drop(columns=['Dysk_Wartosc', 'Dysk_Jednostka'])

df.head()
# Out:
#                                                Tytuł  Cena  \
# 0  Laptop ASUS VivoBook 15 A1504ZA-BQ739W 15,6" i...  2199
# 1  Laptop gamingowy Acer Nitro V 15 ANV15-51 15,6...  2899
# 2  Laptop Lenovo IdeaPad Slim 5 16IAH8 16" i5-124...  2699
# 3  Laptop HP Pavilion 16-ag0019nw 16" R7 8840U 16...  2999
# 4  Laptop Acer Aspire 3 14 A314-23P-R20G 14" R3 7...  1299
#
#                                                 Link  \
# 0  https://www.euro.com.pl/laptopy-i-netbooki/asu...
# 1  https://www.euro.com.pl/laptopy-i-netbooki/ace...
# 2  https://www.euro.com.pl/laptopy-i-netbooki/len...
# 3  https://www.euro.com.pl/laptopy-i-netbooki/hp-...
# 4  https://www.euro.com.pl/laptopy-i-netbooki/ace...
#
#                                Ekran:                     Procesor:  RAM  \
# 0   15,6 ", 1920 x 1080 pikseli 60 Hz   Intel® Core™ i5 12gen 1235U   16
# 1  15,6 ", 1920 x 1080 pikseli 144 Hz  Intel® Core™ i5 13gen 13420H   16
# 2     16 ", 1920 x 1200 pikseli 60 Hz  Intel® Core™ i5 12gen 12450H   16
# 3     16 ", 1920 x 1200 pikseli 60 Hz            AMD Ryzen™ 7 8840U   16
# 4     14 ", 1920 x 1080 pikseli 60 Hz            AMD Ryzen™ 3 7320U    8
#
#                                          Grafika:  Dysk SSD  \
# 0                         Intel® Iris Xe Graphics       512
# 1  NVIDIA® GeForce RTX™ 2050 + Intel UHD Graphics       512
# 2                             Intel® UHD Graphics       512
# 3                                AMD Radeon™ 780M       512
# 4                        AMD Radeon™ 610 Graphics       512
#
#         System operacyjny:
# 0  Windows 11 Home Edition
# 1  Windows 11 Home Edition
# 2  Windows 11 Home Edition
# 3  Windows 11 Home Edition
# 4  Windows 11 Home Edition

# %%
df
# Out:
#                                                   Tytuł   Cena  \
# 0     Laptop ASUS VivoBook 15 A1504ZA-BQ739W 15,6" i...   2199
# 1     Laptop gamingowy Acer Nitro V 15 ANV15-51 15,6...   2899
# 2     Laptop Lenovo IdeaPad Slim 5 16IAH8 16" i5-124...   2699
# 3     Laptop HP Pavilion 16-ag0019nw 16" R7 8840U 16...   2999
# 4     Laptop Acer Aspire 3 14 A314-23P-R20G 14" R3 7...   1299
# ...                                                 ...    ...
# 1423  Laptop gamingowy ASUS ROG Strix Scar 18 2024 G...  14175
# 1424  Laptop biznesowy Dell XPS 14 9440-7715 14,5" 1...  13500
# 1425  Laptop gamingowy MSI Raider GE78 HX 14VHG-626P...  12600
# 1426  Laptop gamingowy MSI Katana 15 B13VGK-1436XPL ...   6930
# 1427  Laptop gamingowy MSI Katana GF66 12UE-1206PL 1...   6120
#
#                                                    Link  \
# 0     https://www.euro.com.pl/laptopy-i-netbooki/asu...
# 1     https://www.euro.com.pl/laptopy-i-netbooki/ace...
# 2     https://www.euro.com.pl/laptopy-i-netbooki/len...
# 3     https://www.euro.com.pl/laptopy-i-netbooki/hp-...
# 4     https://www.euro.com.pl/laptopy-i-netbooki/ace...
# ...                                                 ...
# 1423  https://www.euro.com.pl/laptopy-i-netbooki/asu...
# 1424  https://www.euro.com.pl/laptopy-i-netbooki/del...
# 1425  https://www.euro.com.pl/laptopy-i-netbooki/msi...
# 1426  https://www.euro.com.pl/laptopy-i-netbooki/msi...
# 1427  https://www.euro.com.pl/laptopy-i-netbooki/msi...
#
#                                                  Ekran:  \
# 0                     15,6 ", 1920 x 1080 pikseli 60 Hz
# 1                    15,6 ", 1920 x 1080 pikseli 144 Hz
# 2                       16 ", 1920 x 1200 pikseli 60 Hz
# 3                       16 ", 1920 x 1200 pikseli 60 Hz
# 4                       14 ", 1920 x 1080 pikseli 60 Hz
# ...                                                 ...
# 1423                   18 ", 2560 x 1600 pikseli 240 Hz
# 1424  14,5 ", ekran dotykowy 3200 x 2000 pikseli 120 Hz
# 1425                   17 ", 2560 x 1600 pikseli 240 Hz
# 1426                 15,6 ", 1920 x 1080 pikseli 144 Hz
# 1427                 15,6 ", 1920 x 1080 pikseli 144 Hz
#
#                             Procesor:  RAM  \
# 0         Intel® Core™ i5 12gen 1235U   16
# 1        Intel® Core™ i5 13gen 13420H   16
# 2        Intel® Core™ i5 12gen 12450H   16
# 3                  AMD Ryzen™ 7 8840U   16
# 4                  AMD Ryzen™ 3 7320U    8
# ...                               ...  ...
# 1423    Intel® Core™ i9 14gen 14900HX   32
# 1424  Intel® Core™ Ultra 7 14gen 155H   32
# 1425    Intel® Core™ i9 14gen 14900HX   32
# 1426     Intel® Core™ i9 13gen 13900H   16
# 1427     Intel® Core™ i7 12gen 12650H   16
#
#                                                Grafika:  Dysk SSD  \
# 0                               Intel® Iris Xe Graphics       512
# 1        NVIDIA® GeForce RTX™ 2050 + Intel UHD Graphics       512
# 2                                   Intel® UHD Graphics       512
# 3                                      AMD Radeon™ 780M       512
# 4                              AMD Radeon™ 610 Graphics       512
# ...                                                 ...       ...
# 1423     NVIDIA® Geforce RTX™ 4090 + Intel UHD Graphics      2048
# 1424      NVIDIA® GeForce RTX 4050 + Intel Arc Graphics      1024
# 1425     NVIDIA® GeForce RTX™ 4080 + Intel UHD Graphics      2048
# 1426  NVIDIA® GeForce RTX™ 4070 + Intel Iris Xe Grap...      1024
# 1427     NVIDIA® GeForce RTX™ 3060 + Intel UHD Graphics       512
#
#            System operacyjny:
# 0     Windows 11 Home Edition
# 1     Windows 11 Home Edition
# 2     Windows 11 Home Edition
# 3     Windows 11 Home Edition
# 4     Windows 11 Home Edition
# ...                       ...
# 1423  Windows 11 Professional
# 1424  Windows 11 Professional
# 1425  Windows 11 Home Edition
# 1426              bez systemu
# 1427  Windows 11 Home Edition
#
# [1428 rows x 9 columns]

# %%
df = df.rename(columns={'System operacyjny:': 'System operacyjny'})
df['System operacyjny'].value_counts()
# Out:
# System operacyjny
# Windows 11 Home Edition                                                    634
# Windows 11 Professional                                                    341
# bez systemu                                                                154
# Windows 10 Home Edition                                                     86
# macOS Sonoma lub nowszy                                                     48
# macOS Monterey lub nowszy                                                   36
# macOS Ventura lub nowszy                                                    27
# macOS Sequoia lub nowszy                                                    23
# Chrome OS                                                                   22
# macOS Big Sur lub nowszy                                                    17
# Windows 11 S                                                                16
# Windows 10 Professional                                                     12
# Windows 10 Home Edition (możliwość darmowej aktualizacji do Windows 11)      6
# Windows 10 S                                                                 6
# Name: count, dtype: int64

# %%
def wyodrebnij_system(tytul):
    tytul = tytul.lower()
    if 'macos' in tytul:
        return 'macOS Sonoma'
    elif 'windows 11 home' in tytul or 'windows 11 s' in tytul:
        return 'Windows 11 Home'
    elif 'windows 11 professional' in tytul:
        return 'Windows 11 Professional'
    elif 'windows 10' in tytul:
        return 'Windows 10'
    elif 'chrome os' in tytul or 'chromebook' in tytul:
        return 'Chrome OS'
    elif 'freedos' in tytul:
        return 'FreeDOS'
    else:
        return 'Brak'

df['System operacyjny'] = df['System operacyjny'].apply(wyodrebnij_system)

# %%
df['System operacyjny'].value_counts()
# Out:
# System operacyjny
# Windows 11 Home            650
# Windows 11 Professional    341
# Brak                       154
# macOS Sonoma               151
# Windows 10                 110
# Chrome OS                   22
# Name: count, dtype: int64

# %%
df = df.drop(columns=['Link'])

# %%
df
# Out:
#                                                   Tytuł   Cena  \
# 0     Laptop ASUS VivoBook 15 A1504ZA-BQ739W 15,6" i...   2199
# 1     Laptop gamingowy Acer Nitro V 15 ANV15-51 15,6...   2899
# 2     Laptop Lenovo IdeaPad Slim 5 16IAH8 16" i5-124...   2699
# 3     Laptop HP Pavilion 16-ag0019nw 16" R7 8840U 16...   2999
# 4     Laptop Acer Aspire 3 14 A314-23P-R20G 14" R3 7...   1299
# ...                                                 ...    ...
# 1423  Laptop gamingowy ASUS ROG Strix Scar 18 2024 G...  14175
# 1424  Laptop biznesowy Dell XPS 14 9440-7715 14,5" 1...  13500
# 1425  Laptop gamingowy MSI Raider GE78 HX 14VHG-626P...  12600
# 1426  Laptop gamingowy MSI Katana 15 B13VGK-1436XPL ...   6930
# 1427  Laptop gamingowy MSI Katana GF66 12UE-1206PL 1...   6120
#
#                                                  Ekran:  \
# 0                     15,6 ", 1920 x 1080 pikseli 60 Hz
# 1                    15,6 ", 1920 x 1080 pikseli 144 Hz
# 2                       16 ", 1920 x 1200 pikseli 60 Hz
# 3                       16 ", 1920 x 1200 pikseli 60 Hz
# 4                       14 ", 1920 x 1080 pikseli 60 Hz
# ...                                                 ...
# 1423                   18 ", 2560 x 1600 pikseli 240 Hz
# 1424  14,5 ", ekran dotykowy 3200 x 2000 pikseli 120 Hz
# 1425                   17 ", 2560 x 1600 pikseli 240 Hz
# 1426                 15,6 ", 1920 x 1080 pikseli 144 Hz
# 1427                 15,6 ", 1920 x 1080 pikseli 144 Hz
#
#                             Procesor:  RAM  \
# 0         Intel® Core™ i5 12gen 1235U   16
# 1        Intel® Core™ i5 13gen 13420H   16
# 2        Intel® Core™ i5 12gen 12450H   16
# 3                  AMD Ryzen™ 7 8840U   16
# 4                  AMD Ryzen™ 3 7320U    8
# ...                               ...  ...
# 1423    Intel® Core™ i9 14gen 14900HX   32
# 1424  Intel® Core™ Ultra 7 14gen 155H   32
# 1425    Intel® Core™ i9 14gen 14900HX   32
# 1426     Intel® Core™ i9 13gen 13900H   16
# 1427     Intel® Core™ i7 12gen 12650H   16
#
#                                                Grafika:  Dysk SSD  \
# 0                               Intel® Iris Xe Graphics       512
# 1        NVIDIA® GeForce RTX™ 2050 + Intel UHD Graphics       512
# 2                                   Intel® UHD Graphics       512
# 3                                      AMD Radeon™ 780M       512
# 4                              AMD Radeon™ 610 Graphics       512
# ...                                                 ...       ...
# 1423     NVIDIA® Geforce RTX™ 4090 + Intel UHD Graphics      2048
# 1424      NVIDIA® GeForce RTX 4050 + Intel Arc Graphics      1024
# 1425     NVIDIA® GeForce RTX™ 4080 + Intel UHD Graphics      2048
# 1426  NVIDIA® GeForce RTX™ 4070 + Intel Iris Xe Grap...      1024
# 1427     NVIDIA® GeForce RTX™ 3060 + Intel UHD Graphics       512
#
#             System operacyjny
# 0             Windows 11 Home
# 1             Windows 11 Home
# 2             Windows 11 Home
# 3             Windows 11 Home
# 4             Windows 11 Home
# ...                       ...
# 1423  Windows 11 Professional
# 1424  Windows 11 Professional
# 1425          Windows 11 Home
# 1426                     Brak
# 1427          Windows 11 Home
#
# [1428 rows x 8 columns]

# %%
df.rename(columns={'Procesor:': 'Procesor'}, inplace=True)
def extract_processor_brand(processor_name):
    if pd.isna(processor_name):
        return 'Brak'
    processor_name = processor_name.lower()
    if 'intel' in processor_name:
        return 'Intel'
    elif 'amd' in processor_name:
        return 'AMD'
    elif 'apple' in processor_name:
        return 'Apple'
    elif 'mediatek' in processor_name:
        return 'MediaTek'
    elif 'qualcomm' in processor_name:
        return 'Qualcomm'
    else:
        return 'Inne'

df['Firma procesora'] = df['Procesor'].apply(extract_processor_brand)

df.head()
# Out:
#                                                Tytuł  Cena  \
# 0  Laptop ASUS VivoBook 15 A1504ZA-BQ739W 15,6" i...  2199
# 1  Laptop gamingowy Acer Nitro V 15 ANV15-51 15,6...  2899
# 2  Laptop Lenovo IdeaPad Slim 5 16IAH8 16" i5-124...  2699
# 3  Laptop HP Pavilion 16-ag0019nw 16" R7 8840U 16...  2999
# 4  Laptop Acer Aspire 3 14 A314-23P-R20G 14" R3 7...  1299
#
#                                Ekran:                      Procesor  RAM  \
# 0   15,6 ", 1920 x 1080 pikseli 60 Hz   Intel® Core™ i5 12gen 1235U   16
# 1  15,6 ", 1920 x 1080 pikseli 144 Hz  Intel® Core™ i5 13gen 13420H   16
# 2     16 ", 1920 x 1200 pikseli 60 Hz  Intel® Core™ i5 12gen 12450H   16
# 3     16 ", 1920 x 1200 pikseli 60 Hz            AMD Ryzen™ 7 8840U   16
# 4     14 ", 1920 x 1080 pikseli 60 Hz            AMD Ryzen™ 3 7320U    8
#
#                                          Grafika:  Dysk SSD System operacyjny  \
# 0                         Intel® Iris Xe Graphics       512   Windows 11 Home
# 1  NVIDIA® GeForce RTX™ 2050 + Intel UHD Graphics       512   Windows 11 Home
# 2                             Intel® UHD Graphics       512   Windows 11 Home
# 3                                AMD Radeon™ 780M       512   Windows 11 Home
# 4                        AMD Radeon™ 610 Graphics       512   Windows 11 Home
#
#   Firma procesora
# 0           Intel
# 1           Intel
# 2           Intel
# 3             AMD
# 4             AMD

# %%
df['Firma procesora'].value_counts()
# Out:
# Firma procesora
# Intel       884
# AMD         368
# Apple       151
# Qualcomm     20
# MediaTek      3
# Inne          2
# Name: count, dtype: int64

# %%
df.to_csv('produkty_rtv_agd_szczegoly_full_cleaned.csv', index=False, encoding='utf-8')

# %%
df
# Out:
#                                                   Tytuł   Cena  \
# 0     Laptop ASUS VivoBook 15 A1504ZA-BQ739W 15,6" i...   2199
# 1     Laptop gamingowy Acer Nitro V 15 ANV15-51 15,6...   2899
# 2     Laptop Lenovo IdeaPad Slim 5 16IAH8 16" i5-124...   2699
# 3     Laptop HP Pavilion 16-ag0019nw 16" R7 8840U 16...   2999
# 4     Laptop Acer Aspire 3 14 A314-23P-R20G 14" R3 7...   1299
# ...                                                 ...    ...
# 1423  Laptop gamingowy ASUS ROG Strix Scar 18 2024 G...  14175
# 1424  Laptop biznesowy Dell XPS 14 9440-7715 14,5" 1...  13500
# 1425  Laptop gamingowy MSI Raider GE78 HX 14VHG-626P...  12600
# 1426  Laptop gamingowy MSI Katana 15 B13VGK-1436XPL ...   6930
# 1427  Laptop gamingowy MSI Katana GF66 12UE-1206PL 1...   6120
#
#                                                  Ekran:  \
# 0                     15,6 ", 1920 x 1080 pikseli 60 Hz
# 1                    15,6 ", 1920 x 1080 pikseli 144 Hz
# 2                       16 ", 1920 x 1200 pikseli 60 Hz
# 3                       16 ", 1920 x 1200 pikseli 60 Hz
# 4                       14 ", 1920 x 1080 pikseli 60 Hz
# ...                                                 ...
# 1423                   18 ", 2560 x 1600 pikseli 240 Hz
# 1424  14,5 ", ekran dotykowy 3200 x 2000 pikseli 120 Hz
# 1425                   17 ", 2560 x 1600 pikseli 240 Hz
# 1426                 15,6 ", 1920 x 1080 pikseli 144 Hz
# 1427                 15,6 ", 1920 x 1080 pikseli 144 Hz
#
#                              Procesor  RAM  \
# 0         Intel® Core™ i5 12gen 1235U   16
# 1        Intel® Core™ i5 13gen 13420H   16
# 2        Intel® Core™ i5 12gen 12450H   16
# 3                  AMD Ryzen™ 7 8840U   16
# 4                  AMD Ryzen™ 3 7320U    8
# ...                               ...  ...
# 1423    Intel® Core™ i9 14gen 14900HX   32
# 1424  Intel® Core™ Ultra 7 14gen 155H   32
# 1425    Intel® Core™ i9 14gen 14900HX   32
# 1426     Intel® Core™ i9 13gen 13900H   16
# 1427     Intel® Core™ i7 12gen 12650H   16
#
#                                                Grafika:  Dysk SSD  \
# 0                               Intel® Iris Xe Graphics       512
# 1        NVIDIA® GeForce RTX™ 2050 + Intel UHD Graphics       512
# 2                                   Intel® UHD Graphics       512
# 3                                      AMD Radeon™ 780M       512
# 4                              AMD Radeon™ 610 Graphics       512
# ...                                                 ...       ...
# 1423     NVIDIA® Geforce RTX™ 4090 + Intel UHD Graphics      2048
# 1424      NVIDIA® GeForce RTX 4050 + Intel Arc Graphics      1024
# 1425     NVIDIA® GeForce RTX™ 4080 + Intel UHD Graphics      2048
# 1426  NVIDIA® GeForce RTX™ 4070 + Intel Iris Xe Grap...      1024
# 1427     NVIDIA® GeForce RTX™ 3060 + Intel UHD Graphics       512
#
#             System operacyjny Firma procesora
# 0             Windows 11 Home           Intel
# 1             Windows 11 Home           Intel
# 2             Windows 11 Home           Intel
# 3             Windows 11 Home             AMD
# 4             Windows 11 Home             AMD
# ...                       ...             ...
# 1423  Windows 11 Professional           Intel
# 1424  Windows 11 Professional           Intel
# 1425          Windows 11 Home           Intel
# 1426                     Brak           Intel
# 1427          Windows 11 Home           Intel
#
# [1428 rows x 9 columns]
