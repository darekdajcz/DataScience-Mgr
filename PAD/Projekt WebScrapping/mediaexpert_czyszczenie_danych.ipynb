# %%
import pandas as pd
import numpy as np

df = pd.read_csv('produkty_mediaexpert_szczegoly_full.csv')
df
# Out:
#                                                   Tytuł           Cena  \
# 0     Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2 989\n00\nzł
# 1     Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3 699\n00\nzł
# 2     Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3 399\n00\nzł
# 3     Laptop ACER TravelMate P2 TMP216-51-G2-TCO 16"...  3 399\n00\nzł
# 4     Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4 899\n00\nzł
# ...                                                 ...            ...
# 1726  Laptop ASUS ROG Strix Scar 17 G732LXS-HG047T 1...      Brak ceny
# 1727  Laptop ASUS VivoBook X509JA-BQ241 15.6" i5-103...      Brak ceny
# 1728  Laptop LENOVO Legion 5 15ARH05 15.6" IPS R7-48...      Brak ceny
# 1729  Laptop LENOVO ThinkBook 14 IIL 14" IPS i5-1035...      Brak ceny
# 1730  Laptop APPLE MacBook Pro 2023 16" Retina M3 Pr...      Brak ceny
#
#            Sklep                Procesor:                    RAM:  \
# 0     ediaexpert        AMD Ryzen 7 7730U              16GB, DDR4
# 1     ediaexpert     Intel Core i5-13420H              16GB, DDR5
# 2     ediaexpert    Intel Core i5-12450HX     24GB, DDR5, 4800MHz
# 3     ediaexpert        Intel Core 5 120U              16GB, DDR5
# 4     ediaexpert  Intel Core Ultra 7-155H  16GB, LPDDR5X, 7467MHz
# ...          ...                      ...                     ...
# 1726  ediaexpert     Intel Core i7-10875H     16GB, DDR4, 3200MHz
# 1727  ediaexpert     Intel Core i5-1035G1      8GB, DDR4, 2400MHz
# 1728  ediaexpert        AMD Ryzen 7 4800H     16GB, DDR4, 3200MHz
# 1729  ediaexpert     Intel Core i5-1035G1      8GB, DDR4, 2666MHz
# 1730  ediaexpert             Apple M3 Pro                    18GB
#
#                    Dysk SSD:  \
# 0     512GB PCIe NVMe 4.0 x4
# 1            512GB PCIe NVMe
# 2     512GB PCIe NVMe 4.0 x4
# 3        512GB PCIe NVMe 4.0
# 4     512GB PCIe NVMe 4.0 x4
# ...                      ...
# 1726    1000GB PCIe NVMe 3.0
# 1727         512GB PCIe NVMe
# 1728  512GB PCIe NVMe 3.0 x4
# 1729  256GB PCIe NVMe 3.0 x2
# 1730                  1000GB
#
#                                        Karta graficzna:  \
# 0                                   AMD Radeon Graphics
# 1          NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 2          NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 3                                    Intel UHD Graphics
# 4                                    Intel Arc Graphics
# ...                                                 ...
# 1726  NVIDIA GeForce RTX 2080 Super + Intel Iris Xe ...
# 1727                                 Intel UHD Graphics
# 1728   NVIDIA GeForce GTX 1650 Ti + AMD Radeon Graphics
# 1729                                 Intel UHD Graphics
# 1730                           Apple M3 Pro (18 rdzeni)
#
#                                                  Ekran:  \
# 0            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 1              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 2              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 3            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 4              14", 1920 x 1200px, 60Hz, Ekran dotykowy
# ...                                                 ...
# 1726           17.3", 1920 x 1080px, Matryca IPS, 300Hz
# 1727        15.6", 1920 x 1080px, Matryca TN, LED, 60Hz
# 1728      15.6", 1920 x 1080px, Matryca IPS, LED, 120Hz
# 1729                    14", 1920 x 1080px, Matryca IPS
# 1730  16.2", 3456 x 2234px, Matryca Liquid Retina XD...
#
#                                      System operacyjny: Dysk HDD:
# 0                                       Windows 11 Home       NaN
# 1                                                  Brak       NaN
# 2                                       Windows 11 Home       NaN
# 3                               Windows 11 Professional       NaN
# 4                                       Windows 11 Home       NaN
# ...                                                 ...       ...
# 1726                                    Windows 10 Home       NaN
# 1727                                               Brak       NaN
# 1728                                               Brak       NaN
# 1729  Windows 10 Home (możliwość darmowej aktualizac...       NaN
# 1730                                       macOS Sonoma       NaN
#
# [1731 rows x 10 columns]

# %%
df = df[~df['Cena'].str.contains('Brak ceny', na=False)]
df = df.dropna(subset=['Cena'])

df['Cena'] = (
    df['Cena']
    .str.replace('\n', '', regex=True)
    .str.replace('zł', '', regex=False)
    .str.replace('\u202f', '', regex=False)
    .str.replace('n', '', regex=False)
    .astype(int)
)

df['Cena'] = df.apply(
    lambda row: row['Cena'] /100,
    axis=1
)

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df = df[~df['Cena'].str.contains('Brak ceny', na=False)]
#       2 df = df.dropna(subset=['Cena'])
#       4 df['Cena'] = (
#       5     df['Cena']
#       6     .str.replace('\n', '', regex=True)
#    (...)
#      10     .astype(int)
#      11 )
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df
# Out:
#                                                   Tytuł     Cena       Sklep  \
# 0     Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00  ediaexpert
# 1     Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00  ediaexpert
# 2     Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3399.00  ediaexpert
# 3     Laptop ACER TravelMate P2 TMP216-51-G2-TCO 16"...  3399.00  ediaexpert
# 4     Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4899.00  ediaexpert
# ...                                                 ...      ...         ...
# 1239  Laptop APPLE MacBook Pro 13.3" Retina M1 8GB R...  5389.97  ediaexpert
# 1240  Laptop DELL Inspiron 5400-6643 14" i5-1035G1 8...  2959.97  ediaexpert
# 1241  Laptop LENOVO IdeaPad 3 15ADA05 15.6" R3-3250U...  1199.97  ediaexpert
# 1242  Laptop ACER Extensa EX215-31 15.6" i3-1005G1 8...  1839.97  ediaexpert
# 1243  Laptop LENOVO IdeaPad S540-14API 14" IPS R7-37...  2399.97  ediaexpert
#
#                     Procesor:                    RAM:  \
# 0           AMD Ryzen 7 7730U              16GB, DDR4
# 1        Intel Core i5-13420H              16GB, DDR5
# 2       Intel Core i5-12450HX     24GB, DDR5, 4800MHz
# 3           Intel Core 5 120U              16GB, DDR5
# 4     Intel Core Ultra 7-155H  16GB, LPDDR5X, 7467MHz
# ...                       ...                     ...
# 1239                 Apple M1                     8GB
# 1240     Intel Core i5-1035G1      8GB, DDR4, 3200MHz
# 1241        AMD Ryzen 3 3250U      4GB, DDR4, 2400MHz
# 1242     Intel Core i3-1005G1               8GB, DDR4
# 1243        AMD Ryzen 7 3700U      8GB, DDR4, 2400MHz
#
#                     Dysk SSD:                              Karta graficzna:  \
# 0      512GB PCIe NVMe 4.0 x4                           AMD Radeon Graphics
# 1             512GB PCIe NVMe  NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 2      512GB PCIe NVMe 4.0 x4  NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 3         512GB PCIe NVMe 4.0                            Intel UHD Graphics
# 4      512GB PCIe NVMe 4.0 x4                            Intel Arc Graphics
# ...                       ...                                           ...
# 1239                    512GB                           Apple M1 (8 rdzeni)
# 1240      512GB PCIe NVMe 3.0                            Intel UHD Graphics
# 1241   256GB PCIe NVMe 3.0 x2                           AMD Radeon Graphics
# 1242          256GB PCIe NVMe                            Intel UHD Graphics
# 1243  1000GB PCIe NVMe 3.0 x4                         AMD Radeon RX Vega 10
#
#                                                  Ekran:  \
# 0            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 1              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 2              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 3            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 4              14", 1920 x 1200px, 60Hz, Ekran dotykowy
# ...                                                 ...
# 1239          13.3", 2560 x 1600px, Matryca Retina, LED
# 1240  14", 1920 x 1080px, Matryca WVA, 60Hz, Ekran d...
# 1241                   15.6", 1920 x 1080px, Matryca TN
# 1242              15.6", 1920 x 1080px, Matryca TN, LED
# 1243               14", 1920 x 1080px, Matryca IPS, LED
#
#                                      System operacyjny: Dysk HDD:
# 0                                       Windows 11 Home       NaN
# 1                                                  Brak       NaN
# 2                                       Windows 11 Home       NaN
# 3                               Windows 11 Professional       NaN
# 4                                       Windows 11 Home       NaN
# ...                                                 ...       ...
# 1239                                      macOS Big Sur       NaN
# 1240  Windows 10 Home (możliwość darmowej aktualizac...       NaN
# 1241                                               Brak       NaN
# 1242                                               Brak       NaN
# 1243  Windows 10 Home (możliwość darmowej aktualizac...       NaN
#
# [1243 rows x 10 columns]

# %%
df = df.rename(columns={'RAM:': 'RAM'})
df['RAM'] = df['RAM'].str.extract(r'(\d+)\s*GB', expand=False).replace('', float('nan'))
df.head()
# Out:
#                                                Tytuł    Cena       Sklep  \
# 0  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.0  ediaexpert
# 1  Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.0  ediaexpert
# 2  Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3399.0  ediaexpert
# 3  Laptop ACER TravelMate P2 TMP216-51-G2-TCO 16"...  3399.0  ediaexpert
# 4  Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4899.0  ediaexpert
#
#                  Procesor: RAM               Dysk SSD:  \
# 0        AMD Ryzen 7 7730U  16  512GB PCIe NVMe 4.0 x4
# 1     Intel Core i5-13420H  16         512GB PCIe NVMe
# 2    Intel Core i5-12450HX  24  512GB PCIe NVMe 4.0 x4
# 3        Intel Core 5 120U  16     512GB PCIe NVMe 4.0
# 4  Intel Core Ultra 7-155H  16  512GB PCIe NVMe 4.0 x4
#
#                                Karta graficzna:  \
# 0                           AMD Radeon Graphics
# 1  NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 2  NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 3                            Intel UHD Graphics
# 4                            Intel Arc Graphics
#
#                                        Ekran:       System operacyjny:  \
# 0  16", 1920 x 1200px, Matryca IPS, LED, 60Hz          Windows 11 Home
# 1    15.6", 1920 x 1080px, Matryca IPS, 144Hz                     Brak
# 2    15.6", 1920 x 1080px, Matryca IPS, 144Hz          Windows 11 Home
# 3  16", 1920 x 1200px, Matryca IPS, LED, 60Hz  Windows 11 Professional
# 4    14", 1920 x 1200px, 60Hz, Ekran dotykowy          Windows 11 Home
#
#   Dysk HDD:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df = df.rename(columns={'Dysk SSD:': 'Dysk SSD'})
df[['Dysk_Wartosc', 'Dysk_Jednostka']] = df['Dysk SSD'].str.extract(r'(\d+)\s*(GB|TB)', expand=True)
df['Dysk_Wartosc'] = df.apply(
    lambda row: row['Dysk_Wartosc'] * 1024 if row['Dysk_Jednostka'] == 'TB' else row['Dysk_Wartosc'],
    axis=1
)
df['Dysk SSD'] = df['Dysk_Wartosc']

df = df.drop(columns=['Dysk_Wartosc', 'Dysk_Jednostka'])

df
# Out:
#                                                   Tytuł     Cena       Sklep  \
# 0     Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00  ediaexpert
# 1     Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00  ediaexpert
# 2     Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3399.00  ediaexpert
# 3     Laptop ACER TravelMate P2 TMP216-51-G2-TCO 16"...  3399.00  ediaexpert
# 4     Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4899.00  ediaexpert
# ...                                                 ...      ...         ...
# 1239  Laptop APPLE MacBook Pro 13.3" Retina M1 8GB R...  5389.97  ediaexpert
# 1240  Laptop DELL Inspiron 5400-6643 14" i5-1035G1 8...  2959.97  ediaexpert
# 1241  Laptop LENOVO IdeaPad 3 15ADA05 15.6" R3-3250U...  1199.97  ediaexpert
# 1242  Laptop ACER Extensa EX215-31 15.6" i3-1005G1 8...  1839.97  ediaexpert
# 1243  Laptop LENOVO IdeaPad S540-14API 14" IPS R7-37...  2399.97  ediaexpert
#
#                     Procesor: RAM Dysk SSD  \
# 0           AMD Ryzen 7 7730U  16      512
# 1        Intel Core i5-13420H  16      512
# 2       Intel Core i5-12450HX  24      512
# 3           Intel Core 5 120U  16      512
# 4     Intel Core Ultra 7-155H  16      512
# ...                       ...  ..      ...
# 1239                 Apple M1   8      512
# 1240     Intel Core i5-1035G1   8      512
# 1241        AMD Ryzen 3 3250U   4      256
# 1242     Intel Core i3-1005G1   8      256
# 1243        AMD Ryzen 7 3700U   8     1000
#
#                                   Karta graficzna:  \
# 0                              AMD Radeon Graphics
# 1     NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 2     NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 3                               Intel UHD Graphics
# 4                               Intel Arc Graphics
# ...                                            ...
# 1239                           Apple M1 (8 rdzeni)
# 1240                            Intel UHD Graphics
# 1241                           AMD Radeon Graphics
# 1242                            Intel UHD Graphics
# 1243                         AMD Radeon RX Vega 10
#
#                                                  Ekran:  \
# 0            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 1              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 2              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 3            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 4              14", 1920 x 1200px, 60Hz, Ekran dotykowy
# ...                                                 ...
# 1239          13.3", 2560 x 1600px, Matryca Retina, LED
# 1240  14", 1920 x 1080px, Matryca WVA, 60Hz, Ekran d...
# 1241                   15.6", 1920 x 1080px, Matryca TN
# 1242              15.6", 1920 x 1080px, Matryca TN, LED
# 1243               14", 1920 x 1080px, Matryca IPS, LED
#
#                                      System operacyjny: Dysk HDD:
# 0                                       Windows 11 Home       NaN
# 1                                                  Brak       NaN
# 2                                       Windows 11 Home       NaN
# 3                               Windows 11 Professional       NaN
# 4                                       Windows 11 Home       NaN
# ...                                                 ...       ...
# 1239                                      macOS Big Sur       NaN
# 1240  Windows 10 Home (możliwość darmowej aktualizac...       NaN
# 1241                                               Brak       NaN
# 1242                                               Brak       NaN
# 1243  Windows 10 Home (możliwość darmowej aktualizac...       NaN
#
# [1243 rows x 10 columns]

# %%
# df2 = df.rename(columns={'RAM:': 'RAM'})
#
# df2['RAM'] = df['RAM'].str.extract(r'(\d+)\s*GB', expand=False).replace('', float('nan'))
#
# df
# Out:
#                                                   Tytuł     Cena       Sklep  \
# 0     Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00  ediaexpert
# 1     Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00  ediaexpert
# 2     Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3399.00  ediaexpert
# 3     Laptop ACER TravelMate P2 TMP216-51-G2-TCO 16"...  3399.00  ediaexpert
# 4     Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4899.00  ediaexpert
# ...                                                 ...      ...         ...
# 1239  Laptop APPLE MacBook Pro 13.3" Retina M1 8GB R...  5389.97  ediaexpert
# 1240  Laptop DELL Inspiron 5400-6643 14" i5-1035G1 8...  2959.97  ediaexpert
# 1241  Laptop LENOVO IdeaPad 3 15ADA05 15.6" R3-3250U...  1199.97  ediaexpert
# 1242  Laptop ACER Extensa EX215-31 15.6" i3-1005G1 8...  1839.97  ediaexpert
# 1243  Laptop LENOVO IdeaPad S540-14API 14" IPS R7-37...  2399.97  ediaexpert
#
#                     Procesor: RAM Dysk SSD  \
# 0           AMD Ryzen 7 7730U  16      512
# 1        Intel Core i5-13420H  16      512
# 2       Intel Core i5-12450HX  24      512
# 3           Intel Core 5 120U  16      512
# 4     Intel Core Ultra 7-155H  16      512
# ...                       ...  ..      ...
# 1239                 Apple M1   8      512
# 1240     Intel Core i5-1035G1   8      512
# 1241        AMD Ryzen 3 3250U   4      256
# 1242     Intel Core i3-1005G1   8      256
# 1243        AMD Ryzen 7 3700U   8     1000
#
#                                   Karta graficzna:  \
# 0                              AMD Radeon Graphics
# 1     NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 2     NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 3                               Intel UHD Graphics
# 4                               Intel Arc Graphics
# ...                                            ...
# 1239                           Apple M1 (8 rdzeni)
# 1240                            Intel UHD Graphics
# 1241                           AMD Radeon Graphics
# 1242                            Intel UHD Graphics
# 1243                         AMD Radeon RX Vega 10
#
#                                                  Ekran:  \
# 0            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 1              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 2              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 3            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 4              14", 1920 x 1200px, 60Hz, Ekran dotykowy
# ...                                                 ...
# 1239          13.3", 2560 x 1600px, Matryca Retina, LED
# 1240  14", 1920 x 1080px, Matryca WVA, 60Hz, Ekran d...
# 1241                   15.6", 1920 x 1080px, Matryca TN
# 1242              15.6", 1920 x 1080px, Matryca TN, LED
# 1243               14", 1920 x 1080px, Matryca IPS, LED
#
#                                      System operacyjny: Dysk HDD:
# 0                                       Windows 11 Home       NaN
# 1                                                  Brak       NaN
# 2                                       Windows 11 Home       NaN
# 3                               Windows 11 Professional       NaN
# 4                                       Windows 11 Home       NaN
# ...                                                 ...       ...
# 1239                                      macOS Big Sur       NaN
# 1240  Windows 10 Home (możliwość darmowej aktualizac...       NaN
# 1241                                               Brak       NaN
# 1242                                               Brak       NaN
# 1243  Windows 10 Home (możliwość darmowej aktualizac...       NaN
#
# [1243 rows x 10 columns]

# %%
df = df.rename(columns={'System operacyjny:': 'System operacyjny'})
df['System operacyjny'].value_counts()
# Out:
# System operacyjny
# Windows 11 Home                                                    670
# Brak                                                               243
# Windows 11 Professional                                            148
# macOS Sonoma                                                        38
# macOS Sequoia                                                       33
# Windows 10 Home (możliwość darmowej aktualizacji do Windows 11)     23
# Chrome OS                                                           21
# Linux                                                               14
# macOS Monterey                                                      10
# macOS Ventura                                                       10
# macOS Big Sur                                                        8
# Windows 11 Home S                                                    8
# Windows 10 Home                                                      6
# Windows 10 S (możliwość darmowej aktualizacji do Windows 11)         5
# Windows 10 Professional                                              4
# Windows 11 Professional, Uaktualnienie do Windows 11                 1
# Name: count, dtype: int64

# %%
# df['System operacyjny'] = df['System operacyjny'].replace('Brak', np.nan)

# df['System operacyjny'] = df['System operacyjny'].fillna(
#     df['Tytuł'].apply(lambda x: 'macOS Sequoia' if 'MAC' in x.upper() else 'Windows 11 Home')
# )
#
# df
# Out:
#                                                   Tytuł     Cena       Sklep  \
# 0     Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00  ediaexpert
# 1     Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00  ediaexpert
# 2     Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3399.00  ediaexpert
# 3     Laptop ACER TravelMate P2 TMP216-51-G2-TCO 16"...  3399.00  ediaexpert
# 4     Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4899.00  ediaexpert
# ...                                                 ...      ...         ...
# 1239  Laptop APPLE MacBook Pro 13.3" Retina M1 8GB R...  5389.97  ediaexpert
# 1240  Laptop DELL Inspiron 5400-6643 14" i5-1035G1 8...  2959.97  ediaexpert
# 1241  Laptop LENOVO IdeaPad 3 15ADA05 15.6" R3-3250U...  1199.97  ediaexpert
# 1242  Laptop ACER Extensa EX215-31 15.6" i3-1005G1 8...  1839.97  ediaexpert
# 1243  Laptop LENOVO IdeaPad S540-14API 14" IPS R7-37...  2399.97  ediaexpert
#
#                     Procesor: RAM Dysk SSD  \
# 0           AMD Ryzen 7 7730U  16      512
# 1        Intel Core i5-13420H  16      512
# 2       Intel Core i5-12450HX  24      512
# 3           Intel Core 5 120U  16      512
# 4     Intel Core Ultra 7-155H  16      512
# ...                       ...  ..      ...
# 1239                 Apple M1   8      512
# 1240     Intel Core i5-1035G1   8      512
# 1241        AMD Ryzen 3 3250U   4      256
# 1242     Intel Core i3-1005G1   8      256
# 1243        AMD Ryzen 7 3700U   8     1000
#
#                                   Karta graficzna:  \
# 0                              AMD Radeon Graphics
# 1     NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 2     NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 3                               Intel UHD Graphics
# 4                               Intel Arc Graphics
# ...                                            ...
# 1239                           Apple M1 (8 rdzeni)
# 1240                            Intel UHD Graphics
# 1241                           AMD Radeon Graphics
# 1242                            Intel UHD Graphics
# 1243                         AMD Radeon RX Vega 10
#
#                                                  Ekran:  \
# 0            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 1              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 2              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 3            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 4              14", 1920 x 1200px, 60Hz, Ekran dotykowy
# ...                                                 ...
# 1239          13.3", 2560 x 1600px, Matryca Retina, LED
# 1240  14", 1920 x 1080px, Matryca WVA, 60Hz, Ekran d...
# 1241                   15.6", 1920 x 1080px, Matryca TN
# 1242              15.6", 1920 x 1080px, Matryca TN, LED
# 1243               14", 1920 x 1080px, Matryca IPS, LED
#
#                                       System operacyjny Dysk HDD:
# 0                                       Windows 11 Home       NaN
# 1                                       Windows 11 Home       NaN
# 2                                       Windows 11 Home       NaN
# 3                               Windows 11 Professional       NaN
# 4                                       Windows 11 Home       NaN
# ...                                                 ...       ...
# 1239                                      macOS Big Sur       NaN
# 1240  Windows 10 Home (możliwość darmowej aktualizac...       NaN
# 1241                                    Windows 11 Home       NaN
# 1242                                    Windows 11 Home       NaN
# 1243  Windows 10 Home (możliwość darmowej aktualizac...       NaN
#
# [1243 rows x 10 columns]

# %%
df = df.rename(columns={'Procesor:': 'Procesor'})
df['Procesor'].value_counts()
# Out:
# Procesor
# Intel Core i5-1235U        68
# Intel Core i5-12500H       52
# Intel Core Ultra 7-155H    48
# Intel Core i7-12700H       42
# Apple M3                   40
#                            ..
# AMD Ryzen 9 8945H           1
# Intel Core Ultra 5-226V     1
# AMD Ryzen 9 5900HX          1
# AMD Ryzen 7 Pro 7735U       1
# AMD Ryzen 7 3700U           1
# Name: count, Length: 159, dtype: int64

# %%
def extract_processor_brand(processor_name):
    if 'Intel' in processor_name:
        return 'Intel'
    elif 'AMD' in processor_name:
        return 'AMD'
    elif 'Apple' in processor_name:
        return 'Apple'
    elif 'MediaTek' in processor_name:
        return 'MediaTek'
    elif 'Qualcomm' in processor_name:
        return 'Qualcomm'
    else:
        return 'Inne'

df['Firma procesora'] = df['Procesor'].apply(extract_processor_brand)
df
# Out:
#                                                   Tytuł     Cena       Sklep  \
# 0     Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2989.00  ediaexpert
# 1     Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3699.00  ediaexpert
# 2     Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3399.00  ediaexpert
# 3     Laptop ACER TravelMate P2 TMP216-51-G2-TCO 16"...  3399.00  ediaexpert
# 4     Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4899.00  ediaexpert
# ...                                                 ...      ...         ...
# 1239  Laptop APPLE MacBook Pro 13.3" Retina M1 8GB R...  5389.97  ediaexpert
# 1240  Laptop DELL Inspiron 5400-6643 14" i5-1035G1 8...  2959.97  ediaexpert
# 1241  Laptop LENOVO IdeaPad 3 15ADA05 15.6" R3-3250U...  1199.97  ediaexpert
# 1242  Laptop ACER Extensa EX215-31 15.6" i3-1005G1 8...  1839.97  ediaexpert
# 1243  Laptop LENOVO IdeaPad S540-14API 14" IPS R7-37...  2399.97  ediaexpert
#
#                      Procesor RAM Dysk SSD  \
# 0           AMD Ryzen 7 7730U  16      512
# 1        Intel Core i5-13420H  16      512
# 2       Intel Core i5-12450HX  24      512
# 3           Intel Core 5 120U  16      512
# 4     Intel Core Ultra 7-155H  16      512
# ...                       ...  ..      ...
# 1239                 Apple M1   8      512
# 1240     Intel Core i5-1035G1   8      512
# 1241        AMD Ryzen 3 3250U   4      256
# 1242     Intel Core i3-1005G1   8      256
# 1243        AMD Ryzen 7 3700U   8     1000
#
#                                   Karta graficzna:  \
# 0                              AMD Radeon Graphics
# 1     NVIDIA GeForce RTX 4050 + Intel UHD Graphics
# 2     NVIDIA GeForce RTX 3050 + Intel UHD Graphics
# 3                               Intel UHD Graphics
# 4                               Intel Arc Graphics
# ...                                            ...
# 1239                           Apple M1 (8 rdzeni)
# 1240                            Intel UHD Graphics
# 1241                           AMD Radeon Graphics
# 1242                            Intel UHD Graphics
# 1243                         AMD Radeon RX Vega 10
#
#                                                  Ekran:  \
# 0            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 1              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 2              15.6", 1920 x 1080px, Matryca IPS, 144Hz
# 3            16", 1920 x 1200px, Matryca IPS, LED, 60Hz
# 4              14", 1920 x 1200px, 60Hz, Ekran dotykowy
# ...                                                 ...
# 1239          13.3", 2560 x 1600px, Matryca Retina, LED
# 1240  14", 1920 x 1080px, Matryca WVA, 60Hz, Ekran d...
# 1241                   15.6", 1920 x 1080px, Matryca TN
# 1242              15.6", 1920 x 1080px, Matryca TN, LED
# 1243               14", 1920 x 1080px, Matryca IPS, LED
#
#                                       System operacyjny Dysk HDD:  \
# 0                                       Windows 11 Home       NaN
# 1                                                  Brak       NaN
# 2                                       Windows 11 Home       NaN
# 3                               Windows 11 Professional       NaN
# 4                                       Windows 11 Home       NaN
# ...                                                 ...       ...
# 1239                                      macOS Big Sur       NaN
# 1240  Windows 10 Home (możliwość darmowej aktualizac...       NaN
# 1241                                               Brak       NaN
# 1242                                               Brak       NaN
# 1243  Windows 10 Home (możliwość darmowej aktualizac...       NaN
#
#      Firma procesora
# 0                AMD
# 1              Intel
# 2              Intel
# 3              Intel
# 4              Intel
# ...              ...
# 1239           Apple
# 1240           Intel
# 1241             AMD
# 1242           Intel
# 1243             AMD
#
# [1243 rows x 11 columns]

# %%
df['Firma procesora'].value_counts()
# // kolumna sklep dla kazdego rekordu ma miec wartosc MediaExpert
df['Sklep'] = 'MediaExpert'
df['Firma procesora'].value_counts()
# Out:
# Firma procesora
# Intel       803
# AMD         309
# Apple        99
# Qualcomm     27
# MediaTek      5
# Name: count, dtype: int64

# %%
df = df.rename(columns={'Ekran:': 'Ekran'})
df['Ekran'] = df['Ekran'].str.extract(r'(\d+(?:\.\d+)?)', expand=False)

# %%
df.to_csv('produkty_mediaexpert_szczegoly_full_cleaned.csv', index=False, encoding='utf-8')
