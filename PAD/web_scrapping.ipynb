# %%
# https://pypi.org/project/selenium/
# https://pypi.org/project/beautifulsoup4/
# !pip install selenium
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting selenium
#   Downloading selenium-4.18.1-py3-none-any.whl (10.0 MB)
#                                               0.0/10.0 MB ? eta -:--:--
#                                               0.2/10.0 MB 3.3 MB/s eta 0:00:04
#      ---                                      0.8/10.0 MB 10.0 MB/s eta 0:00:01
#      --------------                           3.6/10.0 MB 28.7 MB/s eta 0:00:01
#      --------------------------------         8.1/10.0 MB 46.9 MB/s eta 0:00:01
#      --------------------------------------- 10.0/10.0 MB 45.6 MB/s eta 0:00:00
# Collecting urllib3[socks]<3,>=1.26 (from selenium)
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#                                               0.0/121.1 kB ? eta -:--:--
#      ---------------------------------------- 121.1/121.1 kB ? eta 0:00:00
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#                                               0.0/460.2 kB ? eta -:--:--
#      ------------------------------------- 460.2/460.2 kB 28.1 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Collecting certifi>=2021.10.8 (from selenium)
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#                                               0.0/163.8 kB ? eta -:--:--
#      ---------------------------------------- 163.8/163.8 kB ? eta 0:00:00
# Collecting typing_extensions>=4.9.0 (from selenium)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting attrs>=20.1.0 (from trio~=0.17->selenium)
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#                                               0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting idna (from trio~=0.17->selenium)
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#                                               0.0/61.6 kB ? eta -:--:--
#      ---------------------------------------- 61.6/61.6 kB 3.4 MB/s eta 0:00:00
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting cffi>=1.14 (from trio~=0.17->selenium)
#   Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
#                                               0.0/181.5 kB ? eta -:--:--
#      ---------------------------------------- 181.5/181.5 kB ? eta 0:00:00
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pycparser (from cffi>=1.14->trio~=0.17->selenium)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#                                               0.0/118.7 kB ? eta -:--:--
#      ---------------------------------------- 118.7/118.7 kB ? eta 0:00:00
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#                                               0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Installing collected packages: sortedcontainers, urllib3, typing_extensions, sniffio, pysocks, pycparser, idna, h11, certifi, attrs, wsproto, outcome, cffi, trio, trio-websocket, selenium
# Successfully installed attrs-23.2.0 certifi-2024.2.2 cffi-1.16.0 h11-0.14.0 idna-3.6 outcome-1.3.0.post0 pycparser-2.21 pysocks-1.7.1 selenium-4.18.1 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 typing_extensions-4.10.0 urllib3-2.2.1 wsproto-1.2.0
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#                                               0.0/147.9 kB ? eta -:--:--
#      -------------------------------------- 147.9/147.9 kB 4.4 MB/s eta 0:00:00
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.5
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

download_service = Service()

driver = webdriver.Chrome(service=download_service)

# %%
driver.get(r"https://www.coffeedesk.pl/kawa/")

# %%
from selenium.webdriver.common.by import By
button_id = "CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll"

web_button = driver.find_element(by=By.ID, value=button_id)
web_button.click()

# %%
product_info_class = "product-info"
product_title_a_class = "product-name"
product_price_div_class = "product-price"

product_info_list = driver.find_elements(by=By.CLASS_NAME, value=product_info_class)
product_data = {}
for product in product_info_list:
    name_element = product.find_element(by=By.CLASS_NAME, value=product_title_a_class)
    price_element = product.find_elements(by=By.CLASS_NAME, value=product_price_div_class)
    # To handle if there is more price elements that expected 
    prices = []
    for price_i in price_element:
        price = price_i.text
        if price:
            prices.append(price)
    if len(price) > 0:
     print(name_element.get_attribute('title'), prices)
     product_data[name_element.get_attribute('title')] = prices
# Out:
# illy Classico - Classic Roast - Kawa ziarnista ['36,90 zł', '31,90 zł']
# Lavazza Qualita Oro ['80,00 zł', '65,90 zł']
# HAYB - Się Przelewa Owoc 250g ['45,00 zł']
# Pellini Top 100% Arabica ['125,00 zł', '79,90 zł']
# HAYB - Się Przelewa Klasyk Filter Blend 250g ['34,00 zł']
# Lavazza Crema e Aroma ['65,00 zł', '54,90 zł']
# LaCava - Shady BRU Nikaragua + Rwanda 250g ['39,00 zł']
# HAYB - Się Przelewa Owoc 250g ['45,00 zł']
# illy Arabica Selection - Guatemala ['36,90 zł', '31,90 zł']
# illy Arabica Selection - Brazylia ['36,90 zł', '31,90 zł']
# HAYB - Się Przelewa Kwiat 250g ['45,00 zł']
# Kofi Brand - Kofi Brasil Espresso 250g ['35,00 zł']
# SIMPLo - Brazylia Aguas de Marco Filter ['43,00 zł']
# illy Classico - Moka Pot - Kawa mielona ['36,90 zł', '31,90 zł']
# illy Arabica Selection - Ethiopia ['36,90 zł', '31,90 zł']
# Pellini - Espresso Bar Vivace n 82 - 1kg ['92,00 zł', '55,90 zł']
# Hard Beans - Brazylia Samambaia Filter - Kawa ziarnista 250g ['42,00 zł']
# Johan & Nyström - Fika - Kawa mielona Filter 500g ['68,00 zł']
# Kofi Brand - Brazylia Guaxupe Espresso 250g ['27,99 zł']
# illy Intenso Bold Roast - Kawa mielona ['36,90 zł', '31,90 zł']
# Lavazza Gran Espresso ['76,00 zł', '65,90 zł']
# Audun Coffee - Brazylia Fazenda Rainha Miaki Espresso 500g ['70,00 zł']
# Johan & Nyström - Fika Filter 500g ['75,00 zł']
# New York Macinato Moka ['30,00 zł']
# Johan & Nyström - Bourbon Jungle Omniroast 500g ['67,00 zł']
# Coffeelab - Gwatemala Huehuetenango Espresso 250g ['31,00 zł']
# COFFEE PLANT - FLOW Very Berry Filter 250g ['44,00 zł', '36,90 zł']
# HAYB - Blue Espresso Blend 250g ['36,00 zł']
# COFFEE PLANT - FLOW Juicy Fruit Filter 250g ['42,00 zł', '36,90 zł']
# COFFEE PLANT - Flow Brownie Filter 250g ['37,00 zł']
# Audun Coffee - Brazylia Fazenda Rainha Miaki Espresso 250g ['35,00 zł']
# Gardelli Specialty Coffees - Cignobianco Espresso Blend 250g ['58,00 zł']
# Le Piantagioni del Caffe - Water Decaf - Kawa bezkofeinowa 250g ['48,00 zł', '46,90 zł']
# Kofi Brand - Brazylia Guaxupe Espresso 1kg ['109,00 zł']
# Hard Beans - Polska Parzucha - Kawa ziarnista 250g ['30,00 zł']
# Arcaffe Roma 1kg ['139,00 zł', '109,90 zł']
# HAYB - Black Espresso Blend 250g ['28,00 zł']
# HAYB - Się Przelewa Tropik Filter 250g ['49,00 zł']

# %%
import json

with open("coffe_data.json", 'w') as file:
    json.dump(product_data, file)

# %%
len(product_data)
# Out:
# 37

# %%
from bs4 import BeautifulSoup

html_coffe = driver.page_source

soup = BeautifulSoup(''.join(html_coffe), 'html.parser')

# %%
product_info_list = soup.find_all("div", {"class": [product_info_class]})

for i in product_info_list:
    print(i.text)
# Out:
#                 illy Classico - Classic Roast - Kawa ziarnista
#
#
# Producent: Illy
#
#
#
# 	To espresso jest równowagą siły i gładkości. Kwintesencja  wyraźnego aromatu czekolady,  karmelu i lekkiej nutki kwiatów.
#
# 	To blend  dziewięciu najwyższej jakości ziaren Arabiki (100%). Ponad połowa z nich pochodzi z Brazylii, co wpływa na niepowtarzalny aromat. Pozostałe rodzaje pochodzą z Afryki i Ameryki Środkowej - co nadaje kawie ton słodyczy.
#
# 	Kawa jest szczególnie polecana do ekspresów ciśnieniowych.
#
#
# 		Średni/Ciemny stopień palenia
#
# 		100% Arabica
#
# 		Niska zawartość kofeiny - ok. 1,5%
#
# 		Opakowanie: 250g (ziarno)
#
#
#
#
#                     Najniższa cena: 29,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 36,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    31,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Lavazza Qualita Oro
#
#
# Producent: Lavazza
#
#
#
# 	Złota jakość (wł. qualita oro) tej kawy bierze się z wyselekcjonowanych ziaren Arabiki sprowadzonych z najlepszych plantacji południowej i centralnej Ameryki oraz Afryki.
#
#
# 	Cechuje ją naturalny, intensywny i aromatyczny zapach. Idealna kawa śniadaniowa, na dobry początek dnia.
#
# 	Opakowanie: 1kg
# 	Opis: kawa ziarnista, o średnim poziomie zawartości kofeiny
#
#
#
#                     Najniższa cena: 62,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 80,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    65,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 HAYB - Się Przelewa Owoc 250g
#
#
# Producent: HAYB
# Data palenia: 13.02.2024
#
#
#
# 	Kawa ziarnista jakości specialty wypalona w warszawskiej palarni HAYB. W opakowaniu znajdziesz ziarna o punktacji 86+ w 100% pochodzące z Rwandy. Kawa palona jasno, polecana szczególnie do kawiarni jako ziarno do gastronomicznych ekspresów przelewowych. Sprawdzi się również do dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. W filiżance można odnaleźć wysoką słodycz, która idzie ręka w rękę z przyjemną kwasowością – jak dojrzały, soczysty, letni owoc.
# Mieszanka składa się z kaw:
#
# - 100% Rwanda
#
#
#
#
#
#
# 	Opinia roastera:
# TO OWOC – NIE ZAKAZANY!
#
# To nie przelewki – Się Przelewa Owoc to przelewik, taki owocowy, lekki, zbalansowany, z dużą dawką słodyczy i rześką kwaskowością. To owocowa myta Afryka – Rwanda konkretnie – w wydaniu daily. Jej atrakcyjna cena zachęca do wypicia jeszcze jednej kawki i kolejnej!
#
# Seria SIĘ PRZELEWA to w ogóle proste sytuacje. Kawka nie wymaga od Ciebie skrupulatnego liczenia klików, będzie dobra, możesz wsypać ją do ekspresu przelewowego bez wyrzutów sumienia – po prostu Effortless Speciality.
#
# Jej supermoce (poza przystępnością i niską ceną) to łagodny smak i niska kwasowość, możesz stosować ją we wszystkich metodach przelewowych: wrzuć ją do swojego ekspresu – nieważne czy to Melitta, czy Moccamasster – strzel sobie Chemex, Aeropress, V60, french press czy co tam sobie zażyczysz. Będzie pysznie!
#
#
#
# 	Metody parzenia:
#
#
#
# 	O palarni:
#
#
# HAYB to warszawska palarnia kawy speciality, która robi swoją robotę porządnie i z uśmiechem - lubią kawę, coś o niej wiedzą, robią ją - wyobrażacie sobie lepszy układ? Chodzi o to, żeby smakowało bez czarów, dlatego ich motto to Effortless Speciality. Wśród kaw HAYB znajdziesz jedynie ziarno jakości speciality, zarówno pod przelewowe metody parzenia, jak i pod espresso, single oraz blendy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    45,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Pellini Top 100% Arabica
#
#
# Producent: Pellini
#
#
#
# 	Pellini Top 100% Arabica to kawa ziarnista dedykowana prawdziwym koneserom czarnego naparu. Produkt stanowi flagową mieszankę włoskiej palarni Pellini. Składa się ze 100% ziaren Arabiki, pochodzących z górskich upraw i starannie selekcjonowanych. Proces ich palenia jest ściśle kontrolowany, aby osiągnąć łagodny i subtelny smak przy zachowaniu wyrazistego, przyjemnego aromatu.
#
# 	Pellini Top jest kawą dedykowaną do przygotowania esencjonalnego espresso. Sprawdzi się zarówno jako napar dodający energii do działania o poranku, jak i w formie kawy popołudniowej, która pobudza i orzeźwia. Produkt może stanowić także bazę dla wielu kaw mlecznych, takich jak cappuccino czy latte machiato.
#
# 	Kawa Pellini Top to ziarna o ciemnym stopniu palenia. Zmielona i zaparzona metodą tradycyjną lub z pomocą ekspresu ciśnieniowego ma średnią zawartość kofeiny. Powolny proces palenia starannie wyselekcjonowanych ziaren Arabiki gwarantuje jej zrównoważony, pełny smak. Natomiast naturalny sposób chłodzenia powietrzem dba o zachowanie intensywnego, zmysłowego aromatu kawy.
#
# 	Pellini Top jest mieszanką niezwykle pożądaną na polskim rynku. Zawdzięcza to wysokiej jakości ziaren poddawanych szczegółowej selekcji oraz procesowi wypalania, który podlega wielu kontrolom po to, aby do konsumentów trafiła 100% Arabica o najczystszym smaku i najlepszym aromacie. Napar z ziaren Pellini Top warto degustować bez dodatku cukru. Kawa z tej mieszanki ma bowiem swój oryginalny, subtelnie słodki, ale też wyrazisty smak, który zasłużył na uznanie.
#
#
# 	Opakowanie: 1kg.
#
#
#
#
#                     Najniższa cena: 89,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 125,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    79,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Heresy - Kolumbia El Placer Double Carbonic White Honey Geisha Filter 126g
#
#
# Producent: Heresy
# Data palenia:
# 13.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Kolumbii, wypalona w palarni Heresy przez Wicemistrza Polski Roasting 2020. Palona jasno, przeznaczona do przelewowych metod parzenia lub zalania w kubku. Profil charakteryzujący się cukierkową słodyczą, owocowością i nutami kwiatowymi.
#
# 	Kraj pochodzenia ziarna:&nbsp; Kolumbia
# 	Region:&nbsp;Quindio
# 	Odmiana: geisha
# 	Producent: Sebastian Ramirez
# 	Obróbka: double carbonic white honey
# 	Położenie upraw: 1800 m n.p.m.
# 	Zbiór: 2023
# 	Wynik w cuppingu: 90+ / 100 punktów
#
#
# 	OBRÓBKA
#
# 	Podwójna fermentacja z wykorzystaniem techniki carbonic maceration. Najpierw wiśnie w całości spędzają sobie 2 dni w szczelnych tankach, w towarzystwie dwutlenku węgla. Następnie depulping – oddzielanie ziarna od owocu. Potem kolejne dwa dni fermentacji, tym razem pod wodą i suszenie.
#
#
# 	PRODUCENT
#
# 	Sebastian to jeden z tych najbardziej innowacyjnych i szalonych na punkcie jakości kolumbijskich producentów. Egzotyczne odmiany botaniczne, laboratoryjny sprzęt do processingu, otwarta głowa i chęć do przesuwania barier, o tym tu mówimy. El Placer to światowy poziom kawowej rozkminki.
#
#
# 	OPINIA ROASTERA
#
# 	Czy to najdroższa kawa w herezyjnej historii? Tak. Czy to najlepsza kawa, jaką zamknęliśmy w słoik? Fair enough. To jest, proszę Państwa, top topów, walizka Marcellusa, kociołek przy tęczy, i tak dalej. Absolutny, światowy majstersztyk producencki. Moglibyśmy użyć jeszcze tysiąca słów, ale polećmy zenem: po prostu spróbuj.
#
#
# 	OPAKOWANIE
#
# 	Kawa spakowana jest w brązowy słoik wykonany z PET, w 100% nadający się do recyklingu lub ponownego wykorzystania. I jeśli teraz myślisz „o nie, plastik!”, to pamiętaj, że standardowe opakowania na kawę są także z plastiku (i kilku innych materiałów, przez co często są trudniejsze do przetworzenia). Myśleliśmy też o szkle, ale jest cięższe, droższe, tłucze się i, uwaga, ma taki sam lub większy (sic!) wpływ na środowisko! Plastikowy słoik okazuje się być całkiem eco-friendly, pamiętaj tylko o wrzuceniu go do odpowiedniego pojemnika, albo znajdź kreatywny sposób, by wykorzystać go w domu.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 97,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 97,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# LaCava - Rwanda Bukonya Washed Filter 250g (outlet)
#
#
# Producent: LaCava
# Data palenia:
# 06.09.2023
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Rwandy, wypalona przez palarnię&nbsp;LaCava. Palona jasno, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. W smaku wyczuwalne są nuty&nbsp;śliwki, miodu, herbaty i maliny.
# Kraj pochodzenia kawy: Rwanda
# Region: Northern Providence, Gakenke District
# Metoda obróbki: Washed
# Odmiana:&nbsp;Bourbon, Typica
# Położenie upraw:&nbsp;1750 - 2100 m n.p.m.
# Punkty w cuppingu:&nbsp;86+ / 100 pkt
#
#
# Najniższa cena: 55,25 zł
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 45,50zł
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 45,50zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Coffeelab - Salwador Finca Andalucia Washed Espresso 250g
#
#
# Producent: Coffeelab
# Data palenia:
# 19.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Salwadoru, wypalona w z warszawskiej palarni Coffeelab. Palona w średnim stopniu, przeznaczona do espresso - sprawdzi się w ekspresach ciśnieniowych i kawiarkach.&nbsp;Kawa o nutach orzechów laskowych, toffi i jabłka.
#
# 	Kraj pochodzenia ziarna: Salwador
# 	Region: Canton el Arco , Cocepcion de Ataco, Ahuachapan
# 	Odmiana:&nbsp;Bourbon, Caturra, Pacamara, Catimor
# 	Obróbka: Washed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 31,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 31,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Johan & Nyström - Delicious Days Filter 250g
#
#
# Producent: Johan & Nyström
# Data palenia:
# 09.01.2024
#
#
#
# Tęsknisz za Salwadorem Menendez? Sprawdź&nbsp;Delicious Days&nbsp;od Johan &amp; Nyström.
#
# 	Kawa ziarnista jakości specialty pochodząca z Salwadoru, wypalana przez szwedzką palarnie Johan &amp; Nystrom. Palona jasno, sprawdzi się przede wszystkim w przelewowych metodach parzenia.&nbsp;Fortaleza jest doskonale zbalansowana, o naturalnych nutach soczystej pomarańczy, nugatu i chrupiącego czerwonego jabłka.
# 	&nbsp;
#
# 	Kraj pochodzenia ziarna:&nbsp;Salwador
# 	Producent: rodzina Menendez
# 	&nbsp;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kafar - Brazylia Monte Carmelo Natural Espresso 1kg
#
#
# Producent: Kafar
# Data palenia:
# 13.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Brazylii, wypalona w gliwickiej palarni Kafar. Palona w ciemnym stopniu, idealna do ekspresu ciśnieniowego i kawiarki. W jej smaku można wyczuć nuty czekolady deserowej, toffi i suszonych owoców. Pełne, gładkie body.&nbsp;
#
# 	Kraj pochodzenia kawy: Brazylia
# 	Farma:&nbsp;Monte Carmelo i Chapadao de Ferro
# 	Metoda obróbki:&nbsp;Natural
# 	&nbsp;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 111,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 111,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hard Beans - Gwatemala San Martin Jilotepeque Washed Espresso 500g (outlet)
#
#
# Producent: Hard Beans
# Data palenia:
# 26.11.2023
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Gwatemali, wypalana przez polską palarnię Hard Beans.&nbsp;Kawa palona w średnim stopniu, przeznaczona do espresso - doskonale sprawdzi się w ekspresach ciśnieniowych i kawiarkach.&nbsp;W jej smaku wyczujesz nuty przypominające syrop klonowy, pistacje i jabłka
# Kraj pochodzenia ziarna: Gwatemala
# Region: San Martin, Jilotepeque
# Metoda obróbki: Washed
# Odmiana: Bourbon, Typica, Caturra, Catuai
# Położenie upraw:&nbsp;1600 - 1800 m n.p.m.
#
#
# Najniższa cena: 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
# 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 64,90zł
#
#
#
# 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 64,90zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zestaw kawa Mad Jungle FIL + klips
#
#
# Producent: Coffeedesk
# Data palenia:
# 22.11.2023
#
#
#
# Hi! Coffeedesk - Mad Jungle Filter 250g - Jak w życiu! Gdy poznajesz szaloną i kapryśna osobowość, bez której nie wyobrażasz sobie letniego cold brew. Orzeźwiająco-cytrusowy rozmach dla prawdziwych koneserów. Ekscesy, fanaberie i soczysta rozkosz podniebienia dla odważnych entuzjastów.
# Hi! Coffeedesk - Klips do opakowania - Klips Hi! Coffeedesk do zamykania opakowań kawy i herbaty. Pozwala na uszczelnienie paczki w szybki i prosty sposób. Zabezpieczenie produktów przed dostępem tlenu pozwala dłużej zachować ich smak. Wykonany ze stali nierdzewnej, ozdobiony logo. Jego długość wynosi 5,1cm, szerokość 2cm.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
# 71,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 61,90zł
#
#
#
# 71,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 71,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 61,90zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Johan & Nyström - Etiopia Tesfaye Bekele Washed Filter 250g
#
#
# Producent: Johan & Nyström
# Data palenia:
# 28.11.2023
#
#
#
# Kawa ziarnista&nbsp;jakości specialty pochodząca z Etiopii, wypalona w szwedzkiej palarni Johan &amp; Nyström.&nbsp;Palona w jasnym stopniu, sprawdzi się&nbsp; do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa i innych alternatywnych metod parzenia.&nbsp;W filiżance można wyczuć lemoniadę, brzoskwinię i zieloną herbatę.
#
# 	Kraj pochodzenia ziarna:&nbsp;Etiopia
# 	Farma:&nbsp;Suke Quto
# 	Producent:&nbsp;Tesfaye Bekele
# 	Położenie upraw: 1800 - 2200&nbsp; m n.p.m.
# 	Odmiana:&nbsp;Welicho, Kurume
# 	Obróbka: Washed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 72,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 72,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# COFFEE PLANT - Brazylia Lua Roxa Espresso 250g
#
#
# Producent: COFFEE PLANT
# Data palenia:
# 14.01.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Brazylii, wypalona w polskiej palarni&nbsp;COFFEE PLANT. Palona w średnim stopniu, sprawdzi się w ekspresach ciśnieniowych i kawiarkach. W smaku wyczuwalne są nuty&nbsp;wanilii, orzechów i białej czekolady.
# Kraj pochodzenia kawy: Brazylia
# Region: Minas Gerais, Cerrado
# Odmiana: Bourbon, Mudo Nuovo
# Metoda obróbki: Natural
# Położenie upraw:&nbsp;800 - 1300 m n.p.m.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 35,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 35,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Heresy - Illuminati Blend Espresso 252g
#
#
# Producent: Heresy
# Data palenia:
# 19.02.2024
#
#
#
# Co powstaje z połączenia Gwatemali z Gwatemalą? Jeszcze więcej Gwatemali w Gwatemali! Ten kraj to nasz ukochany region, do którego robimy regularne wyjazdy, zawsze zaskakując się tym, jak różnorodne kawy potrafi zaserwować. Jeśli Gwatemala kojarzy Ci się z klasycznym smakiem, to Amigo, zazdrościmy Ci jak wiele masz jeszcze do odkrycia! Mamy nadzieję, że lubisz dżemik!
#
# 	Mieszanka kaw ziarnistych jakości specialty, wypalona w palarni Heresy przez Wicemistrza Polski Roasting 2020. Palona średnio, przeznaczona do espresso, kawiarki lub zaparzania w kubku. Profil zbalansowany w smaku, łączący klasyczne i bardziej owocowe nuty, dostarczający wrażeń zarówno fanom tradycyjnych jak i nowoczesnego espresso. Uniwersalne espresso - zarówno pod shota jak i pod mleko. Zarówno dla kawiarni, jak i do domu. Na stałe w heretycznej ofercie!
#
# 	Kraj pochodzenia ziarna: Gwatemala
# 	Producent: mali producenci z regionu Jalapa
# 	Farma: San Martin i Santa Rosa
# 	Odmiana: caturra i bourbon
# 	Obróbka: washed i natural
# 	Położenie upraw: 1600 - 2200 m n.p.m.
#
#
# 	OBRÓBKA
#
# 	Mamy tu połączenie mytej i naturalnej obróbki kaw odmiany caturra i bourbon. San Martin to klasyczny washed. Santa Rosa to bardziej pofermentowany naturalnie wariacik. Mytonatural blend!
#
#
# 	FARMA
#
# 	Kawy z San Martin i Santa Rosa to blendy pochodzące od małych lokalnych producentów z regionu Jalapa. Ich zbiory są łączone i wspólnie obrabiane jako jeden lot.
#
#
# 	OPINIA ROASTERA
#
# 	Kolejny raz stosujemy tu równanie: bardzo dobre + bardzo dobre ≤ bardzo dobre. W bazie głęboka karmelowa słodycz i mnóstwo dżemowej owocowości, takiej granatowej, z lasu. A jako joker, winno-tropikalny natural. Synergia XXI wieku.
#
#
# 	OPAKOWANIE
#
# 	Kawa spakowana jest w brązowy słoik wykonany z PET, w 100% nadający się do recyklingu lub ponownego wykorzystania. I jeśli teraz myślisz „o nie, plastik!”, to pamiętaj, że standardowe opakowania na kawę są także z plastiku (i kilku innych materiałów, przez co często są trudniejsze do przetworzenia). Myśleliśmy też o szkle, ale jest cięższe, droższe, tłucze się i, uwaga, ma taki sam lub większy (sic!) wpływ na środowisko! Plastikowy słoik okazuje się być całkiem eco-friendly, pamiętaj tylko o wrzuceniu go do odpowiedniego pojemnika, albo znajdź kreatywny sposób, by wykorzystać go w domu.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 56,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 56,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Story Coffee - Poranny Klasyk Morning Brew Filter 1kg
#
#
# Producent: Story Coffee Roasters
# Data palenia:
# 21.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Gwatemali, wypalona w warszawskiej palarni Story Coffee Roasters. Palona jasno, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. Kawa charakteryzuje się nutami czekolady, orzechów i czerwonych winogron.
#
# 	Kraj pochodzenia kawy: Gwatemala
# 	Region:&nbsp;Acatenango
# 	Farma: Finca La Soledad
# 	Producent: Rodzina Perez
# 	Metoda obróbki:&nbsp;Washed
# 	Odmiana: Red&nbsp;Bourbon
# 	Położenie upraw: 1400 - 1700 m n.p.m.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 133,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 133,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Johan & Nyström - Bold Statement Filter 250g
#
#
# Producent: Johan & Nyström
# Data palenia:
# 09.01.2024
#
#
#
# Tęsknisz za Brazylią Fortaleza? Sprawdź Bold Statement od Johan &amp; Nyström.
#
# 	Kawa ziarnista&nbsp;jakości specialty pochodząca z Brazylii, wypalona w szwedzkiej palarni Johan &amp; Nyström.&nbsp;Palona w jasnym stopniu, sprawdzi się&nbsp; do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa i innych alternatywnych metod parzenia. Można tu wyczuć nuty czekolady, orzechów laskowych i słodkich migdałów.
#
# 	Kraj pochodzenia ziarna:&nbsp;Brazylia
# 	Region: Mocoa
# 	Farma/Producent: Croce Family
# 	&nbsp;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Heresy - Kolumbia El Placer Double Carbonic White Honey Geisha Filter 126g
#
#
# Producent: Heresy
# Data palenia:
# 13.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Kolumbii, wypalona w palarni Heresy przez Wicemistrza Polski Roasting 2020. Palona jasno, przeznaczona do przelewowych metod parzenia lub zalania w kubku. Profil charakteryzujący się cukierkową słodyczą, owocowością i nutami kwiatowymi.
#
# 	Kraj pochodzenia ziarna:&nbsp; Kolumbia
# 	Region:&nbsp;Quindio
# 	Odmiana: geisha
# 	Producent: Sebastian Ramirez
# 	Obróbka: double carbonic white honey
# 	Położenie upraw: 1800 m n.p.m.
# 	Zbiór: 2023
# 	Wynik w cuppingu: 90+ / 100 punktów
#
#
# 	OBRÓBKA
#
# 	Podwójna fermentacja z wykorzystaniem techniki carbonic maceration. Najpierw wiśnie w całości spędzają sobie 2 dni w szczelnych tankach, w towarzystwie dwutlenku węgla. Następnie depulping – oddzielanie ziarna od owocu. Potem kolejne dwa dni fermentacji, tym razem pod wodą i suszenie.
#
#
# 	PRODUCENT
#
# 	Sebastian to jeden z tych najbardziej innowacyjnych i szalonych na punkcie jakości kolumbijskich producentów. Egzotyczne odmiany botaniczne, laboratoryjny sprzęt do processingu, otwarta głowa i chęć do przesuwania barier, o tym tu mówimy. El Placer to światowy poziom kawowej rozkminki.
#
#
# 	OPINIA ROASTERA
#
# 	Czy to najdroższa kawa w herezyjnej historii? Tak. Czy to najlepsza kawa, jaką zamknęliśmy w słoik? Fair enough. To jest, proszę Państwa, top topów, walizka Marcellusa, kociołek przy tęczy, i tak dalej. Absolutny, światowy majstersztyk producencki. Moglibyśmy użyć jeszcze tysiąca słów, ale polećmy zenem: po prostu spróbuj.
#
#
# 	OPAKOWANIE
#
# 	Kawa spakowana jest w brązowy słoik wykonany z PET, w 100% nadający się do recyklingu lub ponownego wykorzystania. I jeśli teraz myślisz „o nie, plastik!”, to pamiętaj, że standardowe opakowania na kawę są także z plastiku (i kilku innych materiałów, przez co często są trudniejsze do przetworzenia). Myśleliśmy też o szkle, ale jest cięższe, droższe, tłucze się i, uwaga, ma taki sam lub większy (sic!) wpływ na środowisko! Plastikowy słoik okazuje się być całkiem eco-friendly, pamiętaj tylko o wrzuceniu go do odpowiedniego pojemnika, albo znajdź kreatywny sposób, by wykorzystać go w domu.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 97,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 97,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# LaCava - Rwanda Bukonya Washed Filter 250g (outlet)
#
#
# Producent: LaCava
# Data palenia:
# 06.09.2023
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Rwandy, wypalona przez palarnię&nbsp;LaCava. Palona jasno, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. W smaku wyczuwalne są nuty&nbsp;śliwki, miodu, herbaty i maliny.
# Kraj pochodzenia kawy: Rwanda
# Region: Northern Providence, Gakenke District
# Metoda obróbki: Washed
# Odmiana:&nbsp;Bourbon, Typica
# Położenie upraw:&nbsp;1750 - 2100 m n.p.m.
# Punkty w cuppingu:&nbsp;86+ / 100 pkt
#
#
# Najniższa cena: 55,25 zł
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 45,50zł
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 45,50zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Coffeelab - Salwador Finca Andalucia Washed Espresso 250g
#
#
# Producent: Coffeelab
# Data palenia:
# 19.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Salwadoru, wypalona w z warszawskiej palarni Coffeelab. Palona w średnim stopniu, przeznaczona do espresso - sprawdzi się w ekspresach ciśnieniowych i kawiarkach.&nbsp;Kawa o nutach orzechów laskowych, toffi i jabłka.
#
# 	Kraj pochodzenia ziarna: Salwador
# 	Region: Canton el Arco , Cocepcion de Ataco, Ahuachapan
# 	Odmiana:&nbsp;Bourbon, Caturra, Pacamara, Catimor
# 	Obróbka: Washed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 31,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 31,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Johan & Nyström - Delicious Days Filter 250g
#
#
# Producent: Johan & Nyström
# Data palenia:
# 09.01.2024
#
#
#
# Tęsknisz za Salwadorem Menendez? Sprawdź&nbsp;Delicious Days&nbsp;od Johan &amp; Nyström.
#
# 	Kawa ziarnista jakości specialty pochodząca z Salwadoru, wypalana przez szwedzką palarnie Johan &amp; Nystrom. Palona jasno, sprawdzi się przede wszystkim w przelewowych metodach parzenia.&nbsp;Fortaleza jest doskonale zbalansowana, o naturalnych nutach soczystej pomarańczy, nugatu i chrupiącego czerwonego jabłka.
# 	&nbsp;
#
# 	Kraj pochodzenia ziarna:&nbsp;Salwador
# 	Producent: rodzina Menendez
# 	&nbsp;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kafar - Brazylia Monte Carmelo Natural Espresso 1kg
#
#
# Producent: Kafar
# Data palenia:
# 13.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Brazylii, wypalona w gliwickiej palarni Kafar. Palona w ciemnym stopniu, idealna do ekspresu ciśnieniowego i kawiarki. W jej smaku można wyczuć nuty czekolady deserowej, toffi i suszonych owoców. Pełne, gładkie body.&nbsp;
#
# 	Kraj pochodzenia kawy: Brazylia
# 	Farma:&nbsp;Monte Carmelo i Chapadao de Ferro
# 	Metoda obróbki:&nbsp;Natural
# 	&nbsp;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 111,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 111,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hard Beans - Gwatemala San Martin Jilotepeque Washed Espresso 500g (outlet)
#
#
# Producent: Hard Beans
# Data palenia:
# 26.11.2023
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Gwatemali, wypalana przez polską palarnię Hard Beans.&nbsp;Kawa palona w średnim stopniu, przeznaczona do espresso - doskonale sprawdzi się w ekspresach ciśnieniowych i kawiarkach.&nbsp;W jej smaku wyczujesz nuty przypominające syrop klonowy, pistacje i jabłka
# Kraj pochodzenia ziarna: Gwatemala
# Region: San Martin, Jilotepeque
# Metoda obróbki: Washed
# Odmiana: Bourbon, Typica, Caturra, Catuai
# Położenie upraw:&nbsp;1600 - 1800 m n.p.m.
#
#
# Najniższa cena: 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
# 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 64,90zł
#
#
#
# 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 79,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 64,90zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zestaw kawa Mad Jungle FIL + klips
#
#
# Producent: Coffeedesk
# Data palenia:
# 22.11.2023
#
#
#
# Hi! Coffeedesk - Mad Jungle Filter 250g - Jak w życiu! Gdy poznajesz szaloną i kapryśna osobowość, bez której nie wyobrażasz sobie letniego cold brew. Orzeźwiająco-cytrusowy rozmach dla prawdziwych koneserów. Ekscesy, fanaberie i soczysta rozkosz podniebienia dla odważnych entuzjastów.
# Hi! Coffeedesk - Klips do opakowania - Klips Hi! Coffeedesk do zamykania opakowań kawy i herbaty. Pozwala na uszczelnienie paczki w szybki i prosty sposób. Zabezpieczenie produktów przed dostępem tlenu pozwala dłużej zachować ich smak. Wykonany ze stali nierdzewnej, ozdobiony logo. Jego długość wynosi 5,1cm, szerokość 2cm.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
# 71,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 61,90zł
#
#
#
# 71,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 71,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 61,90zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Johan & Nyström - Etiopia Tesfaye Bekele Washed Filter 250g
#
#
# Producent: Johan & Nyström
# Data palenia:
# 28.11.2023
#
#
#
# Kawa ziarnista&nbsp;jakości specialty pochodząca z Etiopii, wypalona w szwedzkiej palarni Johan &amp; Nyström.&nbsp;Palona w jasnym stopniu, sprawdzi się&nbsp; do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa i innych alternatywnych metod parzenia.&nbsp;W filiżance można wyczuć lemoniadę, brzoskwinię i zieloną herbatę.
#
# 	Kraj pochodzenia ziarna:&nbsp;Etiopia
# 	Farma:&nbsp;Suke Quto
# 	Producent:&nbsp;Tesfaye Bekele
# 	Położenie upraw: 1800 - 2200&nbsp; m n.p.m.
# 	Odmiana:&nbsp;Welicho, Kurume
# 	Obróbka: Washed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 72,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 72,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# COFFEE PLANT - Brazylia Lua Roxa Espresso 250g
#
#
# Producent: COFFEE PLANT
# Data palenia:
# 14.01.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Brazylii, wypalona w polskiej palarni&nbsp;COFFEE PLANT. Palona w średnim stopniu, sprawdzi się w ekspresach ciśnieniowych i kawiarkach. W smaku wyczuwalne są nuty&nbsp;wanilii, orzechów i białej czekolady.
# Kraj pochodzenia kawy: Brazylia
# Region: Minas Gerais, Cerrado
# Odmiana: Bourbon, Mudo Nuovo
# Metoda obróbki: Natural
# Położenie upraw:&nbsp;800 - 1300 m n.p.m.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 35,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 35,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Heresy - Illuminati Blend Espresso 252g
#
#
# Producent: Heresy
# Data palenia:
# 19.02.2024
#
#
#
# Co powstaje z połączenia Gwatemali z Gwatemalą? Jeszcze więcej Gwatemali w Gwatemali! Ten kraj to nasz ukochany region, do którego robimy regularne wyjazdy, zawsze zaskakując się tym, jak różnorodne kawy potrafi zaserwować. Jeśli Gwatemala kojarzy Ci się z klasycznym smakiem, to Amigo, zazdrościmy Ci jak wiele masz jeszcze do odkrycia! Mamy nadzieję, że lubisz dżemik!
#
# 	Mieszanka kaw ziarnistych jakości specialty, wypalona w palarni Heresy przez Wicemistrza Polski Roasting 2020. Palona średnio, przeznaczona do espresso, kawiarki lub zaparzania w kubku. Profil zbalansowany w smaku, łączący klasyczne i bardziej owocowe nuty, dostarczający wrażeń zarówno fanom tradycyjnych jak i nowoczesnego espresso. Uniwersalne espresso - zarówno pod shota jak i pod mleko. Zarówno dla kawiarni, jak i do domu. Na stałe w heretycznej ofercie!
#
# 	Kraj pochodzenia ziarna: Gwatemala
# 	Producent: mali producenci z regionu Jalapa
# 	Farma: San Martin i Santa Rosa
# 	Odmiana: caturra i bourbon
# 	Obróbka: washed i natural
# 	Położenie upraw: 1600 - 2200 m n.p.m.
#
#
# 	OBRÓBKA
#
# 	Mamy tu połączenie mytej i naturalnej obróbki kaw odmiany caturra i bourbon. San Martin to klasyczny washed. Santa Rosa to bardziej pofermentowany naturalnie wariacik. Mytonatural blend!
#
#
# 	FARMA
#
# 	Kawy z San Martin i Santa Rosa to blendy pochodzące od małych lokalnych producentów z regionu Jalapa. Ich zbiory są łączone i wspólnie obrabiane jako jeden lot.
#
#
# 	OPINIA ROASTERA
#
# 	Kolejny raz stosujemy tu równanie: bardzo dobre + bardzo dobre ≤ bardzo dobre. W bazie głęboka karmelowa słodycz i mnóstwo dżemowej owocowości, takiej granatowej, z lasu. A jako joker, winno-tropikalny natural. Synergia XXI wieku.
#
#
# 	OPAKOWANIE
#
# 	Kawa spakowana jest w brązowy słoik wykonany z PET, w 100% nadający się do recyklingu lub ponownego wykorzystania. I jeśli teraz myślisz „o nie, plastik!”, to pamiętaj, że standardowe opakowania na kawę są także z plastiku (i kilku innych materiałów, przez co często są trudniejsze do przetworzenia). Myśleliśmy też o szkle, ale jest cięższe, droższe, tłucze się i, uwaga, ma taki sam lub większy (sic!) wpływ na środowisko! Plastikowy słoik okazuje się być całkiem eco-friendly, pamiętaj tylko o wrzuceniu go do odpowiedniego pojemnika, albo znajdź kreatywny sposób, by wykorzystać go w domu.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 56,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 56,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Story Coffee - Poranny Klasyk Morning Brew Filter 1kg
#
#
# Producent: Story Coffee Roasters
# Data palenia:
# 21.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Gwatemali, wypalona w warszawskiej palarni Story Coffee Roasters. Palona jasno, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. Kawa charakteryzuje się nutami czekolady, orzechów i czerwonych winogron.
#
# 	Kraj pochodzenia kawy: Gwatemala
# 	Region:&nbsp;Acatenango
# 	Farma: Finca La Soledad
# 	Producent: Rodzina Perez
# 	Metoda obróbki:&nbsp;Washed
# 	Odmiana: Red&nbsp;Bourbon
# 	Położenie upraw: 1400 - 1700 m n.p.m.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 133,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 133,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Johan & Nyström - Bold Statement Filter 250g
#
#
# Producent: Johan & Nyström
# Data palenia:
# 09.01.2024
#
#
#
# Tęsknisz za Brazylią Fortaleza? Sprawdź Bold Statement od Johan &amp; Nyström.
#
# 	Kawa ziarnista&nbsp;jakości specialty pochodząca z Brazylii, wypalona w szwedzkiej palarni Johan &amp; Nyström.&nbsp;Palona w jasnym stopniu, sprawdzi się&nbsp; do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa i innych alternatywnych metod parzenia. Można tu wyczuć nuty czekolady, orzechów laskowych i słodkich migdałów.
#
# 	Kraj pochodzenia ziarna:&nbsp;Brazylia
# 	Region: Mocoa
# 	Farma/Producent: Croce Family
# 	&nbsp;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 58,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# Heresy - Kolumbia El Placer Double Carbonic White Honey Geisha Filter 126g
#
#
# Producent: Heresy
# Data palenia:
# 13.02.2024
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Kolumbii, wypalona w palarni Heresy przez Wicemistrza Polski Roasting 2020. Palona jasno, przeznaczona do przelewowych metod parzenia lub zalania w kubku. Profil charakteryzujący się cukierkową słodyczą, owocowością i nutami kwiatowymi.
#
# 	Kraj pochodzenia ziarna:&nbsp; Kolumbia
# 	Region:&nbsp;Quindio
# 	Odmiana: geisha
# 	Producent: Sebastian Ramirez
# 	Obróbka: double carbonic white honey
# 	Położenie upraw: 1800 m n.p.m.
# 	Zbiór: 2023
# 	Wynik w cuppingu: 90+ / 100 punktów
#
#
# 	OBRÓBKA
#
# 	Podwójna fermentacja z wykorzystaniem techniki carbonic maceration. Najpierw wiśnie w całości spędzają sobie 2 dni w szczelnych tankach, w towarzystwie dwutlenku węgla. Następnie depulping – oddzielanie ziarna od owocu. Potem kolejne dwa dni fermentacji, tym razem pod wodą i suszenie.
#
#
# 	PRODUCENT
#
# 	Sebastian to jeden z tych najbardziej innowacyjnych i szalonych na punkcie jakości kolumbijskich producentów. Egzotyczne odmiany botaniczne, laboratoryjny sprzęt do processingu, otwarta głowa i chęć do przesuwania barier, o tym tu mówimy. El Placer to światowy poziom kawowej rozkminki.
#
#
# 	OPINIA ROASTERA
#
# 	Czy to najdroższa kawa w herezyjnej historii? Tak. Czy to najlepsza kawa, jaką zamknęliśmy w słoik? Fair enough. To jest, proszę Państwa, top topów, walizka Marcellusa, kociołek przy tęczy, i tak dalej. Absolutny, światowy majstersztyk producencki. Moglibyśmy użyć jeszcze tysiąca słów, ale polećmy zenem: po prostu spróbuj.
#
#
# 	OPAKOWANIE
#
# 	Kawa spakowana jest w brązowy słoik wykonany z PET, w 100% nadający się do recyklingu lub ponownego wykorzystania. I jeśli teraz myślisz „o nie, plastik!”, to pamiętaj, że standardowe opakowania na kawę są także z plastiku (i kilku innych materiałów, przez co często są trudniejsze do przetworzenia). Myśleliśmy też o szkle, ale jest cięższe, droższe, tłucze się i, uwaga, ma taki sam lub większy (sic!) wpływ na środowisko! Plastikowy słoik okazuje się być całkiem eco-friendly, pamiętaj tylko o wrzuceniu go do odpowiedniego pojemnika, albo znajdź kreatywny sposób, by wykorzystać go w domu.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 97,00zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 97,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# LaCava - Rwanda Bukonya Washed Filter 250g (outlet)
#
#
# Producent: LaCava
# Data palenia:
# 06.09.2023
#
#
#
# Kawa ziarnista jakości specialty pochodząca z Rwandy, wypalona przez palarnię&nbsp;LaCava. Palona jasno, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. W smaku wyczuwalne są nuty&nbsp;śliwki, miodu, herbaty i maliny.
# Kraj pochodzenia kawy: Rwanda
# Region: Northern Providence, Gakenke District
# Metoda obróbki: Washed
# Odmiana:&nbsp;Bourbon, Typica
# Położenie upraw:&nbsp;1750 - 2100 m n.p.m.
# Punkty w cuppingu:&nbsp;86+ / 100 pkt
#
#
# Najniższa cena: 55,25 zł
#
#
#
#
#
#
#
#
#
#
#
#
# Przenieś do ulubionych
#
#
#
#
#
#
#
#
# Usuń z listy życzeń
#
#
#
#
#
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 45,50zł
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 45,50zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 HAYB - Się Przelewa Klasyk Filter Blend 250g
#
#
# Producent: HAYB
# Data palenia: 06.02.2024
#
#
#
# 	Mieszanka kaw ziarnistych jakości speciality wypalona w warszawskiej palarni HAYB. W opakowaniu znajdziesz minimum 85% ziaren z Brazylii i około 15% arabiki różnego pochodzenia.
#
# 	Kawa jest palona jasno, polecana szczególnie do kawiarni  jako ziarno do gastronomicznych ekspresów przelewowych. Sprawdzi się również do dripa, Chemexa, AeroPressa, French Pressa oraz innych alternatywnych metod parzenia.
# Mieszanka składa się z kaw:
#
# - 85% Brazylia
# - 15% Arabica
#
#
#
#
#
# 	Opinia roastera:
# NA POCZĄTKU BYŁ KLASYK!
#
# To nie przelewki – Się Przelewa Klasyk to nasz pierwszy taki przelewik, blend, który sprawił, że zaczęło Się Przelewać. I przelewa do dziś. Tak zdaniem wielu smakuje wzorcowy przelew – niezobowiązująca kawa, oparta o Brazylię z niewielkimi domieszkami bardziej owocowej Afryki. To propozycja, która wręcz mówi „zapraszam do świata speciality” – i tak sobie grzecznie za nią wchodzisz, a potem zostajesz na dłużej!
#
# Seria SIĘ PRZELEWA to w ogóle proste sytuacje. Kawka nie wymaga od Ciebie skrupulatnego liczenia klików, będzie dobra, możesz wsypać ją do ekspresu przelewowego bez wyrzutów sumienia – po prostu Effortless Speciality.
#
# Jej supermoce (poza przystępnością i niską ceną) to łagodny smak i niska kwasowość, możesz stosować ją we wszystkich metodach przelewowych: wrzuć ją do swojego ekspresu – nieważne czy to Melitta, czy Moccamasster – strzel sobie Chemex, Aeropress, V60, french press czy co tam sobie zażyczysz. Będzie pysznie!
#
#
#
# 	Metody parzenia:
#
#
#
# 	O palarni:
#
#
# HAYB to warszawska palarnia kawy speciality, która robi swoją robotę porządnie i z uśmiechem - lubią kawę, coś o niej wiedzą, robią ją - wyobrażacie sobie lepszy układ? Chodzi o to, żeby smakowało bez czarów, dlatego ich motto to Effortless Speciality. Wśród kaw HAYB znajdziesz jedynie ziarno jakości speciality, zarówno pod przelewowe metody parzenia, jak i pod espresso, single oraz blendy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    34,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Lavazza Crema e Aroma
#
#
# Producent: Lavazza
#
#
#
# 	Wyśmienita mieszanka najlepszych odmian Arabiki i Robusty. Jej intensywny smak na długo pozostaje w ustach, a trwała pianka podkreśla jej wykwintność.
#
# 	Szczególnie polecana amatorom lekkiego espresso, popularna w wielu kawiarniach i restauracjach. Ze względu na niewielkie wymagania sprzętowe serwowana jest również w domach i biurach.
#
# 	Kawa ziarnista, o normalnym poziomie zawartości kofeiny.
#
#
#
#
#
#                     Najniższa cena: 51,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 65,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    54,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 illy Arabica Selection - Guatemala
#
#
# Producent: Illy
#
#
#
# 	illy Arabica Selection to nowa linia kaw single origin z palarni illy. Ziarna z Gwatemali charakteryzuje kompleksowy smak o delikatnych nutach karmelu, czekolady i miodu.
#
# 	Kawa w Gwatemali uprawiana jest na żyznych glebach wysoko w górach. Odpowiednie temperatury są wynikiem wpływu ruchów ciepłego powietrza znad Meksyku. To w połączeniu z dbałością farmerów daje ziarna o intensywnej aromacie, złożoności smaku i przyjemnej słodkości.
#
#
#
#                     Najniższa cena: 29,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 36,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    31,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 illy Arabica Selection - Brazylia
#
#
# Producent: Illy
#
#
#
# 	illy Arabica Selection to nowa linia ziarnistych kaw jednorodnych (single origin) z palarni illy. Ziarno jest palone w ciemnym stopniu, przeznaczone do parzenia jako espresso.
#
#
# 	Kawę z Brazylii charakteryzuje intensywny smak o naturalnych nutach karmelu. Przygotowana kawa jest kremowa i aromatyczna.
#
# 	Brazylia jest światowym liderem w produkcji arabiki. Kawowiec uprawiany jest głównie na południowym-wschodzie kraju, na dużych wysokościach, w idealnych warunkach klimatycznych.
#
#
#
#                     Najniższa cena: 31,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 36,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    31,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 HAYB - Się Przelewa Kwiat 250g
#
#
# Producent: HAYB
# Data palenia: 13.02.2024
#
#
#
# 	Kawa ziarnista jakości speciality z Etiopii, wypalona w warszawskiej palarni HAYB. Palona jasno, polecana szczególnie do kawiarni  jako ziarno do gastronomicznych ekspresów przelewowych. Sprawdzi się również do dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. W filiżance można odnaleźć kwiatowy aromat oraz nuty owocowo-herbaciane.
# Pochodzenie: Etiopia Guji
#
#
#
#
#
#
# 	Opinia roastera:
# Jej supermoce (poza przystępnością i niską ceną) to łagodny smak i niska kwasowość, możesz stosować ją we wszystkich metodach przelewowych: wrzuć ją do swojego ekspresu – nieważne czy to Melitta, czy Moccamasster – strzel sobie Chemex, Aeropress, V60, french press czy co tam sobie zażyczysz. Będzie pysznie.
#
#
# 	Metody parzenia:
#
#
#
# 	O palarni:
#
#
# HAYB to warszawska palarnia kawy speciality, która robi swoją robotę porządnie i z uśmiechem - lubią kawę, coś o niej wiedzą, robią ją - wyobrażacie sobie lepszy układ? Chodzi o to, żeby smakowało bez czarów, dlatego ich motto to Effortless Speciality. Wśród kaw HAYB znajdziesz jedynie ziarno jakości speciality, zarówno pod przelewowe metody parzenia, jak i pod espresso, single oraz blendy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    45,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Kofi Brand - Kofi Brasil Espresso 250g
#
#
# Producent: Kofi Brand
# Data palenia: 28.01.2024
#
#
#
# 	Kawa ziarnista jakości specialty z Brazylii wypalona przez warszawską palarnię Kofi Brand. Kawa palona w średnim stopniu, idealna do ekspresów ciśnieniowych oraz kawiarek. Można spodziewać się dominującej słodyczy, w smaku i aromacie pojawiają się nuty suszonych owoców, ciemnej czekolady, orzechów i słodkiego karmelu.
# Kraj pochodzenia: Brazylia
# Farma: Fazenda Rainha
# Odmiana: Yellow Bourbon
# Wysokość uprawy: 1100 - 1500 m n.p.m.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    35,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 SIMPLo - Brazylia Aguas de Marco Filter
#
#
# Producent: SIMPLo
# Data palenia: 03.01.2024
#
#
#
# 	Kawa ziarnista jakości speciality pochodząca z Brazylii, wypalona w warszawskiej palarni SIMPLo. Palona w średnio-jasnym stopniu, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa oraz innych alternatywnych metod parzenia, jednak kawa jest również warta spróbowania z kawiarki i ekspresu ciśnieniowego.
#
# 	W smaku pojawia się sporo słodyczy, szczególnie nuty przypominające czekoladę, karmel, orzechy i owoce pestkowe, szczególnie śliwka i nektarynka. Spróbuj także z odrobiną mleka dla podbicia nut orzechowych.
# Kraj pochodzenia kawy: Brazylia
# Region: Minas
# Położenie upraw: 1150 - 1350 m n.p.m.
# Odmiana: Yellow Bourbon
# Metoda obróbki: Pulped natural
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    43,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 illy Classico - Moka Pot - Kawa mielona
#
#
# Producent: Illy
#
#
#
# 	Bardzo aromatyczna z wyraźnym i smacznym body, taka jest illy Moka, stworzona i zmielona specjalnie do parzenia w tradycyjnych kawiarkach.
#
# 	Zmielona nieco grubiej niż w przypadku mielonych kaw przeznaczonych do espresso, Illy moka oferuje lepsze doznania smakowe przy parzeniu w mokach.
#
# 	Jest to wyrafinowana mieszanka ziaren Arabiki z gładkim, bogatym i pełnym body. Idealnie nadaje się na dobry początek dnia!
#
#
#
#
#                     Najniższa cena: 31,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 36,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    31,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 illy Arabica Selection - Ethiopia
#
#
# Producent: Illy
#
#
#
# 	illy Arabica Selection to nowa linia kaw single origin z palarni illy. Ziarna z Etiopii charakteryzuje łagodna kwaskowatość i delikatny kwiatowy, jaśminowy aromat.
#
# 	Etiopia to kraj, w którym rozpoczęła się historia kawy. Kawowiec często rośnie tu na dziko, jednak uprawiany jest także na farmach oraz w prywatnych ogrodach. Ziarna zbierane są ręcznie. Ziarna z tego regionu maja charakterystyczny, delikatnie kwiatowo-cytrusowy aromat.
#
#
#
#                     Najniższa cena: 31,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 36,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    31,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Pellini - Espresso Bar Vivace n 82 - 1kg
#
#
# Producent: Pellini
#
#
#
# 	Nie bez przesady można powiedzieć, że kawa to napój bogów. Czarna czy zabielana mlekiem skutecznie pobudza, podnosi koncentrację i dodaje energii przez cały dzień. Niektórzy wręcz nie wyobrażają sobie bez kawy codziennego poranka.
# 	Pellini Espresso Bar Vivace to doskonała mieszkanka kawy arabica i robusty w proporcjach 80/20. Producent szczególną dbałość przykłada do procesu palenia, który wydobywa wyrazisty smak wyselekcjonowanych ziaren. Tylko najwyższa jakość Pellini Espresso Bar Vivace jest w stanie wydobyć korzenną, lekko orzechową nutę smakową połączoną z niebywałym aromatem i zadowolić kawowych koneserów.
#
# 	Kawa Pellini Espresso Vivace nadaje się do przyrządzenia w ekspresach oraz w kawiarkach. Smakuje wybornie jako czarna solo oraz w duecie z mlekiem, zatem domowe cappuccino lub latte machiato będzie smakować idealnie.
#
# 	Pellini Espresso Bar Vivace pochodzi z włoskiej palarni kaw w Veronie. Została stworzona z miłości do tego aromatycznego napoju znanego na całym świecie. Dzięki stale rosnącemu zapotrzebowaniu producent stara się zaspokoić wymagające gusta klientów. Dbałość o każdy szczegół produkcji daje możliwość delektowania się  świeżym, mocnym wywarem kawowym, zamkniętym zarówno w czarnym espresso, jak i w  kawie na bazie mleka.
#
# 	Pellini Espresso Bar Vivace to jedna z ikon włoskiej marki o unikalnym smaku i aromacie. Wyraziste, pobudzające nuty  zapachowe sprawią, że każdy poranek będzie nasycony energią, a chwile z kawą pozwolą choć na chwilę zatrzymać czas w miejscu.
#
# Opakowanie zawiera 1kg kawy ziarnistej.
#
#
#
#                     Najniższa cena: 59,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 92,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    55,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Hard Beans - Brazylia Samambaia Filter - Kawa ziarnista 250g
#
#
# Producent: Hard Beans
# Data palenia: 21.11.2023
#
#
#
# 	Kawa ziarnista jakości specialty pochodząca z Brazylii, wypalana przez polską palarnię Hard Beans. Palona jasno, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. W smaku kawy pojawiają się naturalne nuty zbliżone do herbatników, toffi, mlecznej czekolady i czerwonych jabłek.
# Kraj pochodzenia ziarna: Brazylia
# Region: Sul de Minas
# Metoda obróbki: Pulped natural
# Odmiana: Yellow Bourbon
# Położenie upraw: 1200 m n.p.m.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    42,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
# 	Mieszanka kaw ziarnistych jakości specialty z Rwandy i Etiopii, wypalona w polskiej palarni COFFEE PLANT. Jasno palona, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. FLOW Very Berry jest bardzo słodka i jednocześnie bardzo owocowa. Łączy w sobie nuty pestkowych i czerwonych owoców. Kawa o wysokiej słodyczy z nutą czerwonych owoców takich jak wiśnie, porzeczki i śliwki.
# Kraj pochodzenia ziarna: Rwanda / Etiopia
# Metoda obróbki: Natural
# Ocena w cuppingu: 84,5 / 87 pkt.
#
#
#
#                     Najniższa cena: 31,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 44,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    36,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 HAYB - Blue Espresso Blend 250g
#
#
# Producent: HAYB
# Data palenia: 13.02.2024
#
#
#
# 	Mieszanka kaw ziarnistych jakości specialty wypalanych przez warszawską HAYB. W paczce znajdziesz ziarna z Brazylii, Gwatemali i Etiopii. Kawa palona w średnim stopniu, idealna do ekspresów ciśnieniowych i kawiarek. W jej smaku dominuje słodycz o nutach mlecznej czekolady, marcepanu i jagód, z delikatną herbacianą nutą i lżejszym body. Świetnie sprawdzi się zarówno jako czarna kawa, jak i z dodatkiem mleka.
# Mieszanka składa się z kaw:
#
# - 40% Brazylia Cerrado
# - 40% Gwatemala Huehuetenango
# - 20% Etiopia Sidamo
#
#
#
#
#
# 	Opinia roastera:
# FEELING BLUE I NIE CHODZI O SMUTEK
# Blue Espresso Blend to klasyczne dzieło, ale coś w nim mocno skręca w szaloną awangardę. I nadal mówimy o kawie!
#
# Połączyliśmy ziarna z Brazylii, Gwatemali i Etiopii, żeby wyciągnąć z nich mnóstwo słodyczy i gładkości. I mamy to: to jeden z naszych najsłodszych blendów, jest tu słodko, gładko i przyjemnie. Dodatek ziaren z Etiopii wprowadza tu nieco owocowej i herbacianej nuty – jest ciekawiej z każdym łykiem. Niby baza prawie jak Yellow, ale uwierzcie nam – to 20% robi różnicę, bo blendowanie to alchemia!
#
# Jeśli kochasz słodkie, gładkie kawki – jesteś w domu
#
#
#
# 	Metody parzenia:
#
#
#
# 	O palarni:
#
#
# HAYB to warszawska palarnia kawy speciality, która robi swoją robotę porządnie i z uśmiechem - lubią kawę, coś o niej wiedzą, robią ją - wyobrażacie sobie lepszy układ? Chodzi o to, żeby smakowało bez czarów, dlatego ich motto to Effortless Speciality. Wśród kaw HAYB znajdziesz jedynie ziarno jakości speciality, zarówno pod przelewowe metody parzenia, jak i pod espresso, single oraz blendy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    36,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 COFFEE PLANT - FLOW Juicy Fruit Filter 250g
#
#
# Producent: COFFEE PLANT
# Data palenia: 11.02.2024
#
#
#
# 	Mieszanka kaw ziarnistych jakości specialty pochodzących z Tanzanii i Etiopii, wypalona w polskiej palarni COFFEE PLANT. Jasno palona, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. FLOW Juicy Fruit łączy w sobie orzeźwiające smaki soczystych owoców z kwiatową nutą. Można w niej wyróżnić nuty akacji, brzoskwini, jaśminu, moreli i cytrusów.
# Kraj pochodzenia ziarna: Tanzana / Etiopia
# Metoda obróbki: Washed
# Ocena w cuppingu: 84,5 / 81 pkt.
#
#
#
#                     Najniższa cena: 32,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 42,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    36,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 COFFEE PLANT - Flow Brownie Filter 250g
#
#
# Producent: COFFEE PLANT
# Data palenia: 11.02.2024
#
#
#
# 	Mieszanka kaw ziarnistych jakości specialty pochodzących z Brazylii i Kenii, wypalona w polskiej palarni COFFEE PLANT. Jasno palona, idealna do ekspresu przelewowego, dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. Flow Brownie to klasyczna kawa pozbawiona kwasowości, która łączy w sobie nuty czekolady, orzechów, rodzynek i śliwki.
# Kraj pochodzenia ziarna: Brazylia / Kenia
# Metoda obróbki: Natural / Anaerobic
# Ocena w cuppingu: 84 / 86,5 pkt.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    37,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Audun Coffee - Brazylia Fazenda Rainha Miaki Espresso 250g
#
#
# Producent: Audun Coffee
# Data palenia: 05.02.2024
#
#
#
# 	Kawa ziarnista jakości speciality pochodząca z Brazylii, wypalona przez Mistrza Świata Roasterów 2015, Auduna Sorbottena. Kawa palona w średnim stopniu, przeznaczona do espresso i kawiarek. Charakteryzuje się intensywną czekoladowo-orzechową słodyczą oraz niską kwasowością.
#
# 	Rodzina Miaki zajmuje się uprawą kawy już od ponad 40 lat. Pokolenie, które obecnie zajmuje się uprawami, czerpało wiedzę od swoich rodziców oraz posiłkowało się studiami w kierunku upraw. Plantacje są prowadzone z dbałością o środowisko naturalne, dzięki czemu część farm zdobyła certyfikację UTZ oraz Rainforest Alliance.
#
# 	Kraj: Brazylia
# 	Region: Minas Gerais
# 	Wysokość: 1050 - 1250 m n.p.m.
# 	Odmiana: Yellow Bourbon
# 	Proces: Pulped natural
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    35,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Gardelli Specialty Coffees - Cignobianco Espresso Blend 250g
#
#
# Producent: Gardelli Specialty Coffees
# Data palenia: 12.12.2023
#
#
#
# 	Cignobianco to interpretacja idealnego espresso według Rubensa Gardelliego, Mistrza Świata w wypalaniu kawy z 2017 roku. Palona w ciemnym stopniu, sprawdzi się idealnie w ekspresach ciśnieniowych i kawiarkach.
#
# 	Kawa jest kremowa, słodka, o długim finiszu i z przyjemną kwaskowatością. Można to osiągnąć dzięki ziarnom z arabiki z zakresu specialty. Świeże ziarna wypalane są oddzielnie i mieszane na koniec.
#
# 	Kawa świetnie sprawdzi się w ekspresie lub w kawiarce. Odnajdziesz w niej nuty mlecznej czekolady, migdałów, żółtych śliwek i karmelu.
#
# 	Mieszanka składa się z dwóch rodzajów ziaren arabiki:
#
# 	Kraj: Brazylia / Etiopia
# 	Region: Mantiqueira de Minas / Sidama
# 	Odmiana: Red Catuaì / Heirloom
# 	Metoda obróbki: Natural / Washed
# 	Wysokość: 1000 - 1900 m n.p.m.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    58,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Le Piantagioni del Caffe - Water Decaf - Kawa bezkofeinowa 250g
#
#
# Producent: Le Piantagioni del Caffè
#
#
#
# 	Kawa bezkofeinowa wypalana przez cenioną włoską palarnię Le Piantagioni del Caffè. Ziarno to 100% arabika pochodząca z Brazylii. W filiżance można spodziewać się przede wszystkim słodyczy o nutach czekoladowo-orzechowych.
#
# 	Brak kofeiny wcale nie musi równać się brakowi smaku! Ziarno z brazylijskiego regionu Cerrado oferuje przyjemną słodycz i minimalną zawartość kofeiny. Proces dekofeinizacji jest przeprowadzany bez użycia sztucznych substancji chemicznych - ziano jest poddawane działaniu pary wodnej i płukaniu w wodzie.
#
#
#
#                     Najniższa cena: 33,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 48,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    46,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Kofi Brand - Brazylia Guaxupe Espresso 1kg
#
#
# Producent: Kofi Brand
# Data palenia: 03.01.2024
#
#
#                                     Brazylijskie ziarno jakości specialty wypalone przez Kofi Brand. Kawa palona w średnim stopniu, idealna do ekspresów ciśnieniowych oraz kawiarek. W jej smaku pojawia się ciemna czekolada, miód i prażone migdały.
#
# 	Kraj pochodzenia: Brazylia
# 	Region: Minas Gerais
# 	Obróbka: Natural
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    109,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Hard Beans - Polska Parzucha - Kawa ziarnista 250g
#
#
# Producent: Hard Beans
# Data palenia: 28.01.2024
#
#
#
# 	Kawa ziarnista, klasyk gatunku, powrót do narodowych korzeni - wyrafinowana kawa dedykowana zagorzałym entuzjastom konwencjonalnych smaków.
#
# 	Starannie wyselekcjonowana mieszanka arabik pochodzących z Ameryki Środkowej i Południowej zadowoli nawet najbardziej wymagające podniebienia. Palona w średnim stopniu, sprawdzi się jako klasyczna parzucha, uda się ją zaparzyć w dripie, wszelkich akcesoriach przelewowych, french pressie, a także da radę w kawiarce.
#
# 	Połączenie niebanalnej słodyczy czekolady i orzechów włoskich oraz nadzwyczajnej cielistości, dopełnione subtelnym muśnięciem kwasowości to cechy, które wyróżniają ją na tle kawowej przeciętności. Znakomity wybór dla kawowych tradycjonalistów.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    30,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 Arcaffe Roma 1kg
#
#
# Producent: Arcaffe
#
#
#
# 	Roma to najbardziej klasyczna mieszanka z Arcaffe. Produkowana niezmiennie od 1926 (wyłączając czas wojny). Jej nazwa to hołd dla baru Roma, który był pierwszym espresso barem w Livorno skąd pochodzi palarnia.
#
# 	Roma to kawa o kompleksowym, i jednocześnie delikatnym profilu smakowym z wyraźnym tytoniowym finiszem, który zawdzięcza kawie z Indii wchodzącej w jej skład. Aromat to karmel, delikatne wypieki oraz leśne owoce - te ostatnie to zasługa ziaren z Etiopii. Delikatne body, średnia kwasowość oraz wyraźna słodycz obecne są dzięki kawom z Ameryki Pd. - głównie Brazylii.
#
# 	Kawa ta świetnie sprawdzi się jako espresso - bez żadnych dodatków najlepiej pokazuje swoje oblicze i pozwala docenić obecność poszczególnych arabik wchodzących w jej skład. Każde ziarno ma tutaj swoje '5 minut', a efekt końcowy jest dowodem na kunszt twórców te mieszanki. Warto również wspomnieć, że wszystkie składniki są wypalane osobno i mieszane dopiero po zakończeniu tego procesu. Pozwala to na indywidualne dopasowanie profilów palenia dla poszczególnych ziaren i wydobycie ich charakteru w najwyższym stopniu.
#
# 	Roma połączona z mlekiem da nam niezwykle delikatne, kremowe i słodkie cappuccino - orzechy brazylijskie, mleczna czekolada, owsianka - idealna kombinacja na rozpoczęcie nowego dnia.
#
# 	Receptura:
# 	Doza: 16 g
# 	Uzysk: 32-36g
# 	Czas ekstrakcji: 27-32 sek.
# 	Temp: 94 C
#
# 	Ziarna, które znajdują się w mieszance to:
# 	- Gwatemala, Finca El Hato Blue
# 	- Etiopia, Sidamo special selection
# 	- Salwador, Finca San Luis
# 	- Brazylia - washed, Fazenda Lagoa do Morro
# 	- Indie, Vellakadai estate
# 	- Brazylia - natural, Fazenda Samambaia
#
# 	Są to kawy certyfikowane przez "CSC ® - Certified Speciality Coffee Association of Italy" - wszystkie opakowania są opatrzone etykietą z numerem i hologramem świadczącym o wysokiej jakości i zapobiegającym fałszerstwom.
#
# 	Więcej o tej kawie przeczytasz na naszym Blogu: https://www.coffeedesk.pl/blog/espresso-miesiaca-luty-arcaffe-roma/
#
#
#
#
#
#                     Najniższa cena: 108,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 139,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    109,90 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 HAYB - Black Espresso Blend 250g
#
#
# Producent: HAYB
# Data palenia: 12.02.2024
#
#
#
# 	Mieszanka wysokiej jakości ziarna arabiki oraz indyjskiej robusty, wypalana w warszawskiej HAYB. W paczce znajdziesz ziarno z Brazylii i Indii. Kawa palona w ciemnym stopniu - we Włoskim stylu, sprawdzi się pod espresso i do kawiarek. Po zaparzeniu jest gęsta i kremowa, o nutach gorzkiej czekolady, orzechów i melasy. Doskonała zarówno dla miłośników czarnych kaw, jak i napojów mlecznych.
# Mieszanka składa się z kaw:
#
# - Brazylia Cerrado (80%)
# - Indie Parchment (20%)
#
#
#
#
#
# 	Opinia roastera:
# To klasyka w czystym wydaniu, we włoskim stylu, dla kawowych tradycjonalistów.
#
# Polecamy jako mocne espresso lub bazę do kaw mlecznych. Dużo ciemnej czekolady, prażonych orzechów, melasy. To gęsta, słodka, mocna i wyrazista kawa! Ideał dla tych, co nie lubią kwasowości w kawie.
#
#
# 	Metody parzenia:
#
#
#
# 	O palarni:
#
#
# HAYB to warszawska palarnia kawy speciality, która robi swoją robotę porządnie i z uśmiechem - lubią kawę, coś o niej wiedzą, robią ją - wyobrażacie sobie lepszy układ? Chodzi o to, żeby smakowało bez czarów, dlatego ich motto to Effortless Speciality. Wśród kaw HAYB znajdziesz jedynie ziarno jakości speciality, zarówno pod przelewowe metody parzenia, jak i pod espresso, single oraz blendy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    28,00 zł
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 HAYB - Się Przelewa Tropik Filter 250g
#
#
# Producent: HAYB
# Data palenia: 13.02.2024
#
#
#
# 	Kawa ziarnista jakości speciality z Kolumbii, wypalona w warszawskiej palarni HAYB. Palona jasno, polecana szczególnie do kawiarni  jako ziarno do gastronomicznych ekspresów przelewowych. Sprawdzi się również do dripa, Chemexa, AeroPressa, French Pressa, oraz innych alternatywnych metod parzenia. W filiżance można odnaleźć nuty dojrzałych owoców, karmelu oraz rumu.
# Mieszanka składa się z kaw:
#
# - 100% Kolumbia
#
#
#
#
#
#
# 	Opinia roastera:
# ŻAR TROPIKÓW!
#
# To nie przelewki – Się Przelewa Tropik to czwarty (i najnowszy) przelewik z serii, taki owocowy, ale inaczej niż Owoc. Tej kawy potrzebowaliśmy wszyscy – i w końcu ją mamy. Domknęliśmy kwartet tropikalnie owocową Kolumbią w wydaniu daily – a jej atrakcyjna cena zachęca do wypicia jeszcze jednej kawki i kolejnej!
#
# Seria SIĘ PRZELEWA to w ogóle proste sytuacje. Kawka nie wymaga od Ciebie skrupulatnego liczenia klików, będzie dobra, możesz wsypać ją do ekspresu przelewowego bez wyrzutów sumienia – po prostu Effortless Speciality.
#
# Jej supermoce (poza przystępnością i niską ceną) to łagodny smak i niska kwasowość, możesz stosować ją we wszystkich metodach przelewowych: wrzuć ją do swojego ekspresu – nieważne czy to Melitta, czy Moccamasster – strzel sobie Chemex, Aeropress, V60, french press czy co tam sobie zażyczysz. Będzie pysznie!
#
#
#
# 	Metody parzenia:
#
#
#
# 	O palarni:
#
#
# HAYB to warszawska palarnia kawy speciality, która robi swoją robotę porządnie i z uśmiechem - lubią kawę, coś o niej wiedzą, robią ją - wyobrażacie sobie lepszy układ? Chodzi o to, żeby smakowało bez czarów, dlatego ich motto to Effortless Speciality. Wśród kaw HAYB znajdziesz jedynie ziarno jakości speciality, zarówno pod przelewowe metody parzenia, jak i pod espresso, single oraz blendy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Przenieś do ulubionych
#
#
#
#
#
#
#  Usuń z listy życzeń
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									                				    49,00 zł
