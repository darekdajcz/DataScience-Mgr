# %%
# !pip install selenium
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: selenium in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (4.26.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.18)
# Requirement already satisfied: trio~=0.17 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from selenium) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: wsproto>=0.14 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: beautifulsoup4 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/darekdajcz/anaconda3/lib/python3.10/site-packages (from beautifulsoup4) (2.5)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
ds = Service()
driver = webdriver.Chrome(service=ds)

# %%
driver.get(r"https://www.mediaexpert.pl/komputery-i-tablety/laptopy-i-ultrabooki/laptopy?page=1")

# %%
from selenium.webdriver.common.by import By
import time
time.sleep(3)

# Akceptujemy wszystkie ciasteczka
try:
    accept_cookies_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
    accept_cookies_button.click()
    print("Kliknięto przycisk akceptacji ciasteczek")
except:
    print("Przycisk akceptacji ciasteczek nie został znaleziony")

# %%
elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'box')]/h2/a[contains(@class, 'is-animate ui-link')]")

# Iterujemy po znalezionych elementach i wypisujemy ich teksty
for element in elements:
    print("Pobrany tekst:", element.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'box')]/h2/a[contains(@class, 'is-animate ui-link')]")
#       3 # Iterujemy po znalezionych elementach i wypisujemy ich teksty
#       4 for element in elements:
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:788, in WebDriver.find_elements(self, by, value)
#     784     return self.execute_script(find_element_js, by.to_dict())
#     786 # Return empty list if driver returns null
#     787 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 788 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:380, in WebDriver.execute(self, driver_command, params)
#     378 response = self.command_executor.execute(driver_command, params)
#     379 if response:
# --> 380     self.error_handler.check_response(response)
#     381     response["value"] = self._unwrap_value(response.get("value", None))
#     382     return response
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=130.0.6723.119)
# Stacktrace:
# 0   chromedriver                        0x0000000100a1d5dc cxxbridge1$str$ptr + 3653648
# 1   chromedriver                        0x0000000100a15e3c cxxbridge1$str$ptr + 3623024
# 2   chromedriver                        0x0000000100480100 cxxbridge1$string$len + 88404
# 3   chromedriver                        0x000000010045bb78 core::str::slice_error_fail::h1cab30ac4b13c655 + 3792
# 4   chromedriver                        0x00000001004e8664 cxxbridge1$string$len + 515768
# 5   chromedriver                        0x00000001004fb630 cxxbridge1$string$len + 593540
# 6   chromedriver                        0x00000001004b70fc cxxbridge1$string$len + 313680
# 7   chromedriver                        0x00000001004b7d4c cxxbridge1$string$len + 316832
# 8   chromedriver                        0x00000001009e864c cxxbridge1$str$ptr + 3436672
# 9   chromedriver                        0x00000001009eb988 cxxbridge1$str$ptr + 3449788
# 10  chromedriver                        0x00000001009cfa5c cxxbridge1$str$ptr + 3335312
# 11  chromedriver                        0x00000001009ec24c cxxbridge1$str$ptr + 3452032
# 12  chromedriver                        0x00000001009c0ce8 cxxbridge1$str$ptr + 3274524
# 13  chromedriver                        0x0000000100a069dc cxxbridge1$str$ptr + 3560464
# 14  chromedriver                        0x0000000100a06b58 cxxbridge1$str$ptr + 3560844
# 15  chromedriver                        0x0000000100a15ad4 cxxbridge1$str$ptr + 3622152
# 16  libsystem_pthread.dylib             0x00000001845b2f94 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001845add34 thread_start + 8

# %%
# /html/body/main/div[2]/div[2]/div[2]/div[2]/div/div[2]/div[2]/div/div/div/div/div/div[2]/div[3]/div/div/div[3]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

# Konfiguracja WebDrivera
ds = Service()
driver = webdriver.Chrome(service=ds)

# Lista do przechowywania danych o produktach
products_data = []

# Przechodzimy przez wszystkie strony
for page in range(1, 2):  # Możesz zmienić zakres stron
    url = f"https://www.mediaexpert.pl/komputery-i-tablety/laptopy-i-ultrabooki/laptopy?page={page}"
    driver.get(url)
    
    # Czekamy chwilę, aby strona się załadowała
    time.sleep(3)
    
    # Akceptujemy ciasteczka, jeśli przycisk jest obecny
    try:
        accept_cookies_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        accept_cookies_button.click()
        print("Kliknięto przycisk akceptacji ciasteczek")
    except:
        print("Przycisk akceptacji ciasteczek nie został znaleziony")

    # Pobieramy elementy dla każdego produktu
    products = driver.find_elements(By.XPATH, "//span/div[contains(@class, 'offer-box')]")
    
    for product in products:
        try:
            # Pobieramy tytuł produktu
            title = product.find_element(By.XPATH, ".//h2/a[contains(@class, 'is-animate ui-link')]").text
        except:
            title = "Brak danych"
        
        try:
            # Pobieramy cenę produktu
            price = product.find_element(By.XPATH, ".//div[contains(@class, 'main-price')]").text
        except:
            price = "Brak ceny"
        
        # Pobieramy szczegóły techniczne z tabeli
        try:
            # Szukamy tabeli w produkcie
            table = product.find_element(By.XPATH, ".//table[contains(@class, 'list attributes')]")
            rows = table.find_elements(By.XPATH, "./tbody/tr")
            
            # Zbieramy dane z tabeli do słownika
            details = {}
            for row in rows:
                try:
                    column_name = row.find_element(By.XPATH, "./th/span").text.strip()
                    value = row.find_element(By.XPATH, "./td/span").text.strip()
                    details[column_name] = value
                except Exception as e:
                    print(f"Błąd w przetwarzaniu szczegółów: {e}")
        except:
            details = {}
        
        # Tworzymy pełny słownik z wszystkimi szczegółami
        product_data = {
            "Tytuł": title,
            "Cena": price,
        }
        product_data.update(details)  # Dodajemy szczegóły jako osobne kolumny
        
        # Dodajemy produkt do listy
        products_data.append(product_data)

    print(f"--- Zakończono stronę {page} ---")


# Zapisujemy dane do CSV
import pandas as pd

df = pd.DataFrame(products_data)
df.to_csv("produkty_mediaexpert_szczegoly.csv", index=False)
print("Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv")
# Out:
# Kliknięto przycisk akceptacji ciasteczek
# --- Zakończono stronę 1 ---
# Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv

# %%
df
# Out:
#                                                 Tytuł           Cena
# 0   Laptop LENOVO LOQ 15IAX9 15.6" IPS 144Hz i5-12...  3 699\n00\nzł
# 1   Laptop APPLE MacBook Pro 2024 14" Retina M4 16...  8 499\n99\nzł
# 2   Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2 989\n00\nzł
# 3   Laptop ACER Nitro V ANV15-51 15.6" IPS 144Hz i...  3 699\n00\nzł
# 4   Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  4 879\n00\nzł
# 5   Laptop ASUS ExpertBook B1502CVA-BQ0095X 15.6" ...  2 799\n00\nzł
# 6   Laptop PREDATOR Helios Neo PHN16-71 16" IPS 16...  6 999\n99\nzł
# 7   Laptop APPLE MacBook Air 13.6" Retina M2 8GB R...  4 199\n00\nzł
# 8   Laptop ACER Swift Go 14 SFG14-63-R19Q 14" OLED...  3 499\n00\nzł
# 9   Laptop LENOVO Yoga 7 2-in-1 14IML9 14" OLED Ul...  4 999\n98\nzł
# 10  Laptop ACER Nitro AN16-41-R7U0 16" IPS 165Hz R...  6 699\n00\nzł
# 11  Laptop LENOVO Yoga Slim 6 14IRH8 14" OLED i5-1...  3 499\n00\nzł
# 12  Laptop ASUS TUF Gaming A15 FA507NV-TT903W 15.6...  4 999\n00\nzł
# 13  Laptop LENOVO Legion Slim 5 16IRH8 16" IPS 240...  5 999\n99\nzł
# 14  Laptop DELL G15 5530-6916 i7-13650HX 16GB RAM ...  5 999\n98\nzł
# 15  Laptop LENOVO Legion 5 15ARH7H 15.6" IPS 165Hz...  5 479\n00\nzł
# 16  Laptop ACER Nitro V 15 ANV15-51-53W4 15.6" IPS...  4 299\n99\nzł
# 17  Laptop HP Pavilion 15-EH3333NW 15.6" IPS R5-75...  2 799\n99\nzł
# 18  Laptop LENOVO Yoga Slim 7 15ILL9 Aura Edition ...  6 399\n99\nzł
# 19  Laptop ACER Nitro V 16 ANV16-41 16" IPS 165Hz ...  4 299\n00\nzł
# 20  Laptop ASUS VivoBook M1502YA-BQ059W 15.6" IPS ...  1 899\n99\nzł
# 21  Laptop LENOVO Legion Slim 5 16AHP9 16" IPS 240...  7 979\n00\nzł
# 22  Laptop ACER Swift 14 AI SF14-11 Copilot+ PC 14...  4 499\n00\nzł
# 23  Laptop LENOVO IdeaPad Slim 5 16ABR8 16" IPS R7...  2 998\n99\nzł
# 24  Laptop ACER Nitro 5 AN515-58 15.6" IPS 144Hz i...  3 389\n99\nzł
# 25  Laptop LENOVO Yoga Book 9 13IRU8 13.3" OLED i7...  8 979\n00\nzł
# 26  Laptop ACER Nitro V 15 ANV15-41 15.6" IPS 144H...  2 999\n99\nzł
# 27  Laptop LENOVO LOQ 15ARP9 15.6" IPS 144Hz R7-74...  3 999\n00\nzł
# 28  Laptop HP Envy x360 15-FH0333NW 15.6" IPS R5-7...  3 999\n98\nzł
# 29  Laptop LENOVO IdeaPad Slim 3 Chrome 14M868 14"...    999\n00\nzł

# %%
# Out:
# 0 Figa Coffee - Brazylia Monte Carmelo Filter 250g
# Producent: FIGA COFFEE
# Data palenia: 04.11.2024
# Najniższa cena: 30,90 zł
# 37,00 zł
# 35,99 zł
# 1 Figa Coffee - Brazylia Monte Carmelo STRONG Espresso 250g
# Producent: FIGA COFFEE
# Data palenia: 04.11.2024
# 37,00 zł
# 2 Story Coffee - Colombian Queen El Puente - Kolumbia Blend Filter 250g
# Producent: STORY COFFEE ROASTERS
# Data palenia: 31.10.2024
# 55,00 zł
# 3 Heresy - Antidotum Filter 252g
# Producent: HERESY
# Data palenia: 29.10.2024
# 49,00 zł
# 4 Heresy - Pastor Universal Blend 1001g
# Producent: HERESY
# Data palenia: 29.10.2024
# 146,00 zł
# 5 Heresy - Gwatemala La Soledad Washed Filter 252g
# Producent: HERESY
# Data palenia: 29.10.2024
# 89,00 zł
# 6 LaCava - Ecstasy Espresso 1kg
# Producent: LACAVA
# Data palenia: 29.10.2024
# 189,00 zł
# 7 Trigger - Brazylia Nutty Batch Filter 1kg
# Producent: TRIGGER
# Data palenia: 29.10.2024
# 146,00 zł
# 8 LaCava - Certified Espresso 1kg
# Producent: LACAVA
# Data palenia: 28.10.2024
# 159,00 zł
# 9 Paso Paso - Kostaryka Diego Robelo Peaberry Washed Omniroast 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 55,00 zł
# 10 Paso Paso - Etiopia Syoum Family Natural Omniroast 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 69,00 zł
# 11 LaCava - Black Art Espresso 1kg
# Producent: LACAVA
# Data palenia: 28.10.2024
# 129,00 zł
# 12 Paso Paso - Nikaragua Silvio Sanchez Catuai Natural Omniroast 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 69,00 zł
# 13 LaCava - Juicy BRU Filter 1kg
# Producent: LACAVA
# Data palenia: 28.10.2024
# 159,00 zł
# 14 LaCava - Daily BRU Filter 1kg
# Producent: LACAVA
# Data palenia: 28.10.2024
# 139,00 zł
# 15 LaCava - Paradox Espresso - Kawa Bezkofeinowa 1kg
# Producent: LACAVA
# Data palenia: 28.10.2024
# 159,00 zł
# 16 LaCava - Daily BRU Filter 350g
# Producent: LACAVA
# Data palenia: 28.10.2024
# 55,00 zł
# 17 Paso Paso - Café de la casa Espresso 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 49,00 zł
# 18 Paso Paso - Etiopia Syoum Family Sidamo Washed Filter 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 69,00 zł
# 19 LaCava - Gwatemala La Soledad Washed Filter 250g
# Producent: LACAVA
# Data palenia: 28.10.2024
# 60,00 zł
# 20 Paso Paso - Salwador Diego Baraona Bourbon Washed Omniroast 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 69,00 zł
# 21 Paso Paso - Kostaryka Jorge Vasquez Catuai Washed Omniroast 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 69,00 zł
# 22 Paso Paso - Kostaryka Diego Robelo Centroamericano Red Honey Filter 250g
# Producent: PASO PASO
# Data palenia: 28.10.2024
# 69,00 zł
# 23 Etno Cafe - Italian Roast 250g
# Producent: ETNO CAFE
# Data palenia: 25.10.2024
# 29,00 zł
# 24 MAMAM - Kostaryka Sonora SL28 Natural Filter 250g
# Producent: MAMAM
# Data palenia: 24.10.2024
# 92,00 zł
# 25 MAMAM - Kenia Rung’eto Kii Washed Filter 250g
# Producent: MAMAM
# Data palenia: 24.10.2024
# 80,00 zł
# 26 MAMAM - Kolumbia El Jardin Washed Filter 250g
# Producent: MAMAM
# Data palenia: 24.10.2024
# 68,00 zł
# 27 The Barn - Etiopia Banko Gotiti Anaerobic Filter 250g
# Producent: THE BARN
# Data palenia: 24.10.2024
# 90,00 zł
# 28 Father's Coffee - Indonezja Pegasing Thermal Washed Filter 300g
# Producent: FATHER'S COFFEE
# Data palenia: 24.10.2024
# 93,00 zł
# 29 Father's Coffee - Kolumbia La Cuba Washed Filter 300g
# Producent: FATHER'S COFFEE
# Data palenia: 24.10.2024
# 74,00 zł
# 30 MAMAM - Kolumbia La Soledad Washed Filter 250g
# Producent: MAMAM
# Data palenia: 24.10.2024
# 99,00 zł
# 31 Father's Coffee - Etiopia Chelbesa Washed Dry Fermentation Filter 300g
# Producent: FATHER'S COFFEE
# Data palenia: 24.10.2024
# 86,00 zł
# 32 MAMAM - Brazylia Monteiro Lobato Natural Filter 250g
# Producent: MAMAM
# Data palenia: 24.10.2024
# 42,99 zł
# 33 The Barn - Salwador Los Pirineos Black Honey Filter 250g
# Producent: THE BARN
# Data palenia: 24.10.2024
# 90,00 zł
# 34 Father's Coffee - Gwatemala Pena Roja Anaerobic Natural Filter 300g
# Producent: FATHER'S COFFEE
# Data palenia: 24.10.2024
# 86,00 zł

# %%
# !pip install scrapy

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import json

class JsonWriterPipeline(object):
    def open_spider(self, spider):
        pass

    def close_spider(self, spider):
        pass

    def process_item(self, item, spider):
        pass
    

class MySpider(scrapy.Spider):
    name = 'mySpider'
    start_urls = []

    custom_settings = {
        'LOG_LEVEL': 'INFO',
    }
    
    def parse(self, response):

        
    
    def _parse_listig(self, listing, response):

        item = {
            'link': 'N/A',
            'title':  'N/A',
            'Localisation':  'N/A',
            'price':  'N/A',
            'room_count':  'N/A',
            'space_sm': 'N/A',
            'floor':  'N/A',
            'representative': 'N/A'
        }

         # Extract the link

        # Extract title

        # Extract localisation

        # Extract price and additional fee

        # Extract rooms, space, and floor information from details

        # Extract representative (e.g., "Oferta prywatna" or other info)

        return item


process = CrawlerProcess({...
})

process.crawl(MySpider)
process.start()
# Out:
# 2024-11-09 15:17:57 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2024-11-09 15:17:57 [scrapy.utils.log] INFO: Versions: lxml 5.2.1.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 24.0.0 (OpenSSL 3.0.14 4 Jun 2024), cryptography 42.0.5, Platform Windows-10-10.0.19045-SP0
# 2024-11-09 15:17:57 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-11-09 15:17:57 [scrapy.extensions.telnet] INFO: Telnet Password: 96f86ab70f966dc6
# 2024-11-09 15:17:57 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-11-09 15:17:57 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 'INFO',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64; rv:48.0) Gecko/20100101 '
#                'Firefox/48.0'}
# 2024-11-09 15:17:58 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-11-09 15:17:58 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-11-09 15:17:58 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.JsonWriterPipeline']
# 2024-11-09 15:17:58 [scrapy.core.engine] INFO: Spider opened
# 2024-11-09 15:17:58 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-11-09 15:17:58 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-11-09 15:18:20 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-11-09 15:18:20 [scrapy.extensions.feedexport] INFO: Stored json feed (12048 items) in: quoteresult_1.json
# 2024-11-09 15:18:20 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 189497,
#  'downloader/request_count': 620,
#  'downloader/request_method_count/GET': 620,
#  'downloader/response_bytes': 21710597,
#  'downloader/response_count': 620,
#  'downloader/response_status_count/200': 310,
#  'downloader/response_status_count/301': 310,
#  'elapsed_time_seconds': 22.14805,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 11, 9, 14, 18, 20, 351750, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 166063945,
#  'httpcompression/response_count': 310,
#  'item_scraped_count': 12048,
#  'log_count/INFO': 11,
#  'response_received_count': 310,
#  'scheduler/dequeued': 620,
#  'scheduler/dequeued/memory': 620,
#  'scheduler/enqueued': 620,
#  'scheduler/enqueued/memory': 620,
#  'start_time': datetime.datetime(2024, 11, 9, 14, 17, 58, 203700, tzinfo=datetime.timezone.utc)}
# 2024-11-09 15:18:20 [scrapy.core.engine] INFO: Spider closed (finished)
