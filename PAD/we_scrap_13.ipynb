# %%
from selenium.webdriver.common.by import By
import time
time.sleep(3)

# Akceptujemy wszystkie ciasteczka
try:
    accept_cookies_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
    accept_cookies_button.click()
    print("Kliknięto przycisk akceptacji ciasteczek")
except:
    print("Przycisk akceptacji ciasteczek nie został znaleziony")

# %%
elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'box')]/h2/a[contains(@class, 'is-animate ui-link')]")

# Iterujemy po znalezionych elementach i wypisujemy ich teksty
for element in elements:
    print("Pobrany tekst:", element.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'box')]/h2/a[contains(@class, 'is-animate ui-link')]")
#       3 # Iterujemy po znalezionych elementach i wypisujemy ich teksty
#       4 for element in elements:
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:788, in WebDriver.find_elements(self, by, value)
#     784     return self.execute_script(find_element_js, by.to_dict())
#     786 # Return empty list if driver returns null
#     787 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 788 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:380, in WebDriver.execute(self, driver_command, params)
#     378 response = self.command_executor.execute(driver_command, params)
#     379 if response:
# --> 380     self.error_handler.check_response(response)
#     381     response["value"] = self._unwrap_value(response.get("value", None))
#     382     return response
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=130.0.6723.119)
# Stacktrace:
# 0   chromedriver                        0x0000000100a1d5dc cxxbridge1$str$ptr + 3653648
# 1   chromedriver                        0x0000000100a15e3c cxxbridge1$str$ptr + 3623024
# 2   chromedriver                        0x0000000100480100 cxxbridge1$string$len + 88404
# 3   chromedriver                        0x000000010045bb78 core::str::slice_error_fail::h1cab30ac4b13c655 + 3792
# 4   chromedriver                        0x00000001004e8664 cxxbridge1$string$len + 515768
# 5   chromedriver                        0x00000001004fb630 cxxbridge1$string$len + 593540
# 6   chromedriver                        0x00000001004b70fc cxxbridge1$string$len + 313680
# 7   chromedriver                        0x00000001004b7d4c cxxbridge1$string$len + 316832
# 8   chromedriver                        0x00000001009e864c cxxbridge1$str$ptr + 3436672
# 9   chromedriver                        0x00000001009eb988 cxxbridge1$str$ptr + 3449788
# 10  chromedriver                        0x00000001009cfa5c cxxbridge1$str$ptr + 3335312
# 11  chromedriver                        0x00000001009ec24c cxxbridge1$str$ptr + 3452032
# 12  chromedriver                        0x00000001009c0ce8 cxxbridge1$str$ptr + 3274524
# 13  chromedriver                        0x0000000100a069dc cxxbridge1$str$ptr + 3560464
# 14  chromedriver                        0x0000000100a06b58 cxxbridge1$str$ptr + 3560844
# 15  chromedriver                        0x0000000100a15ad4 cxxbridge1$str$ptr + 3622152
# 16  libsystem_pthread.dylib             0x00000001845b2f94 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001845add34 thread_start + 8

# %%
# /html/body/main/div[2]/div[2]/div[2]/div[2]/div/div[2]/div[2]/div/div/div/div/div/div[2]/div[3]/div/div/div[3]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

# Konfiguracja WebDrivera
ds = Service()
driver = webdriver.Chrome(service=ds)

# Lista do przechowywania danych o produktach
products_data = []

# Przechodzimy przez wszystkie strony
# range(1,60)
for page in range(1, 2):  # Możesz zmienić zakres stron
    url = f"https://www.mediaexpert.pl/komputery-i-tablety/laptopy-i-ultrabooki/laptopy?page={page}"
    driver.get(url)
    
    # Czekamy chwilę, aby strona się załadowała
    time.sleep(3)
    
    # Akceptujemy ciasteczka, jeśli przycisk jest obecny
    try:
        accept_cookies_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        accept_cookies_button.click()
        print("Kliknięto przycisk akceptacji ciasteczek")
    except:
        print("Przycisk akceptacji ciasteczek nie został znaleziony")

    # Pobieramy elementy dla każdego produktu
    products = driver.find_elements(By.XPATH, "//span/div[contains(@class, 'offer-box')]")
    
    for product in products:
        try:
            # Pobieramy tytuł produktu
            title = product.find_element(By.XPATH, ".//h2/a[contains(@class, 'is-animate ui-link')]").text
        except:
            title = "Brak danych"
        
        try:
            # Pobieramy cenę produktu
            price = product.find_element(By.XPATH, ".//div[contains(@class, 'main-price')]").text
        except:
            price = "Brak ceny"
        
        # Pobieramy szczegóły techniczne z tabeli
        try:
            # Szukamy tabeli w produkcie
            table = product.find_element(By.XPATH, ".//table[contains(@class, 'list attributes')]")
            rows = table.find_elements(By.XPATH, "./tbody/tr")
            
            # Zbieramy dane z tabeli do słownika
            details = {}
            for row in rows:
                try:
                    column_name = row.find_element(By.XPATH, "./th/span").text.strip()
                    value = row.find_element(By.XPATH, "./td/span").text.strip()
                    details[column_name] = value
                except Exception as e:
                    print(f"Błąd w przetwarzaniu szczegółów: {e}")
        except:
            details = {}
        
        # Tworzymy pełny słownik z wszystkimi szczegółami
        product_data = {
            "Tytuł": title,
            "Cena": price,
            "Sklep": "ediaexpert"
        }
        product_data.update(details)  # Dodajemy szczegóły jako osobne kolumny
        
        # Dodajemy produkt do listy
        products_data.append(product_data)

    print(f"--- Zakończono stronę {page} ---")


# Zapisujemy dane do CSV
import pandas as pd

df = pd.DataFrame(products_data)
df.to_csv("produkty_mediaexpert_szczegoly.csv", index=False)
print("Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv")
# Out:
# Kliknięto przycisk akceptacji ciasteczek
# --- Zakończono stronę 1 ---
# Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

# Konfiguracja WebDrivera
ds = Service()
driver = webdriver.Chrome(service=ds)

# Lista do przechowywania danych o produktach
products_data_media_markt = []

# Przechodzimy przez wszystkie strony
# range(1,17)
for page in range(1, 2):  # Możesz zmienić zakres stron
    url = f"https://mediamarkt.pl/pl/category/laptopy-25867.html?page={page}"
    driver.get(url)
    
    # Czekamy chwilę, aby strona się załadowała
    time.sleep(3)
    
    # Akceptujemy ciasteczka, jeśli przycisk jest obecny
    try:
        accept_cookies_button = driver.find_element(By.ID, "pwa-consent-layer-accept-all-button")
        accept_cookies_button.click()
        print("Kliknięto przycisk akceptacji ciasteczek")
    except Exception as e:
        print("Przycisk akceptacji ciasteczek nie został znaleziony lub wystąpił błąd:", e)


    # Pobieramy elementy dla każdego produktu
    products = driver.find_elements(By.XPATH, "//div/div[contains(@class, 'sc-597dbd60-0 InVqu')]")
    
for product in products:
    try:
        # Pobieramy tytuł produktu w odniesieniu do elementu `product`
        title = product.find_element(By.XPATH, ".//p[contains(@class, 'sc-8b815c14-0 dbwSez')]").text
        print("Tytuł produktu:", title)
    except Exception as e:
        print("Nie udało się pobrać tytułu dla produktu:", e)

print(f"--- Zakończono stronę {page} ---")


# Zapisujemy dane do CSV
import pandas as pd

df = pd.DataFrame(products_data_media_markt)
df.to_csv("produkty_mediamarkt_szczegoly.csv", index=False)
print("Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv")
# Out:
# Kliknięto przycisk akceptacji ciasteczek
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# Tytuł produktu:
# --- Zakończono stronę 1 ---
# Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv

# %%
products = driver.find_elements(By.XPATH, "//div/div[contains(@class, 'sc-597dbd60-0 InVqu')]")

for product in products:
    try:
        # Pobieramy wartość z atrybutu `title` w elemencie <div> o odpowiedniej klasie
        title = product.find_element(By.XPATH, ".//div[contains(@class, 'sc-bc13ac82-0') and @title]").get_attribute("title")
        print("Tytuł produktu:", title)
    except Exception as e:
        print("Nie udało się pobrać tytułu dla produktu:", e)
    try:
        # Znajdujemy kontener z danymi
        table = product.find_element(By.XPATH, ".//dl[contains(@class, 'sc-c838db2c-0 VUoRZ')]")
        rows = table.find_elements(By.XPATH, "./dt")  # Znajdujemy wszystkie `dt`
        
        values = table.find_elements(By.XPATH, "./dt")  # Znajdujemy wszystkie `dt`
    
        # Inicjalizujemy słownik na szczegóły
        details = {}

        for i, dt in enumerate(rows):
            try:
                # Pobieramy nazwę kolumny z `dt`
                column_name = dt.find_element(By.XPATH, ".//p[contains(@class, 'sc-8b815c14-0 kDPqet')]").text.strip()

                # Pobieramy odpowiadającą wartość z `dd` - ten sam indeks co `dt`
                dd = table.find_elements(By.XPATH, "./dd")[i]
                column_value = dd.find_element(By.XPATH, "./div/p").text.strip()

                print('xxxxx')
                print(column_name)
                print(column_value)
                print('xxxxx')

                # Dodajemy kolumnę i wartość do słownika
                details[column_name] = column_value
            except Exception as e:
                print(f"Błąd przy przetwarzaniu pary dt-dd: {e}")

        # Wyświetlamy dane szczegółowe dla produktu
        print("Szczegóły produktu:", details)
    except Exception as e:
        print("Nie udało się pobrać szczegółów dla produktu:", e)

    product_data = {
            "Tytuł": title,
            "Sklep": "MediaMarkt"
         }    
    product_data.update(details)  # Dodajemy szczegóły jako osobne kolumny

    products_data_media_markt.append(product_data)

df = pd.DataFrame(products_data_media_markt)
df.to_csv("produkty_mediamarkt_szczegoly.csv", index=False)
print("Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv")
# Out:
# Tytuł produktu: Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A
# xxxxx
# Przekątna ekranu
# 33.78 cm / 13.3 "
# xxxxx
# xxxxx
# Procesor
# Apple M1
# xxxxx
# xxxxx
# Pamięć RAM
# 8 GB
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'Przekątna ekranu': '33.78 cm / 13.3 "', 'Procesor': 'Apple M1', 'Pamięć RAM': '8 GB', '': ''}
# Tytuł produktu: Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Tytuł produktu: Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# xxxxx
#
#
# xxxxx
# Szczegóły produktu: {'': ''}
# Dane zapisano do pliku produkty_mediaexpert_szczegoly.csv

# %%
# Out:
# [{'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt'},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt',
#   'Przekątna ekranu': '33.78 cm / 13.3 "',
#   'Procesor': 'Apple M1',
#   'Pamięć RAM': '8 GB',
#   '': ''},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M1/8GB/256GB SSD/INT/macOS Gwiezdna szarość MGN63ZE/A',
#   'Sklep': 'MediaMarkt',
#   'Przekątna ekranu': '33.78 cm / 13.3 "',
#   'Procesor': 'Apple M1',
#   'Pamięć RAM': '8 GB',
#   '': ''},
#  {'Tytuł': 'Laptop HP 15-fc0056nw FHD Ryzen 3 7320U/8GB/512GB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop LENOVO IdeaPad 3 15IAU7 FHD i3-1215U/8GB/512GB SSD/INT/Win11H Szary (Arctic Grey)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Gaming 3 15ACH6 82K2028BPB FHD Ryzen 5 5500H/16GB/512GB SSD/RTX2050 4GB/Win11H Czarny (Shadow Black)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop HP 15s-eq2771nw FHD Ryzen 7 5700U/16GB/1TB SSD/INT/Win11H Srebrny (Natural Silver)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop 2w1 LENOVO Yoga 7 14IML9 2.8K Dotykowy Ultra 5 125H/16GB/1TB SSD/INT/Win11H  GW36M Zielony (Tidal Teal) + Rysik + Etui',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop ACER Extensa 15 EX215-55-51WD i5-1235U/16GB/512GB SSD/INT/Win11H Szary (Steel Gray)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop ASUS TUF Gaming F17 FX707ZC4-HX008W FHD i5-12500H/16GB/512GB SSD/RTX3050 4GB/Win11H Szary (Mecha Gray)',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-1G464P FHD N4020/4GB/64GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop APPLE MacBook Air 13 M3/8GB/256GB SSD/INT/macOS Gwiezdna szarość',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop LENOVO IdeaPad Slim 3 15ABR8 82XM00BCPB Ryzen 5 7530U/16GB/512GB SSD/INT/Win11H GW36M Szary',
#   'Sklep': 'MediaMarkt',
#   '': ''},
#  {'Tytuł': 'Laptop PEAQ Slim S132V-2G428P-2O FHD Pentium Silver N5030/4GB/128GB eMMC/INT/Win11S + Microsoft 365 12 mies.',
#   'Sklep': 'MediaMarkt',
#   '': ''}]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

# Konfiguracja WebDrivera
ds = Service()
driver = webdriver.Chrome(service=ds)

# Lista do przechowywania danych o produktach
products_data_xkom = []

# Przechodzimy przez wybrane strony (możesz zmienić zakres)
for page in range(1, 2):  # Dostosuj zakres stron
    url = f"https://www.x-kom.pl/g-2/c/159-laptopy-notebooki-ultrabooki.html?page={page}"
    driver.get(url)
    
    # Czekamy chwilę, aby strona się załadowała
    time.sleep(3)
    
    # Pobieramy elementy dla każdego produktu
    products = driver.find_elements(By.XPATH, "//div[contains(@class, 'BoxFlex__Box-sc-bfe0bca9-0 iHPBSK parts__ProductListCol-sc-a93b49f9-1 coJOdn')]")
    
    for product in products:
        # Inicjalizacja zmiennych
        title = "Brak danych"
        price = "Brak danych"
        details = {}

        try:
            # Pobieramy tytuł produktu
            title = product.find_element(By.XPATH, ".//h3[contains(@class, 'parts__Title-sc-1d28d-0 fKUIM parts__Title-sc-6e280ffa-9 hqUuGB')]/span").text
        except Exception as e:
            print("Nie udało się pobrać tytułu dla produktu:", e)

        try:
            # Pobieramy cenę produktu
            price = product.find_element(By.XPATH, ".//span[contains(@class, 'sc-jnqLxu cjLwnY parts__Price-sc-6e255ce0-0 jWNFsL')]").text
        except Exception as e:
            print("Nie udało się pobrać ceny dla produktu:", e)

        try:
            # Znajdujemy wszystkie elementy <li> o podanej klasie
            features = product.find_elements(By.XPATH, ".//li[contains(@class, 'parts__ListItem-sc-27c8b4c9-2 eDfVv')]")
            for feature in features:
                try:
                    # Pobieramy tekst z <li>
                    text = feature.text.strip()
                    # Rozdzielamy na nazwę kolumny i wartość
                    if ":" in text:
                        column_name, column_value = text.split(":", 1)  # Rozdzielamy tylko raz
                        details[column_name.strip()] = column_value.strip()
                except Exception as e:
                    print(f"Błąd przy przetwarzaniu elementu <li>: {e}")
        except Exception as e:
            print("Nie udało się pobrać szczegółów dla produktu:", e)

        # Tworzymy pełny słownik z wszystkimi szczegółami
        product_data = {
            "Tytuł": title,
            "Cena": price,
            "Sklep": "xkom"
        }
        product_data.update(details)  # Dodajemy szczegóły jako osobne kolumny
        print(f"--- title: {title} ---")
        print(f"--- price: {price} ---")
        
        # Dodajemy produkt do listy
        products_data_xkom.append(product_data)

    print(f"--- Zakończono stronę {page} ---")

# Zapisujemy dane do pliku CSV
df = pd.DataFrame(products_data_xkom)
df.to_csv("produkty_xkom_szczegoly.csv", index=False)
print("Dane zapisano do pliku produkty_xkom_szczegoly.csv")
# Out:
# --- title: Apple MacBook Air M1/8GB/256/Mac OS Space Gray ---
# --- price: 3 399,00 zł ---
# --- title: ASUS Vivobook 15 R5‑7530U/16GB/512/Win11 ---
# --- price: 1 889,00 zł ---
# --- title: ASUS Vivobook 15 i5‑1235U/16GB/512/Win11 ---
# --- price: 2 299,00 zł ---
# --- title: Lenovo IdeaPad Slim 3‑15 i5‑12450H/16GB/512/Win11 ---
# --- price: 2 399,00 zł ---
# --- title: Acer Chromebook 315 N4500/8GB/128/FHD ChromeOS ---
# --- price: 1 299,00 zł ---
# --- title: Dell Inspiron 3525 Ryzen 5 5500U/16GB/512/Win11 120Hz ---
# --- price: 2 099,00 zł ---
# --- title: Lenovo IdeaPad Slim 3‑15 i5‑12450H/16GB/1TB/Win11 ---
# --- price: 2 499,00 zł ---
# --- title: Gigabyte AORUS 7 9KF i5‑12500H/16GB/512 RTX4060 360Hz ---
# --- price: 4 499,00 zł ---
# --- title: Dell Vostro 3520 i5‑1235U/16GB/512/Win11P ---
# --- price: 2 599,00 zł ---
# --- title: Dell Vostro 3520 i5‑1235U/16GB/512/Win11P EDU ---
# --- price: 2 499,00 zł ---
# --- title: Dell Inspiron 3520 i5‑1235U/16GB/512/Win11 120Hz ---
# --- price: 2 499,00 zł ---
# --- title: ASUS ZenBook 14 UM3402YA R5‑7430U/16GB/512/Win11 ---
# --- price: 3 299,00 zł ---
# --- title: Lenovo IdeaPad Slim 3‑15 Ryzen 3 7320U/8GB/512/Win11 ---
# --- price: 1 599,00 zł ---
# --- title: Lenovo Yoga 7 2‑in‑1 Ultra 5‑125H/16GB/1TB/Win11 ---
# --- price: 4 999,00 zł ---
# --- title: Lenovo Yoga Slim 6‑14 i5‑13500H/16GB/512/Win11 ---
# --- price: 3 699,00 zł ---
# --- title: Lenovo IdeaPad Gaming 3‑15 R5‑7535HS/16GB/512+1TB/Win11 RTX3050 ---
# --- price: 3 349,00 zł ---
# --- title: Lenovo IdeaPad Gaming 3‑15 R5‑7535HS/16GB/512/Win11 RTX3050 ---
# --- price: 3 299,00 zł ---
# --- title: Apple MacBook Air M2/8GB/256/Mac OS Midnight ---
# --- price: 4 999,00 zł ---
# --- title: MSI Thin A15 Ryzen 5‑7535HS/16GB/512 RTX3050 144Hz ---
# --- price: 2 699,00 zł ---
# --- title: HP Pavilion 15 i5‑1335U/16GB/512/Win11 ---
# --- price: 2 899,00 zł ---
# --- title: HP Victus 15 i5‑12450H/32GB/1TB/Win11 RTX3050 144Hz ---
# --- price: 3 699,00 zł ---
# --- title: MSI Thin 15 i5‑12450H/16GB/512 RTX2050 144Hz ---
# --- price: 2 399,00 zł ---
# --- title: MSI Bravo 17 Ryzen 5‑7535HS/16GB/512 RTX4050 144Hz ---
# --- price: 3 899,00 zł ---
# --- title: Acer Aspire 3 R7‑5700U/16GB/512/Win11 ---
# --- price: 2 399,00 zł ---
# --- title: Acer Nitro V16 R7‑8845HS/16GB/1TB/Win11 RTX4060 165Hz ---
# --- price: 4 999,00 zł ---
# --- title: Lenovo Legion 5‑16 i7‑13650HX/32GB/512+1TB/Win11 RTX4060 165Hz ---
# --- price: 6 199,00 zł ---
# --- title: Acer Nitro V R5‑7535HS/16GB/512 RTX3050 144Hz ---
# --- price: 2 999,00 zł ---
# --- title: Lenovo LOQ 15 i5‑12450HX/32GB/512+1TB/Win11X RTX4060 144Hz ---
# --- price: 4 999,00 zł ---
# --- title: Lenovo IdeaPad Gaming 3‑15 R5‑7535HS/32GB/512+1TB/Win11 RTX3050 ---
# --- price: 3 749,00 zł ---
# --- title: Apple MacBook Air M1/8GB/256/Mac OS Space Gray 36msc ---
# --- price: 3 999,00 zł ---
# --- Zakończono stronę 1 ---
# Dane zapisano do pliku produkty_xkom_szczegoly.csv

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd

# Konfiguracja WebDrivera
ds = Service()
driver = webdriver.Chrome(service=ds)

# Lista do przechowywania danych o produktach
products_data_rtv = []

# Przechodzimy przez wybrane strony (możesz zmienić zakres)
for page in range(1, 2):  # Dostosuj zakres stron
    url = f"https://www.euro.com.pl/laptopy-i-netbooki,strona-{page}.bhtml?link=old-nav"
    driver.get(url)
    
    # Czekamy chwilę, aby strona się załadowała
    time.sleep(3)
    
    # Pobieramy elementy dla każdego produktu
    products = driver.find_elements(By.XPATH, "//div[contains(@class, 'product-medium-box')]")
    
    for product in products:
        # Inicjalizacja zmiennych
        print('product')


    print(f"--- Zakończono stronę {page} ---")

# Zapisujemy dane do pliku CSV
df = pd.DataFrame(products_data_rtv)
df.to_csv("produkty_rtv_szczegoly.csv", index=False)
print("Dane zapisano do pliku produkty_rtv_szczegoly.csv")
# Out:
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# product
# --- Zakończono stronę 1 ---
# Dane zapisano do pliku produkty_rtv_szczegoly.csv

# %%
# Out:
# --- Zakończono stronę 1 ---
